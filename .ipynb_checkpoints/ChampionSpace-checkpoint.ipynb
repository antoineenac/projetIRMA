# %%
import numpy as np
import math
import matplotlib.pyplot as plt
import pandas as pd

# %%
import json

with open('Champs.txt') as f:
    data = f.read()
Champs = json.loads(data)

# %%
Champs
# Out:
# {'Aatrox': {'HP base': '650',
#   'MaxHP': '764',
#   'Mana base': '-1',
#   'Range': '175',
#   'Classe': 'Combattant',
#   'Engage': '0.75',
#   'Peel': '1',
#   'Degats': '3',
#   'Global': '0',
#   'CC': '3',
#   'Hook': '0.5',
#   'Heal': '3',
#   'Shield': '0',
#   'Dash': '1',
#   'Early game': '0.3',
#   'Mid game': '0.6',
#   'Late game': '0.7',
#   'Tank': '0.05',
#   'Bruiser AD': '1',
#   'Bruiser AP': '0',
#   'Burst AP': '0',
#   'DPS AP': '0',
#   'onhit': '0',
#   'Critique': '0.2',
#   'Lethalité': '0.5',
#   'Support Tank': '0',
#   'Support Utilitaire': '0',
#   'Top': '0.98',
#   'JGL': '0.04',
#   'Mid': '0.04',
#   'ADC': '0',
#   'SUP': '0'},
#  'Ahri': {'HP base': '590',
#   'MaxHP': '684',
#   'Mana base': '418',
#   'Range': '550',
#   'Classe': 'Mage',
#   'Engage': '2',
#   'Peel': '0.5',
#   'Degats': '4',
#   'Global': '0',
#   'CC': '1',
#   'Hook': '0',
#   'Heal': '1',
#   'Shield': '0',
#   'Dash': '2',
#   'Early game': '0.4',
# ...

# %%
def add_champ():
    print("Nom du champion")
    name = input()
    print("HP de base")
    hp = input()
    print("MaxHp base")
    maxhp = input()
    print("Mana de base")
    mana = input()
    print("Portée")
    portee = input()
    print("Classe") #directement celle de riot, encodage a reflechir
    classe=input()
    print("Sorts d'Engage")#nombre de sort d'engage
    engage=input()
    print("Sorts de Peel") #nombre de sort de peel
    peel = input()
    print("Sorts de degats") #nombre de sort uniquement pour les degats
    deg = input()
    print("Poke")
    poke = input()
    print("Sorts globaux")
    glob = input()
    print("Gros CD")
    cd = input()
    print("Tank?")
    tank = input()
    print("Bruiser AD?")
    bruiserad = input()
    print("Bruiser AP?")
    bruiserap = input()
    print("AP burst?")
    burstap = input()
    print("AP dps?")
    dpsap = input()
    print("On hit?")
    onhit = input()
    print("critique?")
    crit = input()
    print("lethalite?")
    leta = input()
    print("support degat")
    supdeg = input()
    print("support full")
    supful = input()
    print("TOP?") #%age de pick a ce role
    top = input()
    print("JGL?")
    jgl = input()
    print("MID?")
    mid = input()
    print("ADC?")
    adc = input()
    print("SUP?")
    sup = input()
    Champs[name] = {"Poke" : poke,"Gros CD" : cd, "Global" : glob,"On hit":onhit, "Critique" : crit, "Lethalité" : leta, "Support degats" : supdeg, "Support" : supful,"Tank" : tank, "Bruiser AD" : bruiserad, "Bruiser AP" : bruiserap,"Burst AP" :burstap,"AP DPS" : dpsap, "HP" : hp,"Mana" : mana,"Portee" : portee,"Classe" : classe,"Engage" : engage,"Peel" : peel,"Degats": deg, "Top" : top,"JGL" : jgl,"Mid" : mid,"ADC" : adc,"Sup" : sup}

# %%
f = open('champion.json',encoding="utf8")
  
# returns JSON object as 
# a dictionary
data = json.load(f)

# %%
data['data']['Nilah']
# Out:
# {'version': '13.11.1',
#  'id': 'Nilah',
#  'key': '895',
#  'name': 'Nilah',
#  'title': 'the Joy Unbound',
#  'blurb': "Nilah is an ascetic warrior from a distant land, seeking the world's deadliest, most titanic opponents so that she might challenge and destroy them. Having won her power through an encounter with the long-imprisoned demon of joy, she has no emotions...",
#  'info': {'attack': 8, 'defense': 4, 'magic': 4, 'difficulty': 10},
#  'image': {'full': 'Nilah.png',
#   'sprite': 'champion2.png',
#   'group': 'champion',
#   'x': 336,
#   'y': 96,
#   'w': 48,
#   'h': 48},
#  'tags': ['Fighter', 'Assassin'],
#  'partype': 'Mana',
#  'stats': {'hp': 570,
#   'hpperlevel': 101,
#   'mp': 350,
#   'mpperlevel': 35,
#   'movespeed': 340,
#   'armor': 27,
#   'armorperlevel': 4.2,
#   'spellblock': 32,
#   'spellblockperlevel': 2.05,
#   'attackrange': 225,
#   'hpregen': 4,
#   'hpregenperlevel': 0.9,
#   'mpregen': 8.2,
#   'mpregenperlevel': 0.7,
#   'crit': 0,
# ...
