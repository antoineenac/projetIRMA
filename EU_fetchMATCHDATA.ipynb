# %%
import requests
import time
import numpy as np
import os

# %%
key = "RGAPI-0bd772e8-d399-4acf-8934-52c0195aa383"

# %%
EU_matchs_id = np.load('MATCHID\EU_matchs_id.npy')

# %%
EU_matchs_data = list(np.load("MATCHDATA\EU_matchs_data.npy",allow_pickle=True))

# %%
len(EU_matchs_data)
# Out:
# 5400

# %%
def add_match(match_id,api_key):
    Match = []
    try:
        req = 'https://europe.api.riotgames.com/lol/match/v5/matches/{}?api_key={}'.format(match_id,api_key)
        time.sleep(0.9)
        r = requests.get(req)
        match_info = r.json()
        if match_info['info']['queueId']==420:
            Blue,Red = [],[]
            players = match_info['info']['participants']
            Winner = "Blue" if players[0]['win'] else "Red"
            for i in range(len(players)):
                if i<5:
                    Blue.append(players[i]['individualPosition'])
                    Blue.append(players[i]['championName'])
                else:
                    Red.append(players[i]['individualPosition'])
                    Red.append(players[i]['championName'])
            Match = [Blue,Red,Winner]
    except:
        pass
    return Match

# %%
def match(key):
    m_idss=EU_matchs_id[len(EU_matchs_data)::]
    c=len(EU_matchs_data)
    aux = len(EU_matchs_data)
    for m in m_idss:
        if os.path.exists(os.path.join(os.getcwd(),'stop_true.txt')):
            break
        ma = add_match(m,key)
        if ma!=[]:
            EU_matchs_data.append(ma)
            c+=1
        if c%100==0 or c==aux:
            print("Matchs ajoutés : {}\n".format(c))
            print("Dernier match ajouté : {}".format(ma))
            np.save("MATCHDATA\EU_matchs_data.npy",np.array(EU_matchs_data,dtype=list))

# %%
match(key)
# Out:
# Matchs ajoutés : 5410
#
# Dernier match ajouté : []
# Matchs ajoutés : 5500
#
# Dernier match ajouté : [['TOP', 'Irelia', 'JUNGLE', 'Kindred', 'MIDDLE', 'Zoe', 'BOTTOM', 'Draven', 'UTILITY', 'Nami'], ['TOP', 'Riven', 'JUNGLE', 'Kayn', 'MIDDLE', 'Yasuo', 'BOTTOM', 'Ezreal', 'UTILITY', 'Soraka'], 'Red']
# Matchs ajoutés : 5600
#
# Dernier match ajouté : [['TOP', 'Yasuo', 'JUNGLE', 'Vi', 'MIDDLE', 'Akali', 'BOTTOM', 'Kalista', 'UTILITY', 'Leona'], ['TOP', 'Rammus', 'JUNGLE', 'Warwick', 'MIDDLE', 'Lissandra', 'BOTTOM', 'Caitlyn', 'UTILITY', 'Janna'], 'Red']
# Matchs ajoutés : 5700
#
# Dernier match ajouté : [['TOP', 'Akali', 'JUNGLE', 'Hecarim', 'MIDDLE', 'Syndra', 'BOTTOM', 'Draven', 'UTILITY', 'Nautilus'], ['TOP', 'Fiora', 'JUNGLE', 'Rengar', 'MIDDLE', 'Anivia', 'BOTTOM', 'Zeri', 'UTILITY', 'Rakan'], 'Blue']
# Matchs ajoutés : 5800
#
# Dernier match ajouté : [['TOP', 'Renekton', 'JUNGLE', 'Hecarim', 'MIDDLE', 'Syndra', 'BOTTOM', 'Karthus', 'UTILITY', 'Rell'], ['TOP', 'Jax', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Lissandra', 'BOTTOM', 'Aphelios', 'UTILITY', 'Thresh'], 'Blue']
# Matchs ajoutés : 5900
#
# Dernier match ajouté : [['TOP', 'Talon', 'JUNGLE', 'JarvanIV', 'MIDDLE', 'Xerath', 'BOTTOM', 'Twitch', 'UTILITY', 'Rell'], ['TOP', 'Aatrox', 'JUNGLE', 'Khazix', 'BOTTOM', 'Varus', 'MIDDLE', 'Karthus', 'UTILITY', 'Renata'], 'Blue']
# Matchs ajoutés : 6000
#
# Dernier match ajouté : [['TOP', 'Poppy', 'JUNGLE', 'Evelynn', 'MIDDLE', 'Naafiri', 'BOTTOM', 'Zeri', 'UTILITY', 'Xerath'], ['TOP', 'DrMundo', 'JUNGLE', 'Graves', 'MIDDLE', 'Zac', 'BOTTOM', 'Sivir', 'UTILITY', 'Janna'], 'Blue']
# Matchs ajoutés : 6100
#
# Dernier match ajouté : [['MIDDLE', 'Vladimir', 'JUNGLE', 'Kindred', 'TOP', 'Fiora', 'BOTTOM', 'Ezreal', 'UTILITY', 'Taric'], ['TOP', 'Yasuo', 'JUNGLE', 'Rengar', 'MIDDLE', 'Ryze', 'BOTTOM', 'Jinx', 'UTILITY', 'Thresh'], 'Blue']
# Matchs ajoutés : 6100
#
# Dernier match ajouté : []
# Matchs ajoutés : 6100
#
# Dernier match ajouté : []
# Matchs ajoutés : 6100
#
# Dernier match ajouté : []
# Matchs ajoutés : 6200
#
# Dernier match ajouté : [['TOP', 'Poppy', 'JUNGLE', 'Ekko', 'MIDDLE', 'Veigar', 'BOTTOM', 'Nilah', 'UTILITY', 'Pyke'], ['TOP', 'Mordekaiser', 'JUNGLE', 'Skarner', 'MIDDLE', 'Tryndamere', 'BOTTOM', 'Draven', 'UTILITY', 'Thresh'], 'Red']
# Matchs ajoutés : 6300
#
# Dernier match ajouté : [['TOP', 'Yasuo', 'JUNGLE', 'Hecarim', 'MIDDLE', 'Ezreal', 'BOTTOM', 'Jinx', 'UTILITY', 'Senna'], ['TOP', 'Aatrox', 'JUNGLE', 'Khazix', 'MIDDLE', 'Draven', 'BOTTOM', 'Kalista', 'UTILITY', 'Alistar'], 'Red']
# Matchs ajoutés : 6400
#
# Dernier match ajouté : [['TOP', 'Garen', 'JUNGLE', 'Lillia', 'MIDDLE', 'Zed', 'BOTTOM', 'Ezreal', 'UTILITY', 'Yuumi'], ['TOP', 'Poppy', 'JUNGLE', 'Khazix', 'MIDDLE', 'Ekko', 'BOTTOM', 'Varus', 'UTILITY', 'Janna'], 'Blue']
# Matchs ajoutés : 6400
#
# Dernier match ajouté : []
# Matchs ajoutés : 6500
#
# Dernier match ajouté : [['TOP', 'Kennen', 'JUNGLE', 'Maokai', 'MIDDLE', 'Qiyana', 'BOTTOM', 'Draven', 'UTILITY', 'Blitzcrank'], ['TOP', 'Nasus', 'JUNGLE', 'FiddleSticks', 'MIDDLE', 'Neeko', 'BOTTOM', 'Ashe', 'UTILITY', 'Braum'], 'Red']
# Matchs ajoutés : 6500
#
# Dernier match ajouté : []
# Matchs ajoutés : 6500
#
# Dernier match ajouté : []
# Matchs ajoutés : 6600
#
# Dernier match ajouté : [['TOP', 'Irelia', 'JUNGLE', 'Nunu', 'MIDDLE', 'Zoe', 'BOTTOM', 'Vayne', 'UTILITY', 'Ashe'], ['TOP', 'Kennen', 'JUNGLE', 'Nocturne', 'MIDDLE', 'Yone', 'BOTTOM', 'Kaisa', 'UTILITY', 'Morgana'], 'Red']
# Matchs ajoutés : 6700
#
# Dernier match ajouté : [['TOP', 'Sett', 'JUNGLE', 'Sejuani', 'MIDDLE', 'Viktor', 'BOTTOM', 'Twitch', 'UTILITY', 'Lulu'], ['TOP', 'Mordekaiser', 'JUNGLE', 'Nunu', 'MIDDLE', 'Tristana', 'BOTTOM', 'Vayne', 'UTILITY', 'Thresh'], 'Red']
# Matchs ajoutés : 6800
#
# Dernier match ajouté : [['TOP', 'Illaoi', 'JUNGLE', 'Taliyah', 'MIDDLE', 'Anivia', 'BOTTOM', 'Kaisa', 'UTILITY', 'Nautilus'], ['TOP', 'Aatrox', 'JUNGLE', 'Poppy', 'MIDDLE', 'AurelionSol', 'BOTTOM', 'Ezreal', 'UTILITY', 'Swain'], 'Red']
# Matchs ajoutés : 6900
#
# Dernier match ajouté : [['TOP', 'Sion', 'JUNGLE', 'Kayn', 'MIDDLE', 'Ahri', 'BOTTOM', 'Ashe', 'UTILITY', 'Rell'], ['TOP', 'Zed', 'JUNGLE', 'Talon', 'MIDDLE', 'Annie', 'BOTTOM', 'Vayne', 'UTILITY', 'Janna'], 'Blue']
# Matchs ajoutés : 7000
#
# Dernier match ajouté : [['TOP', 'Kennen', 'JUNGLE', 'FiddleSticks', 'MIDDLE', 'Ezreal', 'BOTTOM', 'Xayah', 'UTILITY', 'Zilean'], ['TOP', 'Camille', 'JUNGLE', 'Kindred', 'MIDDLE', 'Rumble', 'BOTTOM', 'Ziggs', 'UTILITY', 'Rakan'], 'Red']
# Matchs ajoutés : 7000
#
# Dernier match ajouté : []
# Matchs ajoutés : 7100
#
# Dernier match ajouté : [['TOP', 'Yone', 'JUNGLE', 'Viego', 'MIDDLE', 'Syndra', 'BOTTOM', 'Kaisa', 'UTILITY', 'Nautilus'], ['TOP', 'Urgot', 'JUNGLE', 'Khazix', 'MIDDLE', 'Chogath', 'BOTTOM', 'Ashe', 'UTILITY', 'Velkoz'], 'Red']
# Matchs ajoutés : 7200
#
# Dernier match ajouté : [['MIDDLE', 'Jax', 'JUNGLE', 'RekSai', 'TOP', 'Garen', 'BOTTOM', 'Kaisa', 'UTILITY', 'Janna'], ['TOP', 'Camille', 'JUNGLE', 'Evelynn', 'MIDDLE', 'Vayne', 'BOTTOM', 'Draven', 'UTILITY', 'Thresh'], 'Red']
# Matchs ajoutés : 7200
#
# Dernier match ajouté : []
# Matchs ajoutés : 7300
#
# Dernier match ajouté : [['TOP', 'Gangplank', 'JUNGLE', 'Rengar', 'MIDDLE', 'Lissandra', 'BOTTOM', 'Ashe', 'UTILITY', 'Lux'], ['TOP', 'Warwick', 'JUNGLE', 'MasterYi', 'MIDDLE', 'TwistedFate', 'BOTTOM', 'KogMaw', 'UTILITY', 'Janna'], 'Blue']
# Matchs ajoutés : 7300
#
# Dernier match ajouté : []
# Matchs ajoutés : 7400
#
# Dernier match ajouté : [['TOP', 'Mordekaiser', 'JUNGLE', 'FiddleSticks', 'MIDDLE', 'Tristana', 'BOTTOM', 'Sivir', 'UTILITY', 'Senna'], ['TOP', 'Jayce', 'JUNGLE', 'Khazix', 'MIDDLE', 'Ziggs', 'BOTTOM', 'Aphelios', 'UTILITY', 'Rell'], 'Red']
# Matchs ajoutés : 7500
#
# Dernier match ajouté : [['TOP', 'Nasus', 'JUNGLE', 'Udyr', 'MIDDLE', 'Talon', 'BOTTOM', 'Vayne', 'UTILITY', 'Lulu'], ['TOP', 'Camille', 'JUNGLE', 'Khazix', 'MIDDLE', 'Ahri', 'BOTTOM', 'Xayah', 'UTILITY', 'Janna'], 'Blue']
# Matchs ajoutés : 7600
#
# Dernier match ajouté : [['TOP', 'Darius', 'JUNGLE', 'FiddleSticks', 'MIDDLE', 'Tristana', 'BOTTOM', 'Caitlyn', 'UTILITY', 'Thresh'], ['TOP', 'Kled', 'JUNGLE', 'Evelynn', 'MIDDLE', 'Graves', 'BOTTOM', 'Xayah', 'UTILITY', 'Velkoz'], 'Red']
# Matchs ajoutés : 7700
#
# Dernier match ajouté : [['TOP', 'Quinn', 'JUNGLE', 'Hecarim', 'MIDDLE', 'Ekko', 'UTILITY', 'Nautilus', 'BOTTOM', 'Aphelios'], ['TOP', 'Talon', 'JUNGLE', 'Elise', 'MIDDLE', 'Syndra', 'BOTTOM', 'Kalista', 'UTILITY', 'Karma'], 'Red']
# Matchs ajoutés : 7800
#
# Dernier match ajouté : [['TOP', 'Sion', 'JUNGLE', 'Hecarim', 'MIDDLE', 'Syndra', 'BOTTOM', 'Jhin', 'UTILITY', 'Senna'], ['TOP', 'Volibear', 'JUNGLE', 'Zed', 'MIDDLE', 'Akali', 'BOTTOM', 'Ashe', 'UTILITY', 'Janna'], 'Blue']
# Matchs ajoutés : 7900
#
# Dernier match ajouté : [['TOP', 'Sylas', 'JUNGLE', 'Rammus', 'MIDDLE', 'Jayce', 'BOTTOM', 'Karthus', 'UTILITY', 'Bard'], ['TOP', 'Malphite', 'JUNGLE', 'Graves', 'MIDDLE', 'Neeko', 'BOTTOM', 'Samira', 'UTILITY', 'Rell'], 'Red']
# Matchs ajoutés : 7900
#
# Dernier match ajouté : []
# Matchs ajoutés : 7900
#
# Dernier match ajouté : []
# Matchs ajoutés : 8000
#
# Dernier match ajouté : [['TOP', 'Illaoi', 'JUNGLE', 'Belveth', 'MIDDLE', 'Rumble', 'BOTTOM', 'Twitch', 'UTILITY', 'Alistar'], ['TOP', 'Aatrox', 'JUNGLE', 'Kayn', 'MIDDLE', 'Syndra', 'BOTTOM', 'Samira', 'UTILITY', 'Thresh'], 'Red']
# Matchs ajoutés : 8100
#
# Dernier match ajouté : [['TOP', 'Renekton', 'JUNGLE', 'JarvanIV', 'MIDDLE', 'Lissandra', 'BOTTOM', 'Ezreal', 'UTILITY', 'Alistar'], ['TOP', 'Kayn', 'JUNGLE', 'Singed', 'MIDDLE', 'Cassiopeia', 'BOTTOM', 'Samira', 'UTILITY', 'Janna'], 'Red']
# Matchs ajoutés : 8200
#
# Dernier match ajouté : [['TOP', 'Yone', 'JUNGLE', 'Khazix', 'MIDDLE', 'Chogath', 'BOTTOM', 'Lucian', 'UTILITY', 'Rell'], ['TOP', 'Aatrox', 'JUNGLE', 'Viego', 'MIDDLE', 'Lissandra', 'BOTTOM', 'Twitch', 'UTILITY', 'Pyke'], 'Blue']
# Matchs ajoutés : 8300
#
# Dernier match ajouté : [['TOP', 'Illaoi', 'JUNGLE', 'Taliyah', 'MIDDLE', 'Talon', 'BOTTOM', 'Xayah', 'UTILITY', 'Nautilus'], ['TOP', 'Pantheon', 'JUNGLE', 'MasterYi', 'MIDDLE', 'Anivia', 'BOTTOM', 'Sivir', 'UTILITY', 'Pyke'], 'Red']
# Matchs ajoutés : 8400
#
# Dernier match ajouté : [['TOP', 'Gragas', 'UTILITY', 'Nautilus', 'MIDDLE', 'Tristana', 'BOTTOM', 'Twitch', 'JUNGLE', 'Shaco'], ['TOP', 'Riven', 'JUNGLE', 'MasterYi', 'MIDDLE', 'Qiyana', 'JUNGLE', 'Karma', 'BOTTOM', 'Aphelios'], 'Blue']
# Matchs ajoutés : 8400
#
# Dernier match ajouté : []
# Matchs ajoutés : 8500
#
# Dernier match ajouté : [['TOP', 'Kayle', 'JUNGLE', 'Kindred', 'MIDDLE', 'Brand', 'BOTTOM', 'Ashe', 'UTILITY', 'Xerath'], ['TOP', 'Garen', 'JUNGLE', 'Graves', 'MIDDLE', 'Yone', 'BOTTOM', 'Xayah', 'JUNGLE', 'Amumu'], 'Blue']
# Matchs ajoutés : 8500
#
# Dernier match ajouté : []
# Matchs ajoutés : 8500
#
# Dernier match ajouté : []
# Matchs ajoutés : 8600
#
# Dernier match ajouté : [['TOP', 'Aatrox', 'JUNGLE', 'Ivern', 'MIDDLE', 'Viktor', 'BOTTOM', 'Ashe', 'UTILITY', 'Rell'], ['TOP', 'Malphite', 'JUNGLE', 'Naafiri', 'MIDDLE', 'Zoe', 'BOTTOM', 'Twitch', 'UTILITY', 'Milio'], 'Red']
# Matchs ajoutés : 8600
#
# Dernier match ajouté : []
# Matchs ajoutés : 8700
#
# Dernier match ajouté : [['TOP', 'KSante', 'JUNGLE', 'Ekko', 'MIDDLE', 'Zeri', 'BOTTOM', 'Kaisa', 'UTILITY', 'Thresh'], ['TOP', 'Vladimir', 'JUNGLE', 'Graves', 'MIDDLE', 'Azir', 'BOTTOM', 'Draven', 'UTILITY', 'Blitzcrank'], 'Blue']
# Matchs ajoutés : 8800
#
# Dernier match ajouté : [['TOP', 'Fiora', 'JUNGLE', 'Zac', 'MIDDLE', 'Kassadin', 'BOTTOM', 'Vayne', 'UTILITY', 'Yuumi'], ['TOP', 'Varus', 'JUNGLE', 'Khazix', 'MIDDLE', 'Akali', 'BOTTOM', 'Kalista', 'UTILITY', 'Rell'], 'Blue']
# Matchs ajoutés : 8800
#
# Dernier match ajouté : []
# Matchs ajoutés : 8800
#
# Dernier match ajouté : []
# Matchs ajoutés : 8800
#
# Dernier match ajouté : []
# Matchs ajoutés : 8800
#
# Dernier match ajouté : []
# Matchs ajoutés : 8800
#
# Dernier match ajouté : []
# Matchs ajoutés : 8800
#
# Dernier match ajouté : []
# Matchs ajoutés : 8900
#
# Dernier match ajouté : [['TOP', 'Gragas', 'JUNGLE', 'Zac', 'MIDDLE', 'Quinn', 'BOTTOM', 'Jhin', 'UTILITY', 'Zilean'], ['TOP', 'Poppy', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Syndra', 'BOTTOM', 'Ezreal', 'UTILITY', 'Janna'], 'Red']
# Matchs ajoutés : 9000
#
# Dernier match ajouté : [['TOP', 'Camille', 'JUNGLE', 'RekSai', 'MIDDLE', 'Talon', 'BOTTOM', 'Seraphine', 'UTILITY', 'Lux'], ['TOP', 'Jax', 'JUNGLE', 'Shaco', 'MIDDLE', 'Orianna', 'BOTTOM', 'Aphelios', 'UTILITY', 'Sona'], 'Blue']
# Matchs ajoutés : 9100
#
# Dernier match ajouté : [['TOP', 'Jax', 'JUNGLE', 'JarvanIV', 'MIDDLE', 'Malzahar', 'BOTTOM', 'Kaisa', 'UTILITY', 'Leona'], ['TOP', 'Irelia', 'JUNGLE', 'FiddleSticks', 'MIDDLE', 'Yone', 'BOTTOM', 'Karthus', 'UTILITY', 'Blitzcrank'], 'Red']
# Matchs ajoutés : 9100
#
# Dernier match ajouté : []
# Matchs ajoutés : 9100
#
# Dernier match ajouté : []
# Matchs ajoutés : 9100
#
# Dernier match ajouté : []
# Matchs ajoutés : 9100
#
# Dernier match ajouté : []
# Matchs ajoutés : 9100
#
# Dernier match ajouté : []
# Matchs ajoutés : 9100
#
# Dernier match ajouté : []
# Matchs ajoutés : 9100
#
# Dernier match ajouté : []
# Matchs ajoutés : 9200
#
# Dernier match ajouté : [['TOP', 'Urgot', 'JUNGLE', 'Nunu', 'MIDDLE', 'Zed', 'BOTTOM', 'KogMaw', 'UTILITY', 'Lulu'], ['TOP', 'Illaoi', 'JUNGLE', 'Kayn', 'MIDDLE', 'Azir', 'BOTTOM', 'Aphelios', 'UTILITY', 'Milio'], 'Red']
# Matchs ajoutés : 9300
#
# Dernier match ajouté : [['TOP', 'Yone', 'JUNGLE', 'Sejuani', 'MIDDLE', 'Kassadin', 'BOTTOM', 'Ezreal', 'UTILITY', 'Rakan'], ['TOP', 'Yasuo', 'JUNGLE', 'Khazix', 'MIDDLE', 'Katarina', 'BOTTOM', 'Tristana', 'UTILITY', 'Thresh'], 'Red']
# Matchs ajoutés : 9400
#
# Dernier match ajouté : [['TOP', 'Poppy', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Kennen', 'BOTTOM', 'Nilah', 'UTILITY', 'Alistar'], ['TOP', 'Camille', 'JUNGLE', 'Ivern', 'MIDDLE', 'Katarina', 'BOTTOM', 'Samira', 'UTILITY', 'Janna'], 'Blue']
# Matchs ajoutés : 9400
#
# Dernier match ajouté : []
# Matchs ajoutés : 9400
#
# Dernier match ajouté : []
# Matchs ajoutés : 9500
#
# Dernier match ajouté : [['TOP', 'Camille', 'JUNGLE', 'Ivern', 'MIDDLE', 'Velkoz', 'BOTTOM', 'Twitch', 'UTILITY', 'Alistar'], ['TOP', 'Pantheon', 'JUNGLE', 'Warwick', 'MIDDLE', 'Xerath', 'BOTTOM', 'Samira', 'UTILITY', 'Nautilus'], 'Blue']
# Matchs ajoutés : 9600
#
# Dernier match ajouté : [['TOP', 'Aatrox', 'JUNGLE', 'Kindred', 'MIDDLE', 'Leblanc', 'BOTTOM', 'Ashe', 'UTILITY', 'Sona'], ['TOP', 'Yone', 'JUNGLE', 'Khazix', 'MIDDLE', 'Syndra', 'BOTTOM', 'Caitlyn', 'UTILITY', 'Karma'], 'Blue']
# Matchs ajoutés : 9700
#
# Dernier match ajouté : [['TOP', 'Camille', 'JUNGLE', 'Kayn', 'MIDDLE', 'Xerath', 'BOTTOM', 'Jinx', 'UTILITY', 'Annie'], ['TOP', 'Riven', 'JUNGLE', 'Shyvana', 'MIDDLE', 'Syndra', 'BOTTOM', 'Caitlyn', 'UTILITY', 'Lux'], 'Blue']
# Matchs ajoutés : 9800
#
# Dernier match ajouté : [['TOP', 'Camille', 'JUNGLE', 'Karthus', 'MIDDLE', 'Jayce', 'BOTTOM', 'Ashe', 'UTILITY', 'Nautilus'], ['TOP', 'Riven', 'JUNGLE', 'Khazix', 'MIDDLE', 'AurelionSol', 'BOTTOM', 'Ezreal', 'UTILITY', 'Bard'], 'Blue']
# Matchs ajoutés : 9900
#
# Dernier match ajouté : [['TOP', 'Yorick', 'JUNGLE', 'Khazix', 'MIDDLE', 'Sylas', 'BOTTOM', 'Tristana', 'UTILITY', 'Lulu'], ['TOP', 'Vladimir', 'MIDDLE', 'Yone', 'JUNGLE', 'FiddleSticks', 'BOTTOM', 'Xayah', 'UTILITY', 'Nidalee'], 'Blue']
# Matchs ajoutés : 9900
#
# Dernier match ajouté : []
# Matchs ajoutés : 10000
#
# Dernier match ajouté : [['TOP', 'Renekton', 'JUNGLE', 'Vi', 'BOTTOM', 'Xayah', 'MIDDLE', 'Zoe', 'UTILITY', 'Lux'], ['TOP', 'Illaoi', 'JUNGLE', 'Ekko', 'MIDDLE', 'Syndra', 'BOTTOM', 'Draven', 'UTILITY', 'Sona'], 'Red']
# Matchs ajoutés : 10000
#
# Dernier match ajouté : []
# Matchs ajoutés : 10100
#
# Dernier match ajouté : [['TOP', 'Jhin', 'JUNGLE', 'Nocturne', 'MIDDLE', 'Ziggs', 'BOTTOM', 'Ezreal', 'UTILITY', 'Yuumi'], ['TOP', 'Camille', 'JUNGLE', 'Kindred', 'MIDDLE', 'Yasuo', 'BOTTOM', 'Karthus', 'UTILITY', 'Nami'], 'Red']
# Matchs ajoutés : 10100
#
# Dernier match ajouté : []
# Matchs ajoutés : 10100
#
# Dernier match ajouté : []
# Matchs ajoutés : 10200
#
# Dernier match ajouté : [['TOP', 'Poppy', 'JUNGLE', 'Zac', 'MIDDLE', 'Talon', 'BOTTOM', 'Kaisa', 'UTILITY', 'Rakan'], ['TOP', 'Riven', 'JUNGLE', 'Nidalee', 'MIDDLE', 'Yone', 'BOTTOM', 'Xayah', 'UTILITY', 'Karma'], 'Red']
# Matchs ajoutés : 10300
#
# Dernier match ajouté : [['TOP', 'Camille', 'JUNGLE', 'Gragas', 'MIDDLE', 'Kassadin', 'BOTTOM', 'Kaisa', 'UTILITY', 'Rakan'], ['TOP', 'Renekton', 'JUNGLE', 'Elise', 'MIDDLE', 'Syndra', 'BOTTOM', 'Xayah', 'UTILITY', 'Nautilus'], 'Red']
# Matchs ajoutés : 10300
#
# Dernier match ajouté : []
# Matchs ajoutés : 10300
#
# Dernier match ajouté : []
# Matchs ajoutés : 10300
#
# Dernier match ajouté : []
# Matchs ajoutés : 10300
#
# Dernier match ajouté : []
# Matchs ajoutés : 10300
#
# Dernier match ajouté : []
# Matchs ajoutés : 10300
#
# Dernier match ajouté : []
# Matchs ajoutés : 10300
#
# Dernier match ajouté : []
# Matchs ajoutés : 10400
#
# Dernier match ajouté : [['TOP', 'Kayle', 'JUNGLE', 'RekSai', 'MIDDLE', 'Galio', 'BOTTOM', 'Jhin', 'UTILITY', 'Rell'], ['TOP', 'Darius', 'JUNGLE', 'Viego', 'MIDDLE', 'Naafiri', 'BOTTOM', 'Seraphine', 'UTILITY', 'Blitzcrank'], 'Blue']
# Matchs ajoutés : 10400
#
# Dernier match ajouté : []
# Matchs ajoutés : 10500
#
# Dernier match ajouté : [['TOP', 'Tryndamere', 'JUNGLE', 'Sylas', 'MIDDLE', 'Ziggs', 'BOTTOM', 'Twitch', 'UTILITY', 'Lulu'], ['TOP', 'Malphite', 'JUNGLE', 'Graves', 'MIDDLE', 'Kassadin', 'BOTTOM', 'Kaisa', 'UTILITY', 'Belveth'], 'Blue']
# Matchs ajoutés : 10500
#
# Dernier match ajouté : []
# Matchs ajoutés : 10600
#
# Dernier match ajouté : [['TOP', 'Yone', 'JUNGLE', 'RekSai', 'MIDDLE', 'Galio', 'BOTTOM', 'Draven', 'UTILITY', 'Karma'], ['TOP', 'Camille', 'JUNGLE', 'Gragas', 'MIDDLE', 'Ahri', 'BOTTOM', 'Lucian', 'UTILITY', 'Milio'], 'Blue']
# Matchs ajoutés : 10700
#
# Dernier match ajouté : [['TOP', 'Sett', 'JUNGLE', 'Talon', 'MIDDLE', 'Syndra', 'BOTTOM', 'Kaisa', 'UTILITY', 'Neeko'], ['TOP', 'Renekton', 'JUNGLE', 'Hecarim', 'MIDDLE', 'Akali', 'BOTTOM', 'Ashe', 'UTILITY', 'Rakan'], 'Blue']
# Matchs ajoutés : 10700
#
# Dernier match ajouté : []
# Matchs ajoutés : 10800
#
# Dernier match ajouté : [['TOP', 'Akshan', 'JUNGLE', 'Maokai', 'MIDDLE', 'Zyra', 'BOTTOM', 'Xayah', 'UTILITY', 'Thresh'], ['TOP', 'Camille', 'JUNGLE', 'Khazix', 'MIDDLE', 'Leblanc', 'BOTTOM', 'Ziggs', 'JUNGLE', 'Karma'], 'Blue']
# Matchs ajoutés : 10900
#
# Dernier match ajouté : [['TOP', 'Gangplank', 'JUNGLE', 'Zac', 'MIDDLE', 'Katarina', 'BOTTOM', 'Ashe', 'UTILITY', 'Zyra'], ['TOP', 'Jax', 'JUNGLE', 'Talon', 'MIDDLE', 'Kassadin', 'BOTTOM', 'Draven', 'UTILITY', 'Taric'], 'Blue']
# Matchs ajoutés : 11000
#
# Dernier match ajouté : [['TOP', 'Shen', 'JUNGLE', 'Amumu', 'MIDDLE', 'Kled', 'BOTTOM', 'Xayah', 'UTILITY', 'Janna'], ['TOP', 'Fiora', 'JUNGLE', 'Maokai', 'MIDDLE', 'Syndra', 'BOTTOM', 'Ezreal', 'UTILITY', 'Nautilus'], 'Blue']
# Matchs ajoutés : 11100
#
# Dernier match ajouté : [['TOP', 'Malphite', 'JUNGLE', 'Neeko', 'MIDDLE', 'Yasuo', 'BOTTOM', 'Caitlyn', 'UTILITY', 'Karma'], ['TOP', 'Gnar', 'JUNGLE', 'Nocturne', 'MIDDLE', 'Viktor', 'BOTTOM', 'Zeri', 'UTILITY', 'Rakan'], 'Red']
# Matchs ajoutés : 11200
#
# Dernier match ajouté : [['TOP', 'KSante', 'JUNGLE', 'FiddleSticks', 'MIDDLE', 'Leblanc', 'BOTTOM', 'Tristana', 'UTILITY', 'Nautilus'], ['TOP', 'Aatrox', 'JUNGLE', 'Kayn', 'MIDDLE', 'Talon', 'BOTTOM', 'Xayah', 'UTILITY', 'Velkoz'], 'Blue']
# Matchs ajoutés : 11200
#
# Dernier match ajouté : []
# Matchs ajoutés : 11300
#
# Dernier match ajouté : [['TOP', 'Shen', 'JUNGLE', 'Viego', 'MIDDLE', 'Annie', 'BOTTOM', 'Samira', 'UTILITY', 'Alistar'], ['TOP', 'Fiora', 'JUNGLE', 'Sylas', 'MIDDLE', 'Vladimir', 'BOTTOM', 'Kaisa', 'UTILITY', 'Renata'], 'Blue']
# Matchs ajoutés : 11400
#
# Dernier match ajouté : [['TOP', 'Darius', 'JUNGLE', 'Nunu', 'MIDDLE', 'Anivia', 'BOTTOM', 'Draven', 'UTILITY', 'Swain'], ['TOP', 'Renekton', 'JUNGLE', 'Maokai', 'MIDDLE', 'Leblanc', 'BOTTOM', 'Ashe', 'UTILITY', 'Xerath'], 'Blue']
# Matchs ajoutés : 11400
#
# Dernier match ajouté : []
# Matchs ajoutés : 11400
#
# Dernier match ajouté : []
# Matchs ajoutés : 11500
#
# Dernier match ajouté : [['TOP', 'Singed', 'JUNGLE', 'MasterYi', 'MIDDLE', 'Diana', 'BOTTOM', 'Ashe', 'UTILITY', 'Amumu'], ['TOP', 'Shyvana', 'JUNGLE', 'Evelynn', 'MIDDLE', 'Irelia', 'BOTTOM', 'Nilah', 'UTILITY', 'Braum'], 'Red']
# Matchs ajoutés : 11600
#
# Dernier match ajouté : [['TOP', 'Aatrox', 'JUNGLE', 'Kayn', 'MIDDLE', 'Seraphine', 'BOTTOM', 'Samira', 'UTILITY', 'Soraka'], ['TOP', 'Fiora', 'JUNGLE', 'Shaco', 'MIDDLE', 'Jayce', 'BOTTOM', 'Kaisa', 'UTILITY', 'Sona'], 'Red']
# Matchs ajoutés : 11700
#
# Dernier match ajouté : [['TOP', 'Teemo', 'JUNGLE', 'Ivern', 'MIDDLE', 'Gwen', 'BOTTOM', 'Twitch', 'UTILITY', 'Senna'], ['TOP', 'Kled', 'JUNGLE', 'Diana', 'MIDDLE', 'Velkoz', 'BOTTOM', 'Kaisa', 'UTILITY', 'Rammus'], 'Blue']
# Matchs ajoutés : 11800
#
# Dernier match ajouté : [['TOP', 'Jax', 'JUNGLE', 'Maokai', 'MIDDLE', 'Vladimir', 'BOTTOM', 'Samira', 'UTILITY', 'Rell'], ['TOP', 'Olaf', 'JUNGLE', 'Hecarim', 'MIDDLE', 'Viktor', 'BOTTOM', 'Ashe', 'UTILITY', 'Leona'], 'Blue']
# Matchs ajoutés : 11900
#
# Dernier match ajouté : [['TOP', 'Renekton', 'JUNGLE', 'RekSai', 'MIDDLE', 'Ahri', 'BOTTOM', 'Samira', 'UTILITY', 'Rell'], ['TOP', 'Illaoi', 'JUNGLE', 'JarvanIV', 'MIDDLE', 'Pantheon', 'BOTTOM', 'Karthus', 'UTILITY', 'Alistar'], 'Blue']
# Matchs ajoutés : 12000
#
# Dernier match ajouté : [['UTILITY', 'Pyke', 'JUNGLE', 'Talon', 'MIDDLE', 'Kaisa', 'BOTTOM', 'Lucian', 'TOP', 'Ornn'], ['TOP', 'Vladimir', 'JUNGLE', 'Rammus', 'MIDDLE', 'Akali', 'BOTTOM', 'Twitch', 'UTILITY', 'Lulu'], 'Blue']
# Matchs ajoutés : 12100
#
# Dernier match ajouté : [['TOP', 'Darius', 'JUNGLE', 'RekSai', 'MIDDLE', 'TwistedFate', 'BOTTOM', 'Ezreal', 'UTILITY', 'Janna'], ['TOP', 'Renekton', 'JUNGLE', 'Shyvana', 'MIDDLE', 'Taliyah', 'BOTTOM', 'MissFortune', 'UTILITY', 'Rell'], 'Blue']
# Matchs ajoutés : 12200
#
# Dernier match ajouté : [['TOP', 'Rumble', 'JUNGLE', 'Graves', 'MIDDLE', 'Zed', 'BOTTOM', 'Kaisa', 'UTILITY', 'Rakan'], ['TOP', 'Irelia', 'JUNGLE', 'Viego', 'MIDDLE', 'Karthus', 'BOTTOM', 'Xayah', 'UTILITY', 'Zac'], 'Red']
# Matchs ajoutés : 12300
#
# Dernier match ajouté : [['TOP', 'Naafiri', 'JUNGLE', 'Hecarim', 'MIDDLE', 'Neeko', 'BOTTOM', 'Karthus', 'UTILITY', 'Nautilus'], ['TOP', 'Renekton', 'JUNGLE', 'Diana', 'MIDDLE', 'Tristana', 'BOTTOM', 'Syndra', 'UTILITY', 'Rakan'], 'Red']
# Matchs ajoutés : 12300
#
# Dernier match ajouté : []
# Matchs ajoutés : 12400
#
# Dernier match ajouté : [['TOP', 'Fiora', 'JUNGLE', 'Nidalee', 'MIDDLE', 'Zed', 'BOTTOM', 'Draven', 'UTILITY', 'Thresh'], ['TOP', 'KSante', 'JUNGLE', 'Hecarim', 'MIDDLE', 'Lissandra', 'BOTTOM', 'Caitlyn', 'UTILITY', 'Zilean'], 'Red']
# Matchs ajoutés : 12400
#
# Dernier match ajouté : []
# Matchs ajoutés : 12500
#
# Dernier match ajouté : [['TOP', 'Riven', 'JUNGLE', 'JarvanIV', 'MIDDLE', 'AurelionSol', 'BOTTOM', 'Akshan', 'UTILITY', 'Nami'], ['TOP', 'Kennen', 'JUNGLE', 'Kindred', 'MIDDLE', 'Zed', 'BOTTOM', 'MissFortune', 'UTILITY', 'Thresh'], 'Red']
# Matchs ajoutés : 12500
#
# Dernier match ajouté : []
# Matchs ajoutés : 12600
#
# Dernier match ajouté : [['TOP', 'Fiora', 'JUNGLE', 'XinZhao', 'MIDDLE', 'Ahri', 'BOTTOM', 'Kaisa', 'UTILITY', 'Rakan'], ['TOP', 'Riven', 'JUNGLE', 'Nidalee', 'MIDDLE', 'Akshan', 'BOTTOM', 'Xayah', 'UTILITY', 'Nautilus'], 'Red']
# Matchs ajoutés : 12700
#
# Dernier match ajouté : [['TOP', 'Illaoi', 'JUNGLE', 'Rumble', 'MIDDLE', 'Irelia', 'BOTTOM', 'Aphelios', 'UTILITY', 'Leona'], ['TOP', 'Urgot', 'JUNGLE', 'RekSai', 'MIDDLE', 'Malzahar', 'BOTTOM', 'Ashe', 'UTILITY', 'Bard'], 'Blue']
# Matchs ajoutés : 12800
#
# Dernier match ajouté : [['BOTTOM', 'Xayah', 'JUNGLE', 'Belveth', 'MIDDLE', 'Naafiri', 'TOP', 'Fiora', 'UTILITY', 'Maokai'], ['TOP', 'Riven', 'JUNGLE', 'Nidalee', 'MIDDLE', 'Irelia', 'BOTTOM', 'Caitlyn', 'UTILITY', 'Lux'], 'Red']
# Matchs ajoutés : 12800
#
# Dernier match ajouté : []
# Matchs ajoutés : 12800
#
# Dernier match ajouté : []
# Matchs ajoutés : 12800
#
# Dernier match ajouté : []
# Matchs ajoutés : 12800
#
# Dernier match ajouté : []
# Matchs ajoutés : 12800
#
# Dernier match ajouté : []
# Matchs ajoutés : 12900
#
# Dernier match ajouté : [['TOP', 'Volibear', 'JUNGLE', 'RekSai', 'MIDDLE', 'Ekko', 'BOTTOM', 'Draven', 'UTILITY', 'Janna'], ['TOP', 'Camille', 'JUNGLE', 'Khazix', 'MIDDLE', 'Taliyah', 'BOTTOM', 'Xayah', 'UTILITY', 'Nautilus'], 'Blue']
# Matchs ajoutés : 13000
#
# Dernier match ajouté : [['TOP', 'Ornn', 'JUNGLE', 'Hecarim', 'MIDDLE', 'Katarina', 'BOTTOM', 'Yasuo', 'UTILITY', 'Nautilus'], ['TOP', 'Sion', 'JUNGLE', 'Shaco', 'MIDDLE', 'Lux', 'BOTTOM', 'Kaisa', 'UTILITY', 'Rell'], 'Blue']
# Matchs ajoutés : 13100
#
# Dernier match ajouté : [['TOP', 'Darius', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Kassadin', 'BOTTOM', 'Ashe', 'UTILITY', 'Soraka'], ['TOP', 'Tryndamere', 'JUNGLE', 'Naafiri', 'MIDDLE', 'Irelia', 'BOTTOM', 'Xayah', 'UTILITY', 'Velkoz'], 'Blue']
# Matchs ajoutés : 13200
#
# Dernier match ajouté : [['TOP', 'Gragas', 'JUNGLE', 'Shaco', 'MIDDLE', 'Zed', 'BOTTOM', 'Samira', 'UTILITY', 'Rakan'], ['TOP', 'Garen', 'JUNGLE', 'Khazix', 'MIDDLE', 'Leblanc', 'BOTTOM', 'Kaisa', 'UTILITY', 'Alistar'], 'Red']
# Matchs ajoutés : 13300
#
# Dernier match ajouté : [['TOP', 'KSante', 'JUNGLE', 'Udyr', 'MIDDLE', 'Tristana', 'BOTTOM', 'Swain', 'UTILITY', 'Rell'], ['TOP', 'Maokai', 'JUNGLE', 'Kayn', 'MIDDLE', 'Diana', 'BOTTOM', 'Lucian', 'UTILITY', 'Braum'], 'Blue']
# Matchs ajoutés : 13300
#
# Dernier match ajouté : []
# Matchs ajoutés : 13300
#
# Dernier match ajouté : []
# Matchs ajoutés : 13300
#
# Dernier match ajouté : []
# Matchs ajoutés : 13300
#
# Dernier match ajouté : []
# Matchs ajoutés : 13300
#
# Dernier match ajouté : []
# Matchs ajoutés : 13300
#
# Dernier match ajouté : []
# Matchs ajoutés : 13300
#
# Dernier match ajouté : []
# Matchs ajoutés : 13300
#
# Dernier match ajouté : []
# Matchs ajoutés : 13400
#
# Dernier match ajouté : [['TOP', 'Garen', 'JUNGLE', 'Vi', 'MIDDLE', 'Viktor', 'BOTTOM', 'Kaisa', 'UTILITY', 'Janna'], ['TOP', 'Jax', 'JUNGLE', 'RekSai', 'MIDDLE', 'Irelia', 'BOTTOM', 'Varus', 'UTILITY', 'Rell'], 'Blue']
# Matchs ajoutés : 13400
#
# Dernier match ajouté : []
# Matchs ajoutés : 13500
#
# Dernier match ajouté : [['TOP', 'Camille', 'JUNGLE', 'JarvanIV', 'MIDDLE', 'Ahri', 'BOTTOM', 'Draven', 'UTILITY', 'Pyke'], ['TOP', 'Illaoi', 'JUNGLE', 'Kindred', 'MIDDLE', 'Syndra', 'BOTTOM', 'Lucian', 'UTILITY', 'Maokai'], 'Blue']
# Matchs ajoutés : 13500
#
# Dernier match ajouté : []
# Matchs ajoutés : 13600
#
# Dernier match ajouté : [['TOP', 'Camille', 'JUNGLE', 'Nunu', 'MIDDLE', 'Nasus', 'BOTTOM', 'Kaisa', 'UTILITY', 'Pyke'], ['TOP', 'Riven', 'JUNGLE', 'Graves', 'MIDDLE', 'Xerath', 'BOTTOM', 'Xayah', 'UTILITY', 'Ashe'], 'Red']
# Matchs ajoutés : 13600
#
# Dernier match ajouté : []
# Matchs ajoutés : 13700
#
# Dernier match ajouté : [['TOP', 'Pantheon', 'JUNGLE', 'Khazix', 'MIDDLE', 'Xerath', 'BOTTOM', 'Kaisa', 'UTILITY', 'Rakan'], ['TOP', 'Akshan', 'JUNGLE', 'JarvanIV', 'MIDDLE', 'Ahri', 'BOTTOM', 'Varus', 'UTILITY', 'Rell'], 'Blue']
# Matchs ajoutés : 13800
#
# Dernier match ajouté : [['TOP', 'Mordekaiser', 'JUNGLE', 'JarvanIV', 'MIDDLE', 'Qiyana', 'BOTTOM', 'Ashe', 'UTILITY', 'Xerath'], ['TOP', 'Varus', 'JUNGLE', 'MasterYi', 'MIDDLE', 'Vex', 'BOTTOM', 'Kaisa', 'UTILITY', 'Rell'], 'Red']
# Matchs ajoutés : 13900
#
# Dernier match ajouté : [['TOP', 'Gwen', 'JUNGLE', 'Ivern', 'MIDDLE', 'Talon', 'BOTTOM', 'Kaisa', 'UTILITY', 'Rell'], ['TOP', 'Riven', 'JUNGLE', 'Viego', 'MIDDLE', 'Twitch', 'BOTTOM', 'Jhin', 'UTILITY', 'Xerath'], 'Blue']
# Matchs ajoutés : 14000
#
# Dernier match ajouté : [['TOP', 'Malphite', 'JUNGLE', 'XinZhao', 'MIDDLE', 'Ahri', 'BOTTOM', 'Draven', 'UTILITY', 'Nautilus'], ['TOP', 'Aatrox', 'JUNGLE', 'RekSai', 'MIDDLE', 'Lux', 'BOTTOM', 'Kaisa', 'UTILITY', 'Rakan'], 'Blue']
# Matchs ajoutés : 14100
#
# Dernier match ajouté : [['TOP', 'Camille', 'JUNGLE', 'RekSai', 'MIDDLE', 'Ahri', 'BOTTOM', 'Kaisa', 'UTILITY', 'Thresh'], ['TOP', 'Aatrox', 'JUNGLE', 'Taliyah', 'MIDDLE', 'Leblanc', 'BOTTOM', 'Ezreal', 'UTILITY', 'Zyra'], 'Red']
# Matchs ajoutés : 14100
#
# Dernier match ajouté : []
# Matchs ajoutés : 14100
#
# Dernier match ajouté : []
# Matchs ajoutés : 14100
#
# Dernier match ajouté : []
# Matchs ajoutés : 14200
#
# Dernier match ajouté : [['TOP', 'Mordekaiser', 'JUNGLE', 'Rengar', 'MIDDLE', 'Nasus', 'BOTTOM', 'Lucian', 'UTILITY', 'Thresh'], ['TOP', 'Rumble', 'JUNGLE', 'JarvanIV', 'BOTTOM', 'Ezreal', 'MIDDLE', 'Irelia', 'UTILITY', 'Nautilus'], 'Blue']
# Matchs ajoutés : 14300
#
# Dernier match ajouté : [['TOP', 'Garen', 'JUNGLE', 'Lillia', 'MIDDLE', 'Talon', 'BOTTOM', 'Samira', 'UTILITY', 'Rakan'], ['TOP', 'Darius', 'JUNGLE', 'Ekko', 'MIDDLE', 'Viego', 'BOTTOM', 'Aphelios', 'UTILITY', 'Thresh'], 'Red']
# Matchs ajoutés : 14400
#
# Dernier match ajouté : [['TOP', 'Poppy', 'JUNGLE', 'Lillia', 'MIDDLE', 'Jayce', 'BOTTOM', 'Ezreal', 'UTILITY', 'Thresh'], ['TOP', 'Riven', 'JUNGLE', 'Gragas', 'MIDDLE', 'Fizz', 'BOTTOM', 'Tristana', 'UTILITY', 'Rell'], 'Blue']
# Matchs ajoutés : 14400
#
# Dernier match ajouté : []
# Matchs ajoutés : 14500
#
# Dernier match ajouté : [['TOP', 'Yorick', 'JUNGLE', 'Khazix', 'MIDDLE', 'Xerath', 'BOTTOM', 'Ashe', 'UTILITY', 'Rakan'], ['TOP', 'Ornn', 'JUNGLE', 'Volibear', 'MIDDLE', 'AurelionSol', 'BOTTOM', 'Karthus', 'UTILITY', 'Senna'], 'Blue']
# Matchs ajoutés : 14600
#
# Dernier match ajouté : [['TOP', 'Shen', 'JUNGLE', 'Hecarim', 'MIDDLE', 'Fizz', 'BOTTOM', 'Twitch', 'UTILITY', 'Rell'], ['TOP', 'Kayle', 'JUNGLE', 'JarvanIV', 'MIDDLE', 'Ezreal', 'BOTTOM', 'Draven', 'UTILITY', 'Pyke'], 'Blue']
# Matchs ajoutés : 14600
#
# Dernier match ajouté : []
# Matchs ajoutés : 14700
#
# Dernier match ajouté : [['TOP', 'Jayce', 'JUNGLE', 'Rengar', 'MIDDLE', 'Azir', 'BOTTOM', 'Twitch', 'UTILITY', 'Janna'], ['TOP', 'Sion', 'JUNGLE', 'Rell', 'MIDDLE', 'Qiyana', 'BOTTOM', 'Ashe', 'UTILITY', 'Rakan'], 'Red']
# Matchs ajoutés : 14800
#
# Dernier match ajouté : [['TOP', 'Darius', 'JUNGLE', 'Udyr', 'UTILITY', 'Leona', 'BOTTOM', 'Xayah', 'MIDDLE', 'Zoe'], ['TOP', 'Akshan', 'JUNGLE', 'RekSai', 'MIDDLE', 'Galio', 'BOTTOM', 'Samira', 'UTILITY', 'Nautilus'], 'Red']
# Matchs ajoutés : 14900
#
# Dernier match ajouté : [['TOP', 'Jayce', 'JUNGLE', 'Nidalee', 'MIDDLE', 'Leblanc', 'BOTTOM', 'Ashe', 'UTILITY', 'Belveth'], ['TOP', 'Sett', 'JUNGLE', 'RekSai', 'MIDDLE', 'Lissandra', 'BOTTOM', 'Kaisa', 'UTILITY', 'Janna'], 'Red']
# Matchs ajoutés : 14900
#
# Dernier match ajouté : []
# Matchs ajoutés : 15000
#
# Dernier match ajouté : [['TOP', 'Malphite', 'JUNGLE', 'Graves', 'MIDDLE', 'Azir', 'BOTTOM', 'Ezreal', 'UTILITY', 'Xerath'], ['TOP', 'Kalista', 'JUNGLE', 'Sejuani', 'MIDDLE', 'Katarina', 'BOTTOM', 'Jhin', 'UTILITY', 'Blitzcrank'], 'Blue']
# Matchs ajoutés : 15100
#
# Dernier match ajouté : [['TOP', 'Riven', 'JUNGLE', 'Taliyah', 'MIDDLE', 'Yone', 'BOTTOM', 'MissFortune', 'UTILITY', 'Pyke'], ['TOP', 'Warwick', 'JUNGLE', 'Karthus', 'MIDDLE', 'Qiyana', 'BOTTOM', 'Sivir', 'UTILITY', 'Rakan'], 'Blue']
# Matchs ajoutés : 15200
#
# Dernier match ajouté : [['TOP', 'Singed', 'JUNGLE', 'Nocturne', 'MIDDLE', 'Tristana', 'BOTTOM', 'Zeri', 'UTILITY', 'Nautilus'], ['TOP', 'Jayce', 'JUNGLE', 'Karthus', 'MIDDLE', 'Yone', 'BOTTOM', 'Kalista', 'UTILITY', 'Blitzcrank'], 'Red']
# Matchs ajoutés : 15200
#
# Dernier match ajouté : []
# Matchs ajoutés : 15300
#
# Dernier match ajouté : [['TOP', 'Sion', 'JUNGLE', 'Maokai', 'MIDDLE', 'Taliyah', 'BOTTOM', 'Ezreal', 'UTILITY', 'Sona'], ['TOP', 'Aatrox', 'JUNGLE', 'Ivern', 'MIDDLE', 'Neeko', 'BOTTOM', 'Twitch', 'UTILITY', 'Thresh'], 'Blue']
# Matchs ajoutés : 15300
#
# Dernier match ajouté : []
# Matchs ajoutés : 15400
#
# Dernier match ajouté : [['TOP', 'Aatrox', 'JUNGLE', 'FiddleSticks', 'MIDDLE', 'Kayle', 'BOTTOM', 'MissFortune', 'UTILITY', 'Zilean'], ['TOP', 'Jayce', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Kassadin', 'BOTTOM', 'Kaisa', 'UTILITY', 'Thresh'], 'Blue']
# Matchs ajoutés : 15500
#
# Dernier match ajouté : [['TOP', 'Aatrox', 'JUNGLE', 'Graves', 'MIDDLE', 'Nasus', 'BOTTOM', 'Xayah', 'UTILITY', 'Rakan'], ['TOP', 'Malphite', 'JUNGLE', 'Talon', 'MIDDLE', 'Fizz', 'BOTTOM', 'Lucian', 'UTILITY', 'Nami'], 'Red']
# Matchs ajoutés : 15600
#
# Dernier match ajouté : [['TOP', 'Qiyana', 'JUNGLE', 'Udyr', 'MIDDLE', 'Galio', 'BOTTOM', 'Jinx', 'UTILITY', 'Nautilus'], ['TOP', 'KSante', 'JUNGLE', 'Kindred', 'MIDDLE', 'AurelionSol', 'BOTTOM', 'Nilah', 'UTILITY', 'Bard'], 'Blue']
# Matchs ajoutés : 15700
#
# Dernier match ajouté : [['TOP', 'Yone', 'JUNGLE', 'Talon', 'MIDDLE', 'Ahri', 'BOTTOM', 'Ashe', 'UTILITY', 'Zilean'], ['TOP', 'Rumble', 'JUNGLE', 'Hecarim', 'MIDDLE', 'Lucian', 'BOTTOM', 'Tristana', 'UTILITY', 'Taric'], 'Blue']
# Matchs ajoutés : 15800
#
# Dernier match ajouté : [['TOP', 'Darius', 'JUNGLE', 'Hecarim', 'MIDDLE', 'Ahri', 'BOTTOM', 'Chogath', 'UTILITY', 'Senna'], ['TOP', 'Jax', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Sylas', 'BOTTOM', 'Kaisa', 'UTILITY', 'Nautilus'], 'Red']
# Matchs ajoutés : 15900
#
# Dernier match ajouté : [['TOP', 'Aatrox', 'JUNGLE', 'Shyvana', 'MIDDLE', 'Akshan', 'BOTTOM', 'Samira', 'UTILITY', 'Rell'], ['TOP', 'Vayne', 'JUNGLE', 'Sejuani', 'MIDDLE', 'Leblanc', 'BOTTOM', 'MissFortune', 'UTILITY', 'Alistar'], 'Red']
# Matchs ajoutés : 16000
#
# Dernier match ajouté : [['TOP', 'Zac', 'JUNGLE', 'XinZhao', 'MIDDLE', 'Leblanc', 'BOTTOM', 'Zeri', 'UTILITY', 'Amumu'], ['TOP', 'Jax', 'JUNGLE', 'Vi', 'MIDDLE', 'Syndra', 'BOTTOM', 'Jinx', 'UTILITY', 'Thresh'], 'Red']
# Matchs ajoutés : 16000
#
# Dernier match ajouté : []
# Matchs ajoutés : 16000
#
# Dernier match ajouté : []
# Matchs ajoutés : 16100
#
# Dernier match ajouté : [['TOP', 'Akshan', 'JUNGLE', 'Nidalee', 'MIDDLE', 'Velkoz', 'BOTTOM', 'Kaisa', 'UTILITY', 'Karma'], ['TOP', 'Aatrox', 'JUNGLE', 'Darius', 'MIDDLE', 'Taliyah', 'BOTTOM', 'MissFortune', 'UTILITY', 'Amumu'], 'Red']
# Matchs ajoutés : 16200
#
# Dernier match ajouté : [['TOP', 'Yorick', 'JUNGLE', 'Khazix', 'MIDDLE', 'Akali', 'BOTTOM', 'Ashe', 'UTILITY', 'Rakan'], ['TOP', 'Garen', 'JUNGLE', 'Belveth', 'MIDDLE', 'Akshan', 'BOTTOM', 'Karthus', 'UTILITY', 'Braum'], 'Red']
# Matchs ajoutés : 16200
#
# Dernier match ajouté : []
# Matchs ajoutés : 16200
#
# Dernier match ajouté : []
# Matchs ajoutés : 16200
#
# Dernier match ajouté : []
# Matchs ajoutés : 16300
#
# Dernier match ajouté : [['TOP', 'Jax', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Lux', 'BOTTOM', 'Vayne', 'UTILITY', 'Soraka'], ['TOP', 'Yone', 'JUNGLE', 'Diana', 'MIDDLE', 'Kaisa', 'BOTTOM', 'Twitch', 'UTILITY', 'Renata'], 'Red']
# Matchs ajoutés : 16400
#
# Dernier match ajouté : [['TOP', 'Renekton', 'JUNGLE', 'Taliyah', 'MIDDLE', 'Viktor', 'BOTTOM', 'Draven', 'UTILITY', 'Pyke'], ['TOP', 'Gnar', 'JUNGLE', 'Nidalee', 'MIDDLE', 'Jayce', 'BOTTOM', 'Ezreal', 'UTILITY', 'Bard'], 'Red']
# Matchs ajoutés : 16400
#
# Dernier match ajouté : []
# Matchs ajoutés : 16500
#
# Dernier match ajouté : [['TOP', 'Yone', 'JUNGLE', 'Ivern', 'MIDDLE', 'Swain', 'BOTTOM', 'Darius', 'UTILITY', 'Pyke'], ['TOP', 'Akali', 'JUNGLE', 'Rengar', 'MIDDLE', 'Zed', 'BOTTOM', 'Samira', 'UTILITY', 'Maokai'], 'Red']
# Matchs ajoutés : 16500
#
# Dernier match ajouté : []
# Matchs ajoutés : 16600
#
# Dernier match ajouté : [['TOP', 'Darius', 'JUNGLE', 'Khazix', 'MIDDLE', 'Lux', 'BOTTOM', 'Vayne', 'UTILITY', 'Karma'], ['TOP', 'Garen', 'JUNGLE', 'Sejuani', 'MIDDLE', 'Fizz', 'BOTTOM', 'Kaisa', 'UTILITY', 'Braum'], 'Blue']
# Matchs ajoutés : 16600
#
# Dernier match ajouté : []
# Matchs ajoutés : 16700
#
# Dernier match ajouté : [['TOP', 'Jayce', 'JUNGLE', 'Evelynn', 'MIDDLE', 'Taliyah', 'BOTTOM', 'Aphelios', 'UTILITY', 'Rell'], ['TOP', 'Yasuo', 'JUNGLE', 'JarvanIV', 'MIDDLE', 'Xerath', 'BOTTOM', 'Zeri', 'UTILITY', 'Zilean'], 'Red']
# Matchs ajoutés : 16700
#
# Dernier match ajouté : []
# Matchs ajoutés : 16800
#
# Dernier match ajouté : [['TOP', 'Yone', 'JUNGLE', 'Khazix', 'MIDDLE', 'Corki', 'BOTTOM', 'Karthus', 'UTILITY', 'Rell'], ['TOP', 'Camille', 'JUNGLE', 'JarvanIV', 'MIDDLE', 'Katarina', 'BOTTOM', 'Kaisa', 'UTILITY', 'Thresh'], 'Blue']
# Matchs ajoutés : 16900
#
# Dernier match ajouté : [['TOP', 'Naafiri', 'JUNGLE', 'Poppy', 'MIDDLE', 'Malphite', 'BOTTOM', 'Ashe', 'UTILITY', 'Braum'], ['TOP', 'Sylas', 'JUNGLE', 'Khazix', 'MIDDLE', 'Talon', 'BOTTOM', 'Ziggs', 'UTILITY', 'Karma'], 'Red']
# Matchs ajoutés : 16900
#
# Dernier match ajouté : []
# Matchs ajoutés : 17000
#
# Dernier match ajouté : [['TOP', 'Jax', 'JUNGLE', 'Khazix', 'MIDDLE', 'Zed', 'BOTTOM', 'Ezreal', 'UTILITY', 'Velkoz'], ['TOP', 'Vayne', 'JUNGLE', 'Karthus', 'MIDDLE', 'Akshan', 'BOTTOM', 'Ashe', 'UTILITY', 'Renata'], 'Red']
# Matchs ajoutés : 17100
#
# Dernier match ajouté : [['TOP', 'Naafiri', 'JUNGLE', 'Diana', 'MIDDLE', 'Yasuo', 'BOTTOM', 'Lucian', 'UTILITY', 'Rell'], ['TOP', 'Aatrox', 'JUNGLE', 'Shaco', 'MIDDLE', 'Azir', 'BOTTOM', 'Zeri', 'UTILITY', 'Galio'], 'Red']
# Matchs ajoutés : 17100
#
# Dernier match ajouté : []
# Matchs ajoutés : 17100
#
# Dernier match ajouté : []
# Matchs ajoutés : 17200
#
# Dernier match ajouté : [['TOP', 'KSante', 'JUNGLE', 'Maokai', 'MIDDLE', 'Akshan', 'BOTTOM', 'KogMaw', 'UTILITY', 'Zyra'], ['TOP', 'Renekton', 'JUNGLE', 'Lillia', 'MIDDLE', 'Irelia', 'BOTTOM', 'Ezreal', 'UTILITY', 'Janna'], 'Red']
# Matchs ajoutés : 17300
#
# Dernier match ajouté : [['TOP', 'Rengar', 'JUNGLE', 'Kindred', 'MIDDLE', 'Viktor', 'BOTTOM', 'Nilah', 'UTILITY', 'Rakan'], ['TOP', 'TwistedFate', 'JUNGLE', 'JarvanIV', 'MIDDLE', 'Taliyah', 'BOTTOM', 'Kaisa', 'UTILITY', 'Thresh'], 'Red']
# Matchs ajoutés : 17400
#
# Dernier match ajouté : [['TOP', 'KSante', 'JUNGLE', 'Nunu', 'MIDDLE', 'Syndra', 'BOTTOM', 'Ezreal', 'UTILITY', 'Bard'], ['TOP', 'Fiora', 'JUNGLE', 'JarvanIV', 'MIDDLE', 'Annie', 'BOTTOM', 'Twitch', 'UTILITY', 'Senna'], 'Blue']
# Matchs ajoutés : 17500
#
# Dernier match ajouté : [['TOP', 'Gragas', 'JUNGLE', 'Khazix', 'MIDDLE', 'Ahri', 'BOTTOM', 'Twitch', 'UTILITY', 'Amumu'], ['TOP', 'Pantheon', 'JUNGLE', 'Zac', 'MIDDLE', 'Kaisa', 'BOTTOM', 'Tristana', 'UTILITY', 'Taric'], 'Red']
# Matchs ajoutés : 17500
#
# Dernier match ajouté : []
# Matchs ajoutés : 17600
#
# Dernier match ajouté : [['TOP', 'Jax', 'JUNGLE', 'Diana', 'MIDDLE', 'Talon', 'BOTTOM', 'Xayah', 'UTILITY', 'Zilean'], ['TOP', 'Darius', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Kaisa', 'BOTTOM', 'Ashe', 'UTILITY', 'Nautilus'], 'Blue']
# Matchs ajoutés : 17700
#
# Dernier match ajouté : [['TOP', 'MonkeyKing', 'JUNGLE', 'Kayn', 'MIDDLE', 'Qiyana', 'BOTTOM', 'Kaisa', 'UTILITY', 'Senna'], ['TOP', 'Malphite', 'JUNGLE', 'Khazix', 'MIDDLE', 'Zed', 'BOTTOM', 'Ezreal', 'UTILITY', 'Karma'], 'Blue']
# Matchs ajoutés : 17700
#
# Dernier match ajouté : []
# Matchs ajoutés : 17800
#
# Dernier match ajouté : [['MIDDLE', 'Cassiopeia', 'JUNGLE', 'Graves', 'TOP', 'Yone', 'BOTTOM', 'Kaisa', 'UTILITY', 'Rell'], ['TOP', 'Ornn', 'JUNGLE', 'Khazix', 'MIDDLE', 'Irelia', 'BOTTOM', 'Xayah', 'UTILITY', 'Lux'], 'Blue']
# Matchs ajoutés : 17900
#
# Dernier match ajouté : [['TOP', 'Poppy', 'JUNGLE', 'Zed', 'MIDDLE', 'Viktor', 'BOTTOM', 'Xayah', 'UTILITY', 'Karma'], ['TOP', 'Tryndamere', 'JUNGLE', 'Volibear', 'MIDDLE', 'Taliyah', 'BOTTOM', 'Twitch', 'UTILITY', 'Yuumi'], 'Red']
# Matchs ajoutés : 18000
#
# Dernier match ajouté : [['TOP', 'Olaf', 'JUNGLE', 'JarvanIV', 'MIDDLE', 'Zed', 'BOTTOM', 'Kaisa', 'UTILITY', 'Karma'], ['TOP', 'Malphite', 'JUNGLE', 'Vi', 'MIDDLE', 'Akali', 'BOTTOM', 'Twitch', 'UTILITY', 'Soraka'], 'Blue']
# Matchs ajoutés : 18100
#
# Dernier match ajouté : [['TOP', 'Chogath', 'JUNGLE', 'Kayn', 'MIDDLE', 'Anivia', 'BOTTOM', 'Sivir', 'UTILITY', 'Veigar'], ['TOP', 'DrMundo', 'JUNGLE', 'Khazix', 'MIDDLE', 'Ahri', 'BOTTOM', 'Kaisa', 'UTILITY', 'Blitzcrank'], 'Red']
# Matchs ajoutés : 18200
#
# Dernier match ajouté : [['TOP', 'Singed', 'JUNGLE', 'Olaf', 'MIDDLE', 'Talon', 'BOTTOM', 'Xayah', 'UTILITY', 'Janna'], ['TOP', 'Malphite', 'JUNGLE', 'Kayn', 'MIDDLE', 'Neeko', 'BOTTOM', 'Samira', 'UTILITY', 'Rell'], 'Blue']
# Matchs ajoutés : 18300
#
# Dernier match ajouté : [['TOP', 'Sion', 'JUNGLE', 'Shyvana', 'MIDDLE', 'Talon', 'BOTTOM', 'Kaisa', 'UTILITY', 'Zilean'], ['TOP', 'Chogath', 'JUNGLE', 'Kayn', 'MIDDLE', 'Akali', 'BOTTOM', 'Draven', 'UTILITY', 'Nami'], 'Red']
# Matchs ajoutés : 18400
#
# Dernier match ajouté : [['TOP', 'Gnar', 'JUNGLE', 'Zac', 'MIDDLE', 'Anivia', 'BOTTOM', 'Vayne', 'UTILITY', 'Rakan'], ['TOP', 'Shen', 'JUNGLE', 'Belveth', 'MIDDLE', 'Ahri', 'BOTTOM', 'Samira', 'UTILITY', 'Pyke'], 'Blue']
# Matchs ajoutés : 18500
#
# Dernier match ajouté : [['TOP', 'Sion', 'JUNGLE', 'Udyr', 'MIDDLE', 'Katarina', 'BOTTOM', 'Ezreal', 'UTILITY', 'Blitzcrank'], ['TOP', 'Illaoi', 'JUNGLE', 'Maokai', 'MIDDLE', 'Jayce', 'BOTTOM', 'Aphelios', 'UTILITY', 'Sona'], 'Red']
# Matchs ajoutés : 18500
#
# Dernier match ajouté : []
# Matchs ajoutés : 18600
#
# Dernier match ajouté : [['TOP', 'Jayce', 'JUNGLE', 'Skarner', 'MIDDLE', 'Talon', 'BOTTOM', 'Kaisa', 'UTILITY', 'Leona'], ['TOP', 'Irelia', 'JUNGLE', 'JarvanIV', 'MIDDLE', 'Kassadin', 'BOTTOM', 'Draven', 'UTILITY', 'Sett'], 'Blue']
# Matchs ajoutés : 18600
#
# Dernier match ajouté : []
# Matchs ajoutés : 18700
#
# Dernier match ajouté : [['TOP', 'Fiora', 'JUNGLE', 'Nidalee', 'MIDDLE', 'Zed', 'BOTTOM', 'Twitch', 'UTILITY', 'Lulu'], ['TOP', 'KSante', 'JUNGLE', 'Viego', 'MIDDLE', 'Vladimir', 'BOTTOM', 'Zeri', 'UTILITY', 'Soraka'], 'Blue']
# Matchs ajoutés : 18800
#
# Dernier match ajouté : [['TOP', 'Akali', 'JUNGLE', 'Kayn', 'MIDDLE', 'Anivia', 'BOTTOM', 'Aphelios', 'UTILITY', 'Bard'], ['TOP', 'Irelia', 'JUNGLE', 'Amumu', 'MIDDLE', 'Ezreal', 'BOTTOM', 'Draven', 'UTILITY', 'Pyke'], 'Red']
# Matchs ajoutés : 18900
#
# Dernier match ajouté : [['TOP', 'Urgot', 'JUNGLE', 'Lillia', 'MIDDLE', 'Gangplank', 'BOTTOM', 'Lucian', 'UTILITY', 'Yuumi'], ['TOP', 'TahmKench', 'JUNGLE', 'Viego', 'MIDDLE', 'Vladimir', 'BOTTOM', 'Swain', 'UTILITY', 'Senna'], 'Red']
# Matchs ajoutés : 19000
#
# Dernier match ajouté : [['TOP', 'Varus', 'JUNGLE', 'Khazix', 'MIDDLE', 'Zed', 'BOTTOM', 'Tristana', 'UTILITY', 'Rell'], ['TOP', 'Lissandra', 'JUNGLE', 'LeeSin', 'BOTTOM', 'Ezreal', 'MIDDLE', 'Vladimir', 'UTILITY', 'Pyke'], 'Red']
# Matchs ajoutés : 19000
#
# Dernier match ajouté : []
# Matchs ajoutés : 19000
#
# Dernier match ajouté : []
# Matchs ajoutés : 19100
#
# Dernier match ajouté : [['TOP', 'Illaoi', 'JUNGLE', 'Khazix', 'MIDDLE', 'Malzahar', 'BOTTOM', 'Caitlyn', 'UTILITY', 'JarvanIV'], ['TOP', 'Maokai', 'JUNGLE', 'Hecarim', 'MIDDLE', 'Zed', 'BOTTOM', 'Ezreal', 'UTILITY', 'Annie'], 'Blue']
# Matchs ajoutés : 19100
#
# Dernier match ajouté : []
# Matchs ajoutés : 19100
#
# Dernier match ajouté : []
# Matchs ajoutés : 19100
#
# Dernier match ajouté : []
# Matchs ajoutés : 19200
#
# Dernier match ajouté : [['TOP', 'Gwen', 'JUNGLE', 'Hecarim', 'MIDDLE', 'Syndra', 'BOTTOM', 'Ashe', 'UTILITY', 'Alistar'], ['TOP', 'Gangplank', 'JUNGLE', 'Viego', 'MIDDLE', 'Ryze', 'BOTTOM', 'Samira', 'UTILITY', 'Renata'], 'Blue']
# Matchs ajoutés : 19300
#
# Dernier match ajouté : [['TOP', 'Yone', 'JUNGLE', 'Talon', 'MIDDLE', 'Sylas', 'BOTTOM', 'Caitlyn', 'UTILITY', 'Nami'], ['TOP', 'Garen', 'JUNGLE', 'Graves', 'MIDDLE', 'Zoe', 'BOTTOM', 'Ezreal', 'UTILITY', 'Karma'], 'Red']
# Matchs ajoutés : 19400
#
# Dernier match ajouté : [['TOP', 'Garen', 'JUNGLE', 'Ivern', 'MIDDLE', 'Sylas', 'BOTTOM', 'Xayah', 'UTILITY', 'Alistar'], ['TOP', 'Kayle', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Singed', 'BOTTOM', 'Jinx', 'UTILITY', 'Bard'], 'Blue']
# Matchs ajoutés : 19400
#
# Dernier match ajouté : []
# Matchs ajoutés : 19500
#
# Dernier match ajouté : [['TOP', 'Fiora', 'JUNGLE', 'Viego', 'MIDDLE', 'Kassadin', 'BOTTOM', 'Xayah', 'UTILITY', 'Nautilus'], ['TOP', 'Talon', 'JUNGLE', 'Skarner', 'MIDDLE', 'Yasuo', 'Invalid', 'Varus', 'UTILITY', 'Thresh'], 'Blue']
# Matchs ajoutés : 19600
#
# Dernier match ajouté : [['TOP', 'Sett', 'JUNGLE', 'Lillia', 'MIDDLE', 'Ahri', 'BOTTOM', 'Ashe', 'UTILITY', 'Janna'], ['TOP', 'Rammus', 'JUNGLE', 'Kayn', 'MIDDLE', 'Lux', 'BOTTOM', 'Samira', 'UTILITY', 'Rell'], 'Red']
# Matchs ajoutés : 19700
#
# Dernier match ajouté : [['TOP', 'Vayne', 'JUNGLE', 'Karthus', 'MIDDLE', 'Graves', 'BOTTOM', 'Samira', 'UTILITY', 'Blitzcrank'], ['TOP', 'Gnar', 'JUNGLE', 'Ekko', 'MIDDLE', 'Xerath', 'BOTTOM', 'Twitch', 'UTILITY', 'Taric'], 'Red']
# Matchs ajoutés : 19700
#
# Dernier match ajouté : []
# Matchs ajoutés : 19800
#
# Dernier match ajouté : [['TOP', 'Garen', 'JUNGLE', 'Maokai', 'MIDDLE', 'Akshan', 'BOTTOM', 'Xayah', 'UTILITY', 'Pyke'], ['TOP', 'Darius', 'JUNGLE', 'Amumu', 'MIDDLE', 'Leblanc', 'BOTTOM', 'Tristana', 'UTILITY', 'Taric'], 'Blue']
# Matchs ajoutés : 19900
#
# Dernier match ajouté : [['TOP', 'Riven', 'JUNGLE', 'Ivern', 'MIDDLE', 'Katarina', 'BOTTOM', 'Samira', 'UTILITY', 'Nautilus'], ['TOP', 'Darius', 'JUNGLE', 'Viego', 'MIDDLE', 'Twitch', 'BOTTOM', 'Nilah', 'UTILITY', 'Pyke'], 'Blue']
# Matchs ajoutés : 20000
#
# Dernier match ajouté : [['TOP', 'Fiora', 'JUNGLE', 'Rengar', 'MIDDLE', 'AurelionSol', 'BOTTOM', 'Lucian', 'JUNGLE', 'Nami'], ['TOP', 'Malphite', 'JUNGLE', 'JarvanIV', 'MIDDLE', 'TwistedFate', 'BOTTOM', 'Draven', 'UTILITY', 'Milio'], 'Red']
# Matchs ajoutés : 20100
#
# Dernier match ajouté : [['TOP', 'Renekton', 'JUNGLE', 'Karthus', 'MIDDLE', 'Tristana', 'BOTTOM', 'Ezreal', 'UTILITY', 'Rell'], ['TOP', 'Olaf', 'JUNGLE', 'Graves', 'MIDDLE', 'Irelia', 'BOTTOM', 'Kalista', 'UTILITY', 'Swain'], 'Red']
# Matchs ajoutés : 20200
#
# Dernier match ajouté : [['TOP', 'Illaoi', 'JUNGLE', 'Kayn', 'MIDDLE', 'Kassadin', 'BOTTOM', 'Ashe', 'UTILITY', 'Bard'], ['TOP', 'Riven', 'JUNGLE', 'FiddleSticks', 'MIDDLE', 'Sylas', 'BOTTOM', 'Kaisa', 'UTILITY', 'Thresh'], 'Red']
# Matchs ajoutés : 20300
#
# Dernier match ajouté : [['TOP', 'Irelia', 'JUNGLE', 'Rell', 'MIDDLE', 'Sylas', 'BOTTOM', 'Kaisa', 'UTILITY', 'Pyke'], ['TOP', 'Garen', 'JUNGLE', 'Trundle', 'MIDDLE', 'Zed', 'BOTTOM', 'Vayne', 'UTILITY', 'Thresh'], 'Blue']
# Matchs ajoutés : 20400
#
# Dernier match ajouté : [['TOP', 'Garen', 'JUNGLE', 'Belveth', 'MIDDLE', 'Viktor', 'BOTTOM', 'Ezreal', 'UTILITY', 'Janna'], ['TOP', 'Fiora', 'JUNGLE', 'Kindred', 'MIDDLE', 'Orianna', 'BOTTOM', 'Karthus', 'UTILITY', 'Rell'], 'Red']
# Matchs ajoutés : 20500
#
# Dernier match ajouté : [['TOP', 'Renekton', 'JUNGLE', 'Shaco', 'MIDDLE', 'Ahri', 'BOTTOM', 'Samira', 'UTILITY', 'Nautilus'], ['TOP', 'Garen', 'JUNGLE', 'Kindred', 'MIDDLE', 'Syndra', 'BOTTOM', 'Kaisa', 'UTILITY', 'Janna'], 'Blue']
# Matchs ajoutés : 20600
#
# Dernier match ajouté : [['TOP', 'Jax', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Anivia', 'BOTTOM', 'Xayah', 'UTILITY', 'Rakan'], ['TOP', 'Fiora', 'JUNGLE', 'FiddleSticks', 'MIDDLE', 'Lissandra', 'BOTTOM', 'Ezreal', 'JUNGLE', 'Ashe'], 'Red']
# Matchs ajoutés : 20700
#
# Dernier match ajouté : [['TOP', 'Urgot', 'JUNGLE', 'Ekko', 'MIDDLE', 'Akshan', 'BOTTOM', 'Ashe', 'UTILITY', 'Rell'], ['TOP', 'Malphite', 'JUNGLE', 'FiddleSticks', 'MIDDLE', 'Graves', 'BOTTOM', 'Ezreal', 'UTILITY', 'Pyke'], 'Red']
# Matchs ajoutés : 20700
#
# Dernier match ajouté : []
# Matchs ajoutés : 20700
#
# Dernier match ajouté : []
# Matchs ajoutés : 20700
#
# Dernier match ajouté : []
# Matchs ajoutés : 20700
#
# Dernier match ajouté : []
# Matchs ajoutés : 20700
#
# Dernier match ajouté : []
# Matchs ajoutés : 20700
#
# Dernier match ajouté : []
# Matchs ajoutés : 20700
#
# Dernier match ajouté : []
# Matchs ajoutés : 20800
#
# Dernier match ajouté : [['TOP', 'Kled', 'JUNGLE', 'Viego', 'MIDDLE', 'Leblanc', 'BOTTOM', 'Tristana', 'UTILITY', 'Yuumi'], ['TOP', 'Ivern', 'JUNGLE', 'RekSai', 'MIDDLE', 'Vex', 'BOTTOM', 'Kaisa', 'UTILITY', 'Blitzcrank'], 'Red']
# Matchs ajoutés : 20900
#
# Dernier match ajouté : [['TOP', 'KSante', 'JUNGLE', 'Viego', 'MIDDLE', 'Caitlyn', 'BOTTOM', 'Varus', 'UTILITY', 'Sona'], ['TOP', 'DrMundo', 'JUNGLE', 'Volibear', 'MIDDLE', 'Syndra', 'BOTTOM', 'Jinx', 'UTILITY', 'Milio'], 'Red']
# Matchs ajoutés : 20900
#
# Dernier match ajouté : []
# Matchs ajoutés : 21000
#
# Dernier match ajouté : [['TOP', 'Sett', 'JUNGLE', 'Khazix', 'MIDDLE', 'Akshan', 'BOTTOM', 'Ziggs', 'UTILITY', 'Janna'], ['TOP', 'Kled', 'JUNGLE', 'Kindred', 'MIDDLE', 'Akali', 'BOTTOM', 'Draven', 'UTILITY', 'Blitzcrank'], 'Blue']
# Matchs ajoutés : 21100
#
# Dernier match ajouté : [['TOP', 'Jax', 'JUNGLE', 'Kayn', 'MIDDLE', 'Lux', 'BOTTOM', 'Kaisa', 'UTILITY', 'Amumu'], ['TOP', 'Akshan', 'JUNGLE', 'Hecarim', 'MIDDLE', 'Xerath', 'BOTTOM', 'Draven', 'UTILITY', 'Janna'], 'Blue']
# Matchs ajoutés : 21200
#
# Dernier match ajouté : [['TOP', 'Jax', 'JUNGLE', 'Belveth', 'MIDDLE', 'Veigar', 'BOTTOM', 'MissFortune', 'UTILITY', 'Thresh'], ['TOP', 'Darius', 'JUNGLE', 'Warwick', 'MIDDLE', 'Leblanc', 'BOTTOM', 'Varus', 'UTILITY', 'Maokai'], 'Red']
# Matchs ajoutés : 21300
#
# Dernier match ajouté : [['TOP', 'Riven', 'JUNGLE', 'Viego', 'BOTTOM', 'Tristana', 'MIDDLE', 'Kassadin', 'UTILITY', 'Nautilus'], ['TOP', 'Camille', 'JUNGLE', 'Udyr', 'MIDDLE', 'Katarina', 'BOTTOM', 'Zeri', 'UTILITY', 'Milio'], 'Blue']
# Matchs ajoutés : 21400
#
# Dernier match ajouté : [['TOP', 'Renekton', 'JUNGLE', 'Ekko', 'MIDDLE', 'Naafiri', 'BOTTOM', 'Kaisa', 'UTILITY', 'Heimerdinger'], ['TOP', 'Rumble', 'JUNGLE', 'Rengar', 'MIDDLE', 'Zoe', 'BOTTOM', 'Ashe', 'UTILITY', 'Zyra'], 'Blue']
# Matchs ajoutés : 21500
#
# Dernier match ajouté : [['TOP', 'Vayne', 'JUNGLE', 'Hecarim', 'MIDDLE', 'Ahri', 'BOTTOM', 'Yasuo', 'UTILITY', 'Nautilus'], ['TOP', 'Ornn', 'JUNGLE', 'Graves', 'MIDDLE', 'Kaisa', 'BOTTOM', 'Xayah', 'UTILITY', 'Rell'], 'Blue']
# Matchs ajoutés : 21600
#
# Dernier match ajouté : [['TOP', 'Karma', 'JUNGLE', 'Nidalee', 'MIDDLE', 'Aatrox', 'BOTTOM', 'Kaisa', 'UTILITY', 'Rell'], ['TOP', 'Renekton', 'JUNGLE', 'Viego', 'MIDDLE', 'Vladimir', 'UTILITY', 'Senna', 'BOTTOM', 'Chogath'], 'Blue']
# Matchs ajoutés : 21600
#
# Dernier match ajouté : []
# Matchs ajoutés : 21700
#
# Dernier match ajouté : [['TOP', 'Quinn', 'JUNGLE', 'Gwen', 'MIDDLE', 'Veigar', 'BOTTOM', 'Twitch', 'UTILITY', 'Thresh'], ['TOP', 'Jax', 'JUNGLE', 'Graves', 'MIDDLE', 'Sylas', 'BOTTOM', 'Kaisa', 'UTILITY', 'Nautilus'], 'Red']
# Matchs ajoutés : 21800
#
# Dernier match ajouté : [['TOP', 'Gragas', 'JUNGLE', 'Nunu', 'MIDDLE', 'Zed', 'BOTTOM', 'Kalista', 'UTILITY', 'Pyke'], ['TOP', 'Kaisa', 'JUNGLE', 'MasterYi', 'MIDDLE', 'Ekko', 'BOTTOM', 'Vayne', 'UTILITY', 'Yuumi'], 'Blue']
# Matchs ajoutés : 21800
#
# Dernier match ajouté : []
# Matchs ajoutés : 21900
#
# Dernier match ajouté : [['TOP', 'KSante', 'JUNGLE', 'Sejuani', 'MIDDLE', 'Cassiopeia', 'BOTTOM', 'Ezreal', 'UTILITY', 'Karma'], ['TOP', 'Olaf', 'JUNGLE', 'Maokai', 'MIDDLE', 'Akshan', 'BOTTOM', 'Lucian', 'UTILITY', 'Milio'], 'Blue']
# Matchs ajoutés : 21900
#
# Dernier match ajouté : []
# Matchs ajoutés : 22000
#
# Dernier match ajouté : [['TOP', 'Camille', 'JUNGLE', 'Taliyah', 'MIDDLE', 'Yone', 'BOTTOM', 'Draven', 'UTILITY', 'Quinn'], ['TOP', 'Gwen', 'JUNGLE', 'Rell', 'MIDDLE', 'Syndra', 'BOTTOM', 'Varus', 'UTILITY', 'Soraka'], 'Red']
# Matchs ajoutés : 22100
#
# Dernier match ajouté : [['TOP', 'Aatrox', 'JUNGLE', 'Maokai', 'MIDDLE', 'Syndra', 'BOTTOM', 'Kaisa', 'UTILITY', 'Taric'], ['TOP', 'Azir', 'JUNGLE', 'XinZhao', 'MIDDLE', 'Katarina', 'BOTTOM', 'Twitch', 'UTILITY', 'Lulu'], 'Red']
# Matchs ajoutés : 22100
#
# Dernier match ajouté : []
# Matchs ajoutés : 22200
#
# Dernier match ajouté : [['TOP', 'MonkeyKing', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Ahri', 'BOTTOM', 'Ashe', 'UTILITY', 'Zilean'], ['TOP', 'Gwen', 'JUNGLE', 'Khazix', 'MIDDLE', 'Lux', 'BOTTOM', 'Chogath', 'UTILITY', 'Senna'], 'Red']
# Matchs ajoutés : 22300
#
# ...
# Dernier match ajouté : []
# Matchs ajoutés : 158100
#
# Dernier match ajouté : []
# Matchs ajoutés : 158200
#
# Dernier match ajouté : [['TOP', 'Swain', 'JUNGLE', 'Ekko', 'MIDDLE', 'Pantheon', 'BOTTOM', 'Varus', 'UTILITY', 'Rell'], ['TOP', 'Mordekaiser', 'JUNGLE', 'Graves', 'MIDDLE', 'Syndra', 'BOTTOM', 'Kaisa', 'UTILITY', 'Thresh'], 'Blue']
# Matchs ajoutés : 158300
#
# Dernier match ajouté : [['TOP', 'Jayce', 'JUNGLE', 'Viego', 'MIDDLE', 'Lissandra', 'BOTTOM', 'Ezreal', 'UTILITY', 'Shen'], ['TOP', 'Irelia', 'JUNGLE', 'Khazix', 'MIDDLE', 'Ahri', 'BOTTOM', 'Yasuo', 'UTILITY', 'Alistar'], 'Blue']
# Matchs ajoutés : 158400
#
# Dernier match ajouté : [['TOP', 'Olaf', 'JUNGLE', 'FiddleSticks', 'MIDDLE', 'Kassadin', 'BOTTOM', 'Kaisa', 'UTILITY', 'Soraka'], ['TOP', 'Tryndamere', 'JUNGLE', 'Evelynn', 'MIDDLE', 'Xerath', 'BOTTOM', 'Zeri', 'UTILITY', 'Taric'], 'Blue']
# Matchs ajoutés : 158500
#
# Dernier match ajouté : [['TOP', 'Urgot', 'JUNGLE', 'RekSai', 'MIDDLE', 'Ziggs', 'BOTTOM', 'KogMaw', 'UTILITY', 'Milio'], ['TOP', 'Fiora', 'JUNGLE', 'Poppy', 'MIDDLE', 'Yasuo', 'BOTTOM', 'Twitch', 'UTILITY', 'Lulu'], 'Blue']
# Matchs ajoutés : 158600
#
# Dernier match ajouté : [['TOP', 'Gnar', 'JUNGLE', 'RekSai', 'MIDDLE', 'Ahri', 'BOTTOM', 'Karthus', 'UTILITY', 'Pyke'], ['TOP', 'Kennen', 'JUNGLE', 'Maokai', 'MIDDLE', 'Zed', 'BOTTOM', 'Ezreal', 'UTILITY', 'Ivern'], 'Blue']
# Matchs ajoutés : 158700
#
# Dernier match ajouté : [['UTILITY', 'Yuumi', 'JUNGLE', 'Viego', 'MIDDLE', 'Syndra', 'BOTTOM', 'Zeri', 'TOP', 'Gragas'], ['TOP', 'Renekton', 'JUNGLE', 'JarvanIV', 'MIDDLE', 'Ahri', 'BOTTOM', 'Ezreal', 'UTILITY', 'Thresh'], 'Blue']
# Matchs ajoutés : 158800
#
# Dernier match ajouté : [['TOP', 'Jayce', 'JUNGLE', 'Maokai', 'MIDDLE', 'Katarina', 'BOTTOM', 'Tristana', 'UTILITY', 'Velkoz'], ['TOP', 'Mordekaiser', 'JUNGLE', 'Gragas', 'MIDDLE', 'Lux', 'BOTTOM', 'Ezreal', 'UTILITY', 'Pyke'], 'Red']
# Matchs ajoutés : 158900
#
# Dernier match ajouté : [['TOP', 'Akshan', 'JUNGLE', 'MasterYi', 'MIDDLE', 'Leblanc', 'BOTTOM', 'Tristana', 'UTILITY', 'Nautilus'], ['TOP', 'Gwen', 'JUNGLE', 'Zac', 'MIDDLE', 'Caitlyn', 'BOTTOM', 'Ashe', 'UTILITY', 'Pyke'], 'Red']
# Matchs ajoutés : 158900
#
# Dernier match ajouté : []
# Matchs ajoutés : 158900
#
# Dernier match ajouté : []
# Matchs ajoutés : 159000
#
# Dernier match ajouté : [['TOP', 'Sett', 'JUNGLE', 'Viego', 'MIDDLE', 'Leblanc', 'BOTTOM', 'Ashe', 'UTILITY', 'Lulu'], ['TOP', 'Ivern', 'JUNGLE', 'Amumu', 'MIDDLE', 'Syndra', 'BOTTOM', 'Twitch', 'UTILITY', 'Rakan'], 'Red']
# Matchs ajoutés : 159000
#
# Dernier match ajouté : []
# Matchs ajoutés : 159100
#
# Dernier match ajouté : [['TOP', 'Akali', 'JUNGLE', 'Hecarim', 'MIDDLE', 'Irelia', 'BOTTOM', 'Kaisa', 'UTILITY', 'Pyke'], ['TOP', 'Pantheon', 'JUNGLE', 'Kayn', 'MIDDLE', 'Galio', 'BOTTOM', 'Draven', 'UTILITY', 'Nautilus'], 'Red']
# Matchs ajoutés : 159200
#
# Dernier match ajouté : [['TOP', 'Gwen', 'JUNGLE', 'Kayn', 'MIDDLE', 'Ahri', 'BOTTOM', 'Ezreal', 'UTILITY', 'Karma'], ['TOP', 'Irelia', 'JUNGLE', 'Viego', 'MIDDLE', 'Syndra', 'BOTTOM', 'Swain', 'UTILITY', 'Senna'], 'Red']
# Matchs ajoutés : 159300
#
# Dernier match ajouté : [['TOP', 'Nasus', 'JUNGLE', 'Kindred', 'MIDDLE', 'Sylas', 'BOTTOM', 'Karthus', 'UTILITY', 'Nautilus'], ['MIDDLE', 'Ahri', 'JUNGLE', 'Talon', 'TOP', 'Renekton', 'BOTTOM', 'Seraphine', 'UTILITY', 'Alistar'], 'Red']
# Matchs ajoutés : 159300
#
# Dernier match ajouté : []
# Matchs ajoutés : 159300
#
# Dernier match ajouté : []
# Matchs ajoutés : 159400
#
# Dernier match ajouté : [['TOP', 'Gangplank', 'JUNGLE', 'Kayn', 'MIDDLE', 'Malzahar', 'BOTTOM', 'Twitch', 'UTILITY', 'Milio'], ['TOP', 'Irelia', 'JUNGLE', 'Talon', 'MIDDLE', 'Vladimir', 'BOTTOM', 'Zeri', 'UTILITY', 'Nautilus'], 'Blue']
# Matchs ajoutés : 159500
#
# Dernier match ajouté : [['TOP', 'Riven', 'JUNGLE', 'Viego', 'MIDDLE', 'Orianna', 'BOTTOM', 'Kaisa', 'UTILITY', 'Nautilus'], ['JUNGLE', 'Ivern', 'TOP', 'Jax', 'MIDDLE', 'Ahri', 'BOTTOM', 'Draven', 'UTILITY', 'Braum'], 'Blue']
# Matchs ajoutés : 159600
#
# Dernier match ajouté : [['TOP', 'FiddleSticks', 'JUNGLE', 'Nunu', 'MIDDLE', 'Irelia', 'BOTTOM', 'Ezreal', 'UTILITY', 'Renata'], ['TOP', 'Sion', 'JUNGLE', 'Ivern', 'MIDDLE', 'Lissandra', 'BOTTOM', 'Samira', 'UTILITY', 'Alistar'], 'Blue']
# Matchs ajoutés : 159600
#
# Dernier match ajouté : []
# Matchs ajoutés : 159600
#
# Dernier match ajouté : []
# Matchs ajoutés : 159700
#
# Dernier match ajouté : [['TOP', 'Illaoi', 'JUNGLE', 'Khazix', 'MIDDLE', 'Ahri', 'BOTTOM', 'Sivir', 'UTILITY', 'Xerath'], ['TOP', 'Yorick', 'JUNGLE', 'JarvanIV', 'MIDDLE', 'Veigar', 'BOTTOM', 'Aphelios', 'UTILITY', 'Karma'], 'Blue']
# Matchs ajoutés : 159800
#
# Dernier match ajouté : [['TOP', 'Renekton', 'JUNGLE', 'Belveth', 'MIDDLE', 'Orianna', 'BOTTOM', 'Senna', 'UTILITY', 'Renata'], ['TOP', 'KSante', 'JUNGLE', 'Rengar', 'MIDDLE', 'Akali', 'BOTTOM', 'Draven', 'UTILITY', 'Rakan'], 'Red']
# Matchs ajoutés : 159800
#
# Dernier match ajouté : []
# Matchs ajoutés : 159800
#
# Dernier match ajouté : []
# Matchs ajoutés : 159800
#
# Dernier match ajouté : []
# Matchs ajoutés : 159900
#
# Dernier match ajouté : [['TOP', 'Yone', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Kassadin', 'BOTTOM', 'Xayah', 'UTILITY', 'Thresh'], ['TOP', 'Jax', 'JUNGLE', 'Vi', 'MIDDLE', 'Vladimir', 'BOTTOM', 'Vayne', 'UTILITY', 'Pyke'], 'Blue']
# Matchs ajoutés : 160000
#
# Dernier match ajouté : [['TOP', 'Camille', 'JUNGLE', 'Poppy', 'MIDDLE', 'Syndra', 'BOTTOM', 'Seraphine', 'UTILITY', 'Rakan'], ['TOP', 'Renekton', 'JUNGLE', 'Kindred', 'MIDDLE', 'Ahri', 'BOTTOM', 'Jhin', 'UTILITY', 'Swain'], 'Red']
# Matchs ajoutés : 160000
#
# Dernier match ajouté : []
# Matchs ajoutés : 160000
#
# Dernier match ajouté : []
# Matchs ajoutés : 160000
#
# Dernier match ajouté : []
# Matchs ajoutés : 160100
#
# Dernier match ajouté : [['TOP', 'Olaf', 'JUNGLE', 'Sejuani', 'MIDDLE', 'Katarina', 'BOTTOM', 'Jhin', 'UTILITY', 'Pantheon'], ['TOP', 'Aatrox', 'JUNGLE', 'Khazix', 'MIDDLE', 'Chogath', 'BOTTOM', 'Aphelios', 'UTILITY', 'Pyke'], 'Blue']
# Matchs ajoutés : 160200
#
# Dernier match ajouté : [['TOP', 'Camille', 'JUNGLE', 'FiddleSticks', 'MIDDLE', 'LeeSin', 'BOTTOM', 'Jinx', 'UTILITY', 'Karthus'], ['TOP', 'Akshan', 'JUNGLE', 'Viego', 'MIDDLE', 'Katarina', 'UTILITY', 'Jhin', 'UTILITY', 'Senna'], 'Red']
# Matchs ajoutés : 160300
#
# Dernier match ajouté : [['TOP', 'Riven', 'JUNGLE', 'Hecarim', 'MIDDLE', 'Ahri', 'BOTTOM', 'Kalista', 'UTILITY', 'Leona'], ['TOP', 'Aatrox', 'JUNGLE', 'JarvanIV', 'MIDDLE', 'Vladimir', 'BOTTOM', 'Ashe', 'UTILITY', 'Braum'], 'Blue']
# Matchs ajoutés : 160400
#
# Dernier match ajouté : [['TOP', 'Varus', 'JUNGLE', 'Khazix', 'MIDDLE', 'Anivia', 'BOTTOM', 'KogMaw', 'UTILITY', 'Braum'], ['TOP', 'Malphite', 'JUNGLE', 'Zed', 'MIDDLE', 'TwistedFate', 'BOTTOM', 'Twitch', 'UTILITY', 'Rakan'], 'Blue']
# Matchs ajoutés : 160400
#
# Dernier match ajouté : []
# Matchs ajoutés : 160500
#
# Dernier match ajouté : [['TOP', 'Maokai', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Seraphine', 'BOTTOM', 'Ezreal', 'UTILITY', 'Senna'], ['TOP', 'Gragas', 'JUNGLE', 'RekSai', 'MIDDLE', 'Malzahar', 'BOTTOM', 'Jhin', 'UTILITY', 'Karma'], 'Red']
# Matchs ajoutés : 160600
#
# Dernier match ajouté : [['TOP', 'Sylas', 'JUNGLE', 'RekSai', 'MIDDLE', 'Zed', 'BOTTOM', 'Kaisa', 'UTILITY', 'Alistar'], ['TOP', 'Jax', 'JUNGLE', 'JarvanIV', 'MIDDLE', 'Irelia', 'BOTTOM', 'Nilah', 'UTILITY', 'Xerath'], 'Red']
# Matchs ajoutés : 160700
#
# Dernier match ajouté : [['TOP', 'Irelia', 'JUNGLE', 'Kayn', 'MIDDLE', 'Akali', 'BOTTOM', 'Seraphine', 'UTILITY', 'Pyke'], ['TOP', 'Fiora', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Tristana', 'BOTTOM', 'Kaisa', 'UTILITY', 'Zyra'], 'Blue']
# Matchs ajoutés : 160700
#
# Dernier match ajouté : []
# Matchs ajoutés : 160700
#
# Dernier match ajouté : []
# Matchs ajoutés : 160800
#
# Dernier match ajouté : [['TOP', 'Rammus', 'JUNGLE', 'Viego', 'MIDDLE', 'Kassadin', 'BOTTOM', 'Aphelios', 'UTILITY', 'TahmKench'], ['TOP', 'Yone', 'JUNGLE', 'JarvanIV', 'MIDDLE', 'Katarina', 'BOTTOM', 'Kaisa', 'UTILITY', 'Blitzcrank'], 'Red']
# Matchs ajoutés : 160800
#
# Dernier match ajouté : []
# Matchs ajoutés : 160800
#
# Dernier match ajouté : []
# Matchs ajoutés : 160800
#
# Dernier match ajouté : []
# Matchs ajoutés : 160800
#
# Dernier match ajouté : []
# Matchs ajoutés : 160800
#
# Dernier match ajouté : []
# Matchs ajoutés : 160800
#
# Dernier match ajouté : []
# Matchs ajoutés : 160900
#
# Dernier match ajouté : [['TOP', 'Akali', 'JUNGLE', 'Kindred', 'MIDDLE', 'Sylas', 'BOTTOM', 'Varus', 'UTILITY', 'Senna'], ['TOP', 'Kayle', 'JUNGLE', 'Viego', 'MIDDLE', 'Neeko', 'BOTTOM', 'Aphelios', 'UTILITY', 'Nautilus'], 'Red']
# Matchs ajoutés : 161000
#
# Dernier match ajouté : [['TOP', 'Rumble', 'JUNGLE', 'Rengar', 'MIDDLE', 'Lissandra', 'BOTTOM', 'Yasuo', 'UTILITY', 'Pyke'], ['TOP', 'Aatrox', 'JUNGLE', 'Nunu', 'MIDDLE', 'Talon', 'BOTTOM', 'Jinx', 'UTILITY', 'Janna'], 'Red']
# Matchs ajoutés : 161100
#
# Dernier match ajouté : [['TOP', 'Renekton', 'JUNGLE', 'Talon', 'MIDDLE', 'Sylas', 'BOTTOM', 'Kaisa', 'UTILITY', 'Janna'], ['TOP', 'Aatrox', 'JUNGLE', 'Hecarim', 'MIDDLE', 'Akali', 'BOTTOM', 'Nilah', 'UTILITY', 'Pyke'], 'Blue']
# Matchs ajoutés : 161200
#
# Dernier match ajouté : [['TOP', 'Jayce', 'JUNGLE', 'JarvanIV', 'MIDDLE', 'Veigar', 'BOTTOM', 'Vayne', 'UTILITY', 'Karma'], ['TOP', 'Darius', 'JUNGLE', 'Karthus', 'MIDDLE', 'Tristana', 'BOTTOM', 'Kaisa', 'UTILITY', 'Nautilus'], 'Red']
# Matchs ajoutés : 161300
#
# Dernier match ajouté : [['TOP', 'Olaf', 'JUNGLE', 'Twitch', 'MIDDLE', 'Pyke', 'BOTTOM', 'Cassiopeia', 'UTILITY', 'Rakan'], ['TOP', 'Gnar', 'JUNGLE', 'Rell', 'MIDDLE', 'Syndra', 'BOTTOM', 'Kaisa', 'UTILITY', 'Blitzcrank'], 'Red']
# Matchs ajoutés : 161400
#
# Dernier match ajouté : [['TOP', 'Darius', 'JUNGLE', 'Ekko', 'MIDDLE', 'Naafiri', 'BOTTOM', 'Ashe', 'UTILITY', 'Lulu'], ['TOP', 'Riven', 'JUNGLE', 'RekSai', 'MIDDLE', 'Ahri', 'BOTTOM', 'MissFortune', 'UTILITY', 'Rell'], 'Red']
# Matchs ajoutés : 161400
#
# Dernier match ajouté : []
# Matchs ajoutés : 161500
#
# Dernier match ajouté : [['TOP', 'Vladimir', 'JUNGLE', 'Talon', 'MIDDLE', 'Naafiri', 'BOTTOM', 'Ashe', 'UTILITY', 'Karma'], ['TOP', 'Poppy', 'JUNGLE', 'Taliyah', 'MIDDLE', 'Veigar', 'BOTTOM', 'Twitch', 'UTILITY', 'Milio'], 'Blue']
# Matchs ajoutés : 161600
#
# Dernier match ajouté : [['TOP', 'Gangplank', 'JUNGLE', 'Shaco', 'MIDDLE', 'Tristana', 'BOTTOM', 'Varus', 'UTILITY', 'Brand'], ['TOP', 'Ornn', 'JUNGLE', 'Rengar', 'MIDDLE', 'Zed', 'BOTTOM', 'Ziggs', 'UTILITY', 'Nautilus'], 'Blue']
# Matchs ajoutés : 161600
#
# Dernier match ajouté : []
# Matchs ajoutés : 161700
#
# Dernier match ajouté : [['TOP', 'Fiora', 'JUNGLE', 'Kindred', 'MIDDLE', 'Zed', 'BOTTOM', 'Kaisa', 'UTILITY', 'Rakan'], ['TOP', 'Darius', 'JUNGLE', 'Zac', 'MIDDLE', 'Syndra', 'BOTTOM', 'Ezreal', 'UTILITY', 'Karma'], 'Red']
# Matchs ajoutés : 161800
#
# Dernier match ajouté : [['TOP', 'Jax', 'JUNGLE', 'Evelynn', 'MIDDLE', 'Qiyana', 'BOTTOM', 'Kaisa', 'UTILITY', 'Lux'], ['TOP', 'Gnar', 'JUNGLE', 'RekSai', 'MIDDLE', 'Syndra', 'BOTTOM', 'Aphelios', 'UTILITY', 'Braum'], 'Blue']
# Matchs ajoutés : 161800
#
# Dernier match ajouté : []
# Matchs ajoutés : 161900
#
# Dernier match ajouté : [['TOP', 'Renekton', 'JUNGLE', 'Talon', 'MIDDLE', 'Zoe', 'BOTTOM', 'Ashe', 'UTILITY', 'TahmKench'], ['TOP', 'Camille', 'JUNGLE', 'Sylas', 'MIDDLE', 'Naafiri', 'BOTTOM', 'Kaisa', 'UTILITY', 'Nautilus'], 'Red']
# Matchs ajoutés : 162000
#
# Dernier match ajouté : [['TOP', 'Darius', 'JUNGLE', 'Nidalee', 'MIDDLE', 'Annie', 'BOTTOM', 'Kaisa', 'UTILITY', 'Pyke'], ['TOP', 'Renekton', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Syndra', 'BOTTOM', 'MissFortune', 'UTILITY', 'Neeko'], 'Blue']
# Matchs ajoutés : 162000
#
# Dernier match ajouté : []
# Matchs ajoutés : 162100
#
# Dernier match ajouté : [['TOP', 'Anivia', 'JUNGLE', 'Hecarim', 'MIDDLE', 'Yone', 'BOTTOM', 'Kaisa', 'UTILITY', 'Pantheon'], ['TOP', 'Tryndamere', 'JUNGLE', 'MonkeyKing', 'MIDDLE', 'Ahri', 'BOTTOM', 'Yasuo', 'UTILITY', 'Swain'], 'Red']
# Matchs ajoutés : 162100
#
# Dernier match ajouté : []
# Matchs ajoutés : 162200
#
# Dernier match ajouté : [['TOP', 'Garen', 'JUNGLE', 'FiddleSticks', 'MIDDLE', 'Azir', 'BOTTOM', 'Jhin', 'UTILITY', 'Karma'], ['TOP', 'Ornn', 'JUNGLE', 'Poppy', 'MIDDLE', 'Kaisa', 'BOTTOM', 'Ezreal', 'UTILITY', 'Nami'], 'Blue']
# Matchs ajoutés : 162300
#
# Dernier match ajouté : [['TOP', 'Akali', 'JUNGLE', 'Viego', 'MIDDLE', 'Sylas', 'BOTTOM', 'Ashe', 'UTILITY', 'Senna'], ['TOP', 'Jayce', 'JUNGLE', 'Hecarim', 'MIDDLE', 'Lissandra', 'BOTTOM', 'MissFortune', 'UTILITY', 'Karma'], 'Blue']
# Matchs ajoutés : 162400
#
# Dernier match ajouté : [['TOP', 'Illaoi', 'JUNGLE', 'Kayn', 'MIDDLE', 'Tristana', 'BOTTOM', 'Kaisa', 'UTILITY', 'Rell'], ['TOP', 'Rumble', 'JUNGLE', 'Gragas', 'MIDDLE', 'Zed', 'BOTTOM', 'MissFortune', 'UTILITY', 'Rakan'], 'Blue']
# Matchs ajoutés : 162400
#
# Dernier match ajouté : []
# Matchs ajoutés : 162400
#
# Dernier match ajouté : []
# Matchs ajoutés : 162500
#
# Dernier match ajouté : [['TOP', 'Yone', 'JUNGLE', 'Graves', 'MIDDLE', 'Cassiopeia', 'BOTTOM', 'Varus', 'UTILITY', 'Sona'], ['TOP', 'Pantheon', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Vladimir', 'BOTTOM', 'Nilah', 'UTILITY', 'Nautilus'], 'Red']
# Matchs ajoutés : 162600
#
# Dernier match ajouté : [['TOP', 'Zac', 'JUNGLE', 'Shaco', 'MIDDLE', 'Qiyana', 'BOTTOM', 'Kaisa', 'UTILITY', 'Thresh'], ['TOP', 'Aatrox', 'JUNGLE', 'Graves', 'MIDDLE', 'Katarina', 'BOTTOM', 'Xayah', 'UTILITY', 'Janna'], 'Blue']
# Matchs ajoutés : 162600
#
# Dernier match ajouté : []
# Matchs ajoutés : 162600
#
# Dernier match ajouté : []
# Matchs ajoutés : 162600
#
# Dernier match ajouté : []
# Matchs ajoutés : 162600
#
# Dernier match ajouté : []
# Matchs ajoutés : 162700
#
# Dernier match ajouté : [['TOP', 'Yone', 'JUNGLE', 'Maokai', 'MIDDLE', 'Zed', 'BOTTOM', 'Ezreal', 'UTILITY', 'Xerath'], ['TOP', 'Urgot', 'JUNGLE', 'Nidalee', 'MIDDLE', 'Qiyana', 'BOTTOM', 'Kaisa', 'UTILITY', 'Seraphine'], 'Blue']
# Matchs ajoutés : 162800
#
# Dernier match ajouté : [['TOP', 'Yasuo', 'JUNGLE', 'Evelynn', 'MIDDLE', 'Yone', 'BOTTOM', 'Draven', 'UTILITY', 'Karma'], ['TOP', 'KSante', 'JUNGLE', 'Zed', 'MIDDLE', 'Cassiopeia', 'BOTTOM', 'Kaisa', 'UTILITY', 'Sona'], 'Blue']
# Matchs ajoutés : 162900
#
# Dernier match ajouté : [['TOP', 'Rumble', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Leblanc', 'BOTTOM', 'Ezreal', 'UTILITY', 'Bard'], ['TOP', 'Akali', 'JUNGLE', 'Udyr', 'MIDDLE', 'Yasuo', 'BOTTOM', 'Draven', 'UTILITY', 'Rakan'], 'Red']
# Matchs ajoutés : 162900
#
# Dernier match ajouté : []
# Matchs ajoutés : 163000
#
# Dernier match ajouté : [['TOP', 'Jayce', 'JUNGLE', 'Naafiri', 'MIDDLE', 'Ahri', 'JUNGLE', 'Taric', 'BOTTOM', 'Kaisa'], ['TOP', 'Aatrox', 'JUNGLE', 'Kindred', 'MIDDLE', 'Vladimir', 'BOTTOM', 'Samira', 'UTILITY', 'Nautilus'], 'Blue']
# Matchs ajoutés : 163100
#
# Dernier match ajouté : [['TOP', 'Aatrox', 'JUNGLE', 'Talon', 'MIDDLE', 'Syndra', 'BOTTOM', 'Kaisa', 'UTILITY', 'Nautilus'], ['TOP', 'Rumble', 'JUNGLE', 'Viego', 'MIDDLE', 'Jayce', 'BOTTOM', 'Tristana', 'UTILITY', 'Leona'], 'Blue']
# Matchs ajoutés : 163200
#
# Dernier match ajouté : [['TOP', 'Olaf', 'JUNGLE', 'Taliyah', 'MIDDLE', 'Tristana', 'BOTTOM', 'Ezreal', 'UTILITY', 'Soraka'], ['TOP', 'Yone', 'JUNGLE', 'Belveth', 'MIDDLE', 'Lissandra', 'BOTTOM', 'Ashe', 'UTILITY', 'Bard'], 'Blue']
# Matchs ajoutés : 163200
#
# Dernier match ajouté : []
# Matchs ajoutés : 163300
#
# Dernier match ajouté : [['TOP', 'Renekton', 'JUNGLE', 'Sejuani', 'MIDDLE', 'Cassiopeia', 'BOTTOM', 'Draven', 'UTILITY', 'Pyke'], ['TOP', 'Rumble', 'JUNGLE', 'Viego', 'MIDDLE', 'Ekko', 'BOTTOM', 'Samira', 'UTILITY', 'Rell'], 'Blue']
# Matchs ajoutés : 163300
#
# Dernier match ajouté : []
# Matchs ajoutés : 163300
#
# Dernier match ajouté : []
# Matchs ajoutés : 163300
#
# Dernier match ajouté : []
# Matchs ajoutés : 163300
#
# Dernier match ajouté : []
# Matchs ajoutés : 163400
#
# Dernier match ajouté : [['TOP', 'Darius', 'JUNGLE', 'Shaco', 'MIDDLE', 'Lissandra', 'BOTTOM', 'Ashe', 'UTILITY', 'Blitzcrank'], ['TOP', 'Renekton', 'JUNGLE', 'Evelynn', 'MIDDLE', 'Jayce', 'BOTTOM', 'Tristana', 'UTILITY', 'Thresh'], 'Red']
# Matchs ajoutés : 163400
#
# Dernier match ajouté : []
# Matchs ajoutés : 163400
#
# Dernier match ajouté : []
# Matchs ajoutés : 163500
#
# Dernier match ajouté : [['TOP', 'Camille', 'JUNGLE', 'Shaco', 'MIDDLE', 'Leblanc', 'BOTTOM', 'Draven', 'UTILITY', 'Pyke'], ['TOP', 'Gwen', 'JUNGLE', 'Nocturne', 'MIDDLE', 'Vladimir', 'BOTTOM', 'Zeri', 'UTILITY', 'Yuumi'], 'Blue']
# Matchs ajoutés : 163500
#
# Dernier match ajouté : []
