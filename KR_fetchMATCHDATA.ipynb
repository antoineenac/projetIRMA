# %%
import requests
import time
import numpy as np
import os

# %%
key = "RGAPI-0bd772e8-d399-4acf-8934-52c0195aa383"

# %%
KR_matchs_id = np.load('MATCHID\KR_matchs_id.npy')

# %%
KR_matchs_data = list(np.load("MATCHDATA\KR_matchs_data.npy",allow_pickle=True))

# %%
len(KR_matchs_data)
# Out:
# 3800

# %%
def add_match(match_id,api_key):
    Match = []
    try:
        req = 'https://asia.api.riotgames.com/lol/match/v5/matches/{}?api_key={}'.format(match_id,api_key)
        time.sleep(0.9)
        r = requests.get(req)
        match_info = r.json()
        if match_info['info']['queueId']==420:
            Blue,Red = [],[]
            players = match_info['info']['participants']
            Winner = "Blue" if players[0]['win'] else "Red"
            for i in range(len(players)):
                if i<5:
                    Blue.append(players[i]['individualPosition'])
                    Blue.append(players[i]['championName'])
                else:
                    Red.append(players[i]['individualPosition'])
                    Red.append(players[i]['championName'])
            Match = [Blue,Red,Winner]
    except:
        pass
    return Match

# %%
def match(key):
    m_idss=KR_matchs_id[len(KR_matchs_data):]
    c=len(KR_matchs_data)
    aux = len(KR_matchs_data)
    for m in m_idss:
        if os.path.exists(os.path.join(os.getcwd(),'stop_true.txt')):
            break
        ma = add_match(m,key)
        if ma!=[]:
            KR_matchs_data.append(ma)
            c+=1
        if c%100==0 or c==aux:
            print("Matchs ajoutés : {}\n".format(c))
            print("Dernier match ajouté : {}".format(ma))
            np.save("MATCHDATA\KR_matchs_data.npy",np.array(KR_matchs_data,dtype=list))

# %%
match(key)
# Out:
# Matchs ajoutés : 3900
#
# Dernier match ajouté : [['TOP', 'Camille', 'JUNGLE', 'Nidalee', 'MIDDLE', 'Corki', 'BOTTOM', 'Kaisa', 'UTILITY', 'Blitzcrank'], ['TOP', 'Rumble', 'JUNGLE', 'Graves', 'BOTTOM', 'Sivir', 'BOTTOM', 'Zoe', 'UTILITY', 'Thresh'], 'Blue']
# Matchs ajoutés : 3900
#
# Dernier match ajouté : []
# Matchs ajoutés : 3900
#
# Dernier match ajouté : []
# Matchs ajoutés : 3900
#
# Dernier match ajouté : []
# Matchs ajoutés : 3900
#
# Dernier match ajouté : []
# Matchs ajoutés : 4000
#
# Dernier match ajouté : [['TOP', 'Kayle', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Karthus', 'BOTTOM', 'Kaisa', 'UTILITY', 'Thresh'], ['TOP', 'Gangplank', 'JUNGLE', 'Evelynn', 'MIDDLE', 'Irelia', 'BOTTOM', 'Sivir', 'UTILITY', 'Maokai'], 'Blue']
# Matchs ajoutés : 4000
#
# Dernier match ajouté : []
# Matchs ajoutés : 4100
#
# Dernier match ajouté : [['TOP', 'Ornn', 'JUNGLE', 'Taliyah', 'MIDDLE', 'Naafiri', 'BOTTOM', 'Ezreal', 'UTILITY', 'Annie'], ['TOP', 'Aatrox', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Gragas', 'BOTTOM', 'Kaisa', 'UTILITY', 'Neeko'], 'Blue']
# Matchs ajoutés : 4200
#
# Dernier match ajouté : [['TOP', 'DrMundo', 'JUNGLE', 'Udyr', 'MIDDLE', 'Yone', 'BOTTOM', 'Kaisa', 'UTILITY', 'Alistar'], ['TOP', 'Gnar', 'JUNGLE', 'Vi', 'MIDDLE', 'Viktor', 'BOTTOM', 'Samira', 'UTILITY', 'Nautilus'], 'Blue']
# Matchs ajoutés : 4300
#
# Dernier match ajouté : [['TOP', 'Jax', 'JUNGLE', 'RekSai', 'MIDDLE', 'Neeko', 'BOTTOM', 'Tristana', 'UTILITY', 'FiddleSticks'], ['TOP', 'Quinn', 'JUNGLE', 'Maokai', 'MIDDLE', 'Naafiri', 'BOTTOM', 'Sivir', 'UTILITY', 'Singed'], 'Red']
# Matchs ajoutés : 4400
#
# Dernier match ajouté : [['TOP', 'Morgana', 'JUNGLE', 'Maokai', 'MIDDLE', 'Jayce', 'BOTTOM', 'Ezreal', 'JUNGLE', 'Soraka'], ['TOP', 'Fiora', 'JUNGLE', 'Hecarim', 'MIDDLE', 'Chogath', 'BOTTOM', 'Kaisa', 'UTILITY', 'Rell'], 'Blue']
# Matchs ajoutés : 4500
#
# Dernier match ajouté : [['TOP', 'Akali', 'JUNGLE', 'RekSai', 'MIDDLE', 'Zed', 'BOTTOM', 'Ezreal', 'UTILITY', 'Braum'], ['TOP', 'Rengar', 'JUNGLE', 'Ivern', 'MIDDLE', 'Malphite', 'BOTTOM', 'Aphelios', 'UTILITY', 'Thresh'], 'Red']
# Matchs ajoutés : 4500
#
# Dernier match ajouté : []
# Matchs ajoutés : 4600
#
# Dernier match ajouté : [['TOP', 'KSante', 'JUNGLE', 'Taliyah', 'MIDDLE', 'Viktor', 'BOTTOM', 'Jhin', 'UTILITY', 'Xerath'], ['TOP', 'Poppy', 'JUNGLE', 'Graves', 'MIDDLE', 'Anivia', 'BOTTOM', 'Ezreal', 'UTILITY', 'Blitzcrank'], 'Red']
# Matchs ajoutés : 4700
#
# Dernier match ajouté : [['TOP', 'Aatrox', 'JUNGLE', 'Elise', 'MIDDLE', 'Yasuo', 'BOTTOM', 'Aphelios', 'UTILITY', 'Rakan'], ['TOP', 'Gnar', 'JUNGLE', 'Viego', 'MIDDLE', 'Vladimir', 'BOTTOM', 'Xayah', 'UTILITY', 'Nautilus'], 'Blue']
# Matchs ajoutés : 4700
#
# Dernier match ajouté : []
# Matchs ajoutés : 4800
#
# Dernier match ajouté : [['TOP', 'Malphite', 'JUNGLE', 'Kindred', 'MIDDLE', 'TwistedFate', 'BOTTOM', 'Lucian', 'UTILITY', 'Nautilus'], ['TOP', 'Udyr', 'JUNGLE', 'RekSai', 'MIDDLE', 'Sylas', 'BOTTOM', 'Ezreal', 'UTILITY', 'Thresh'], 'Blue']
# Matchs ajoutés : 4800
#
# Dernier match ajouté : []
# Matchs ajoutés : 4900
#
# Dernier match ajouté : [['JUNGLE', 'Belveth', 'TOP', 'Sylas', 'MIDDLE', 'Orianna', 'BOTTOM', 'Ashe', 'UTILITY', 'Thresh'], ['TOP', 'Yone', 'JUNGLE', 'Gwen', 'MIDDLE', 'Cassiopeia', 'BOTTOM', 'Ezreal', 'UTILITY', 'Alistar'], 'Blue']
# Matchs ajoutés : 4900
#
# Dernier match ajouté : []
# Matchs ajoutés : 5000
#
# Dernier match ajouté : [['TOP', 'Akali', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Riven', 'BOTTOM', 'Ezreal', 'UTILITY', 'Neeko'], ['TOP', 'Renekton', 'JUNGLE', 'Shaco', 'MIDDLE', 'Swain', 'BOTTOM', 'Xayah', 'UTILITY', 'Sylas'], 'Blue']
# Matchs ajoutés : 5100
#
# Dernier match ajouté : [['TOP', 'Rumble', 'JUNGLE', 'JarvanIV', 'MIDDLE', 'Talon', 'BOTTOM', 'Varus', 'UTILITY', 'Karma'], ['MIDDLE', 'Yasuo', 'JUNGLE', 'Evelynn', 'TOP', 'Nautilus', 'BOTTOM', 'Ashe', 'UTILITY', 'Thresh'], 'Blue']
# Matchs ajoutés : 5100
#
# Dernier match ajouté : []
# Matchs ajoutés : 5200
#
# Dernier match ajouté : [['TOP', 'Heimerdinger', 'JUNGLE', 'Khazix', 'MIDDLE', 'Annie', 'BOTTOM', 'Ezreal', 'UTILITY', 'Bard'], ['TOP', 'Sion', 'JUNGLE', 'Rengar', 'MIDDLE', 'Jayce', 'BOTTOM', 'Kaisa', 'UTILITY', 'Rell'], 'Blue']
# Matchs ajoutés : 5300
#
# Dernier match ajouté : [['TOP', 'Rengar', 'JUNGLE', 'Khazix', 'MIDDLE', 'Yasuo', 'BOTTOM', 'Aphelios', 'UTILITY', 'Milio'], ['TOP', 'Renekton', 'JUNGLE', 'Nidalee', 'MIDDLE', 'Qiyana', 'BOTTOM', 'Xayah', 'UTILITY', 'Rakan'], 'Blue']
# Matchs ajoutés : 5300
#
# Dernier match ajouté : []
# Matchs ajoutés : 5400
#
# Dernier match ajouté : [['TOP', 'Yone', 'JUNGLE', 'Maokai', 'MIDDLE', 'Malzahar', 'BOTTOM', 'Twitch', 'UTILITY', 'Rakan'], ['TOP', 'Urgot', 'JUNGLE', 'JarvanIV', 'MIDDLE', 'Akali', 'BOTTOM', 'Kaisa', 'UTILITY', 'Alistar'], 'Red']
# Matchs ajoutés : 5500
#
# Dernier match ajouté : [['TOP', 'Riven', 'JUNGLE', 'FiddleSticks', 'MIDDLE', 'Tristana', 'BOTTOM', 'Ezreal', 'UTILITY', 'Yuumi'], ['TOP', 'Rumble', 'JUNGLE', 'Elise', 'MIDDLE', 'Zed', 'BOTTOM', 'Sivir', 'UTILITY', 'Thresh'], 'Red']
# Matchs ajoutés : 5600
#
# Dernier match ajouté : [['TOP', 'Sion', 'JUNGLE', 'Ivern', 'MIDDLE', 'Galio', 'BOTTOM', 'Aphelios', 'UTILITY', 'Soraka'], ['TOP', 'Rumble', 'JUNGLE', 'Volibear', 'MIDDLE', 'Talon', 'BOTTOM', 'Ashe', 'UTILITY', 'Rell'], 'Red']
# Matchs ajoutés : 5600
#
# Dernier match ajouté : []
# Matchs ajoutés : 5700
#
# Dernier match ajouté : [['TOP', 'Illaoi', 'JUNGLE', 'Nidalee', 'MIDDLE', 'Talon', 'BOTTOM', 'MissFortune', 'UTILITY', 'Neeko'], ['TOP', 'Maokai', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Zoe', 'BOTTOM', 'Jhin', 'UTILITY', 'Heimerdinger'], 'Blue']
# Matchs ajoutés : 5800
#
# Dernier match ajouté : [['TOP', 'Katarina', 'JUNGLE', 'Taliyah', 'MIDDLE', 'Jayce', 'BOTTOM', 'Varus', 'UTILITY', 'Blitzcrank'], ['TOP', 'Jax', 'JUNGLE', 'LeeSin', 'MIDDLE', 'AurelionSol', 'BOTTOM', 'Swain', 'UTILITY', 'Rell'], 'Red']
# Matchs ajoutés : 5800
#
# Dernier match ajouté : []
# Matchs ajoutés : 5900
#
# Dernier match ajouté : [['TOP', 'Ornn', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Chogath', 'BOTTOM', 'Ashe', 'UTILITY', 'Senna'], ['TOP', 'Yorick', 'JUNGLE', 'Shaco', 'MIDDLE', 'Ahri', 'BOTTOM', 'Kaisa', 'UTILITY', 'Nautilus'], 'Red']
# Matchs ajoutés : 5900
#
# Dernier match ajouté : []
# Matchs ajoutés : 6000
#
# Dernier match ajouté : [['TOP', 'Olaf', 'JUNGLE', 'Diana', 'MIDDLE', 'Aatrox', 'BOTTOM', 'Xayah', 'UTILITY', 'Nautilus'], ['TOP', 'TahmKench', 'JUNGLE', 'Zac', 'MIDDLE', 'Zed', 'BOTTOM', 'Ziggs', 'UTILITY', 'Heimerdinger'], 'Blue']
# Matchs ajoutés : 6100
#
# Dernier match ajouté : [['TOP', 'Heimerdinger', 'JUNGLE', 'Ekko', 'MIDDLE', 'Yone', 'BOTTOM', 'Samira', 'UTILITY', 'Braum'], ['TOP', 'Gnar', 'JUNGLE', 'Maokai', 'MIDDLE', 'Lissandra', 'BOTTOM', 'Xayah', 'UTILITY', 'Rakan'], 'Blue']
# Matchs ajoutés : 6100
#
# Dernier match ajouté : []
# Matchs ajoutés : 6200
#
# Dernier match ajouté : [['TOP', 'Trundle', 'JUNGLE', 'Graves', 'MIDDLE', 'Syndra', 'BOTTOM', 'Ezreal', 'UTILITY', 'Soraka'], ['TOP', 'Rumble', 'JUNGLE', 'Kindred', 'MIDDLE', 'Akali', 'UTILITY', 'Pyke', 'BOTTOM', 'Tristana'], 'Red']
# Matchs ajoutés : 6300
#
# Dernier match ajouté : [['TOP', 'KSante', 'JUNGLE', 'Nidalee', 'MIDDLE', 'Leblanc', 'BOTTOM', 'Kaisa', 'UTILITY', 'Leona'], ['TOP', 'Zac', 'JUNGLE', 'Graves', 'MIDDLE', 'Tristana', 'BOTTOM', 'Vayne', 'UTILITY', 'Soraka'], 'Blue']
# Matchs ajoutés : 6400
#
# Dernier match ajouté : [['TOP', 'Gwen', 'JUNGLE', 'Skarner', 'MIDDLE', 'Lissandra', 'BOTTOM', 'Tristana', 'UTILITY', 'Veigar'], ['TOP', 'Pantheon', 'JUNGLE', 'Taliyah', 'MIDDLE', 'Yasuo', 'BOTTOM', 'Ezreal', 'UTILITY', 'Pyke'], 'Red']
# Matchs ajoutés : 6400
#
# Dernier match ajouté : []
# Matchs ajoutés : 6500
#
# Dernier match ajouté : [['TOP', 'Neeko', 'JUNGLE', 'Kindred', 'MIDDLE', 'Zac', 'BOTTOM', 'Kalista', 'UTILITY', 'Nautilus'], ['TOP', 'Volibear', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Ekko', 'BOTTOM', 'Sivir', 'UTILITY', 'Alistar'], 'Blue']
# Matchs ajoutés : 6600
#
# Dernier match ajouté : [['TOP', 'Renekton', 'JUNGLE', 'Ivern', 'MIDDLE', 'Yone', 'BOTTOM', 'Kaisa', 'UTILITY', 'Morgana'], ['TOP', 'Udyr', 'JUNGLE', 'Sejuani', 'MIDDLE', 'Akali', 'BOTTOM', 'Varus', 'UTILITY', 'Taric'], 'Red']
# Matchs ajoutés : 6600
#
# Dernier match ajouté : []
# Matchs ajoutés : 6700
#
# Dernier match ajouté : [['TOP', 'Fiora', 'JUNGLE', 'Viego', 'MIDDLE', 'Orianna', 'BOTTOM', 'Kaisa', 'UTILITY', 'Alistar'], ['TOP', 'Cassiopeia', 'JUNGLE', 'Elise', 'MIDDLE', 'Irelia', 'BOTTOM', 'Xayah', 'UTILITY', 'Nautilus'], 'Red']
# Matchs ajoutés : 6700
#
# Dernier match ajouté : []
# Matchs ajoutés : 6800
#
# Dernier match ajouté : [['TOP', 'Fiora', 'JUNGLE', 'Graves', 'MIDDLE', 'Cassiopeia', 'BOTTOM', 'Kaisa', 'UTILITY', 'Nautilus'], ['TOP', 'Quinn', 'JUNGLE', 'JarvanIV', 'MIDDLE', 'Vladimir', 'BOTTOM', 'Jinx', 'UTILITY', 'Zilean'], 'Blue']
# Matchs ajoutés : 6900
#
# Dernier match ajouté : [['TOP', 'Darius', 'JUNGLE', 'Zac', 'MIDDLE', 'Taliyah', 'BOTTOM', 'Jhin', 'UTILITY', 'Xerath'], ['TOP', 'Mordekaiser', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Ahri', 'BOTTOM', 'Ezreal', 'UTILITY', 'Alistar'], 'Blue']
# Matchs ajoutés : 7000
#
# Dernier match ajouté : [['TOP', 'Renekton', 'JUNGLE', 'Nidalee', 'MIDDLE', 'Jayce', 'BOTTOM', 'Ezreal', 'UTILITY', 'Shaco'], ['TOP', 'Jax', 'JUNGLE', 'Rengar', 'MIDDLE', 'Anivia', 'BOTTOM', 'Draven', 'UTILITY', 'Blitzcrank'], 'Red']
# Matchs ajoutés : 7000
#
# Dernier match ajouté : []
# Matchs ajoutés : 7100
#
# Dernier match ajouté : [['TOP', 'KSante', 'JUNGLE', 'Viego', 'MIDDLE', 'Ahri', 'BOTTOM', 'Seraphine', 'UTILITY', 'Senna'], ['TOP', 'Cassiopeia', 'JUNGLE', 'Khazix', 'MIDDLE', 'Talon', 'BOTTOM', 'Ashe', 'UTILITY', 'Braum'], 'Blue']
# Matchs ajoutés : 7200
#
# Dernier match ajouté : [['TOP', 'Ornn', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Anivia', 'BOTTOM', 'Aphelios', 'UTILITY', 'Leona'], ['TOP', 'Aatrox', 'JUNGLE', 'Viego', 'MIDDLE', 'Lissandra', 'BOTTOM', 'Ezreal', 'UTILITY', 'Karma'], 'Red']
# Matchs ajoutés : 7300
#
# Dernier match ajouté : [['TOP', 'Aatrox', 'JUNGLE', 'Naafiri', 'MIDDLE', 'Xerath', 'BOTTOM', 'Aphelios', 'UTILITY', 'Leona'], ['TOP', 'Quinn', 'JUNGLE', 'JarvanIV', 'MIDDLE', 'Orianna', 'UTILITY', 'Blitzcrank', 'BOTTOM', 'Xayah'], 'Red']
# Matchs ajoutés : 7400
#
# Dernier match ajouté : [['TOP', 'Shyvana', 'JUNGLE', 'Taliyah', 'MIDDLE', 'TwistedFate', 'BOTTOM', 'Ezreal', 'UTILITY', 'Pyke'], ['TOP', 'Olaf', 'JUNGLE', 'JarvanIV', 'MIDDLE', 'Ahri', 'BOTTOM', 'Zeri', 'UTILITY', 'Zac'], 'Blue']
# Matchs ajoutés : 7500
#
# Dernier match ajouté : [['TOP', 'Akali', 'JUNGLE', 'Hecarim', 'MIDDLE', 'Naafiri', 'BOTTOM', 'Ashe', 'UTILITY', 'Nautilus'], ['TOP', 'Renekton', 'JUNGLE', 'Khazix', 'MIDDLE', 'Lissandra', 'BOTTOM', 'Ezreal', 'UTILITY', 'Zyra'], 'Blue']
# Matchs ajoutés : 7600
#
# Dernier match ajouté : [['TOP', 'Kayle', 'JUNGLE', 'Udyr', 'MIDDLE', 'Tristana', 'BOTTOM', 'Xayah', 'UTILITY', 'Rengar'], ['TOP', 'Darius', 'JUNGLE', 'Graves', 'MIDDLE', 'Ekko', 'BOTTOM', 'Aphelios', 'UTILITY', 'Thresh'], 'Red']
# Matchs ajoutés : 7600
#
# Dernier match ajouté : []
# Matchs ajoutés : 7700
#
# Dernier match ajouté : [['TOP', 'Sion', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Xerath', 'BOTTOM', 'Kaisa', 'UTILITY', 'Rakan'], ['TOP', 'Shen', 'JUNGLE', 'Khazix', 'MIDDLE', 'Leblanc', 'BOTTOM', 'MissFortune', 'UTILITY', 'Thresh'], 'Blue']
# Matchs ajoutés : 7800
#
# Dernier match ajouté : [['TOP', 'Rengar', 'JUNGLE', 'Zac', 'MIDDLE', 'Fizz', 'BOTTOM', 'Samira', 'UTILITY', 'Nautilus'], ['TOP', 'Heimerdinger', 'JUNGLE', 'Khazix', 'MIDDLE', 'Swain', 'BOTTOM', 'Kaisa', 'UTILITY', 'Rell'], 'Red']
# Matchs ajoutés : 7900
#
# Dernier match ajouté : [['MIDDLE', 'Fizz', 'JUNGLE', 'Viego', 'TOP', 'Volibear', 'BOTTOM', 'Ashe', 'UTILITY', 'Zac'], ['TOP', 'Cassiopeia', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Vex', 'BOTTOM', 'Kaisa', 'UTILITY', 'Thresh'], 'Blue']
# Matchs ajoutés : 8000
#
# Dernier match ajouté : [['TOP', 'KSante', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Leblanc', 'BOTTOM', 'Draven', 'UTILITY', 'Alistar'], ['TOP', 'Gangplank', 'JUNGLE', 'RekSai', 'MIDDLE', 'Ahri', 'BOTTOM', 'Ezreal', 'UTILITY', 'Gragas'], 'Red']
# Matchs ajoutés : 8000
#
# Dernier match ajouté : []
# Matchs ajoutés : 8100
#
# Dernier match ajouté : [['TOP', 'Aatrox', 'JUNGLE', 'Neeko', 'MIDDLE', 'Orianna', 'BOTTOM', 'Zeri', 'UTILITY', 'Nautilus'], ['MIDDLE', 'Irelia', 'JUNGLE', 'Poppy', 'TOP', 'Jax', 'BOTTOM', 'Kaisa', 'UTILITY', 'Rakan'], 'Red']
# Matchs ajoutés : 8200
#
# Dernier match ajouté : [['TOP', 'Jax', 'JUNGLE', 'Nunu', 'MIDDLE', 'Jayce', 'BOTTOM', 'Kaisa', 'UTILITY', 'Rell'], ['TOP', 'Rumble', 'JUNGLE', 'Ivern', 'MIDDLE', 'Yone', 'BOTTOM', 'Xayah', 'UTILITY', 'Gragas'], 'Blue']
# Matchs ajoutés : 8200
#
# Dernier match ajouté : []
# Matchs ajoutés : 8200
#
# Dernier match ajouté : []
# Matchs ajoutés : 8300
#
# Dernier match ajouté : [['TOP', 'Malphite', 'JUNGLE', 'Taliyah', 'MIDDLE', 'Irelia', 'BOTTOM', 'Kaisa', 'UTILITY', 'Blitzcrank'], ['TOP', 'Shen', 'JUNGLE', 'Poppy', 'MIDDLE', 'Sylas', 'BOTTOM', 'Ezreal', 'UTILITY', 'Karma'], 'Red']
# Matchs ajoutés : 8400
#
# Dernier match ajouté : [['TOP', 'Fiora', 'JUNGLE', 'Khazix', 'MIDDLE', 'Ekko', 'BOTTOM', 'Samira', 'UTILITY', 'Leona'], ['TOP', 'Poppy', 'JUNGLE', 'Hecarim', 'MIDDLE', 'KSante', 'BOTTOM', 'Kaisa', 'UTILITY', 'Xerath'], 'Red']
# Matchs ajoutés : 8500
#
# Dernier match ajouté : [['TOP', 'Fiora', 'JUNGLE', 'Gragas', 'MIDDLE', 'Talon', 'BOTTOM', 'Sivir', 'UTILITY', 'Nautilus'], ['TOP', 'Poppy', 'JUNGLE', 'Lillia', 'MIDDLE', 'Qiyana', 'BOTTOM', 'Zeri', 'UTILITY', 'Braum'], 'Red']
# Matchs ajoutés : 8500
#
# Dernier match ajouté : []
# Matchs ajoutés : 8600
#
# Dernier match ajouté : [['TOP', 'DrMundo', 'JUNGLE', 'Rengar', 'MIDDLE', 'Tristana', 'BOTTOM', 'Kaisa', 'UTILITY', 'Zyra'], ['TOP', 'Jax', 'JUNGLE', 'Nidalee', 'MIDDLE', 'Yasuo', 'BOTTOM', 'Nilah', 'UTILITY', 'Pyke'], 'Red']
# Matchs ajoutés : 8700
#
# Dernier match ajouté : [['TOP', 'Camille', 'JUNGLE', 'Nidalee', 'MIDDLE', 'Annie', 'BOTTOM', 'Zeri', 'UTILITY', 'Pyke'], ['TOP', 'Fiora', 'JUNGLE', 'Viego', 'MIDDLE', 'Zoe', 'BOTTOM', 'Kaisa', 'UTILITY', 'Zac'], 'Red']
# Matchs ajoutés : 8800
#
# Dernier match ajouté : [['TOP', 'Rumble', 'JUNGLE', 'Graves', 'MIDDLE', 'Ahri', 'BOTTOM', 'Zeri', 'UTILITY', 'Brand'], ['TOP', 'Jayce', 'JUNGLE', 'Viego', 'MIDDLE', 'Neeko', 'BOTTOM', 'MissFortune', 'UTILITY', 'Thresh'], 'Blue']
# Matchs ajoutés : 8900
#
# Dernier match ajouté : [['TOP', 'Nasus', 'JUNGLE', 'Ekko', 'MIDDLE', 'Zed', 'BOTTOM', 'Samira', 'UTILITY', 'Rell'], ['TOP', 'Aatrox', 'JUNGLE', 'Sion', 'MIDDLE', 'Viego', 'BOTTOM', 'Jhin', 'UTILITY', 'Renata'], 'Red']
# Matchs ajoutés : 9000
#
# Dernier match ajouté : [['TOP', 'Udyr', 'JUNGLE', 'Graves', 'MIDDLE', 'Neeko', 'BOTTOM', 'Samira', 'UTILITY', 'Rell'], ['TOP', 'Illaoi', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Leblanc', 'BOTTOM', 'Kaisa', 'UTILITY', 'Rakan'], 'Blue']
# Matchs ajoutés : 9100
#
# Dernier match ajouté : [['TOP', 'Jax', 'JUNGLE', 'Viego', 'MIDDLE', 'Qiyana', 'BOTTOM', 'Samira', 'UTILITY', 'Rell'], ['JUNGLE', 'Taric', 'JUNGLE', 'Khazix', 'MIDDLE', 'Azir', 'BOTTOM', 'Kaisa', 'UTILITY', 'Blitzcrank'], 'Red']
# Matchs ajoutés : 9100
#
# Dernier match ajouté : []
# Matchs ajoutés : 9100
#
# Dernier match ajouté : []
# Matchs ajoutés : 9200
#
# Dernier match ajouté : [['TOP', 'Jax', 'JUNGLE', 'Viego', 'MIDDLE', 'Swain', 'BOTTOM', 'Kaisa', 'UTILITY', 'Alistar'], ['TOP', 'Darius', 'JUNGLE', 'Kindred', 'MIDDLE', 'Zeri', 'BOTTOM', 'Aphelios', 'UTILITY', 'Rell'], 'Red']
# Matchs ajoutés : 9300
#
# Dernier match ajouté : [['TOP', 'Fiora', 'JUNGLE', 'Khazix', 'MIDDLE', 'Sylas', 'BOTTOM', 'Kaisa', 'UTILITY', 'Blitzcrank'], ['TOP', 'Jayce', 'JUNGLE', 'Belveth', 'UTILITY', 'Karma', 'BOTTOM', 'Ezreal', 'MIDDLE', 'Azir'], 'Red']
# Matchs ajoutés : 9400
#
# Dernier match ajouté : [['TOP', 'Jayce', 'JUNGLE', 'Shaco', 'MIDDLE', 'Ahri', 'BOTTOM', 'Jhin', 'UTILITY', 'Rakan'], ['TOP', 'Camille', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Lissandra', 'BOTTOM', 'Ezreal', 'UTILITY', 'Brand'], 'Red']
# Matchs ajoutés : 9500
#
# Dernier match ajouté : [['TOP', 'Akali', 'JUNGLE', 'Graves', 'MIDDLE', 'KSante', 'UTILITY', 'Ezreal', 'BOTTOM', 'Yasuo'], ['TOP', 'Mordekaiser', 'JUNGLE', 'Sylas', 'MIDDLE', 'TwistedFate', 'BOTTOM', 'Samira', 'UTILITY', 'Blitzcrank'], 'Red']
# Matchs ajoutés : 9500
#
# Dernier match ajouté : []
# Matchs ajoutés : 9600
#
# Dernier match ajouté : [['TOP', 'Renekton', 'JUNGLE', 'JarvanIV', 'MIDDLE', 'Lissandra', 'BOTTOM', 'Kaisa', 'UTILITY', 'Lux'], ['TOP', 'Leblanc', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Katarina', 'BOTTOM', 'Xayah', 'UTILITY', 'Nautilus'], 'Blue']
# Matchs ajoutés : 9700
#
# Dernier match ajouté : [['TOP', 'Renekton', 'JUNGLE', 'Viego', 'MIDDLE', 'Vex', 'BOTTOM', 'Ezreal', 'UTILITY', 'Shaco'], ['TOP', 'Quinn', 'JUNGLE', 'Kayn', 'MIDDLE', 'Leblanc', 'BOTTOM', 'Jhin', 'UTILITY', 'Rell'], 'Blue']
# Matchs ajoutés : 9800
#
# Dernier match ajouté : [['TOP', 'Kennen', 'JUNGLE', 'Rengar', 'MIDDLE', 'Katarina', 'BOTTOM', 'Tristana', 'UTILITY', 'Nautilus'], ['TOP', 'Yorick', 'JUNGLE', 'LeeSin', 'Invalid', 'Neeko', 'BOTTOM', 'Kaisa', 'UTILITY', 'Maokai'], 'Blue']
# Matchs ajoutés : 9900
#
# Dernier match ajouté : [['TOP', 'Aatrox', 'JUNGLE', 'Viego', 'MIDDLE', 'Leblanc', 'BOTTOM', 'Jhin', 'UTILITY', 'Karma'], ['TOP', 'Irelia', 'JUNGLE', 'Karthus', 'MIDDLE', 'Talon', 'BOTTOM', 'Ezreal', 'UTILITY', 'Thresh'], 'Blue']
# Matchs ajoutés : 10000
#
# Dernier match ajouté : [['TOP', 'Riven', 'JUNGLE', 'Zac', 'MIDDLE', 'Leblanc', 'BOTTOM', 'Aphelios', 'UTILITY', 'Soraka'], ['TOP', 'Jax', 'JUNGLE', 'Kayn', 'MIDDLE', 'Ahri', 'BOTTOM', 'Ezreal', 'UTILITY', 'Karma'], 'Red']
# Matchs ajoutés : 10100
#
# Dernier match ajouté : [['TOP', 'Fiora', 'JUNGLE', 'Graves', 'MIDDLE', 'Sylas', 'BOTTOM', 'Kaisa', 'UTILITY', 'Lulu'], ['TOP', 'Maokai', 'JUNGLE', 'Kindred', 'MIDDLE', 'Katarina', 'BOTTOM', 'Xayah', 'UTILITY', 'Alistar'], 'Blue']
# Matchs ajoutés : 10100
#
# Dernier match ajouté : []
# Matchs ajoutés : 10100
#
# Dernier match ajouté : []
# Matchs ajoutés : 10200
#
# Dernier match ajouté : [['TOP', 'Renekton', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Sylas', 'BOTTOM', 'Xayah', 'UTILITY', 'Rakan'], ['TOP', 'Gnar', 'JUNGLE', 'Neeko', 'MIDDLE', 'Yasuo', 'BOTTOM', 'Kaisa', 'UTILITY', 'Annie'], 'Blue']
# Matchs ajoutés : 10300
#
# Dernier match ajouté : [['TOP', 'Jax', 'JUNGLE', 'Shaco', 'MIDDLE', 'TwistedFate', 'BOTTOM', 'Ezreal', 'UTILITY', 'Karma'], ['TOP', 'Singed', 'JUNGLE', 'Nidalee', 'MIDDLE', 'Yasuo', 'BOTTOM', 'Xayah', 'UTILITY', 'Rakan'], 'Red']
# Matchs ajoutés : 10400
#
# Dernier match ajouté : [['TOP', 'Quinn', 'JUNGLE', 'Neeko', 'MIDDLE', 'Talon', 'BOTTOM', 'Ashe', 'UTILITY', 'Karma'], ['TOP', 'Cassiopeia', 'JUNGLE', 'Khazix', 'MIDDLE', 'Jayce', 'BOTTOM', 'Ezreal', 'UTILITY', 'Rakan'], 'Red']
# Matchs ajoutés : 10500
#
# Dernier match ajouté : [['TOP', 'Rengar', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Ivern', 'BOTTOM', 'Jinx', 'UTILITY', 'Alistar'], ['TOP', 'Tryndamere', 'JUNGLE', 'Shaco', 'MIDDLE', 'Annie', 'BOTTOM', 'Xayah', 'UTILITY', 'Thresh'], 'Blue']
# Matchs ajoutés : 10600
#
# Dernier match ajouté : [['TOP', 'Nasus', 'JUNGLE', 'Talon', 'MIDDLE', 'Azir', 'BOTTOM', 'Caitlyn', 'UTILITY', 'Lux'], ['TOP', 'Teemo', 'JUNGLE', 'Viego', 'MIDDLE', 'Xerath', 'BOTTOM', 'Draven', 'UTILITY', 'Seraphine'], 'Red']
# Matchs ajoutés : 10700
#
# Dernier match ajouté : [['TOP', 'Yasuo', 'JUNGLE', 'Rammus', 'MIDDLE', 'Yone', 'BOTTOM', 'Jinx', 'UTILITY', 'Thresh'], ['TOP', 'Jayce', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Lissandra', 'BOTTOM', 'Aphelios', 'UTILITY', 'Nautilus'], 'Red']
# Matchs ajoutés : 10800
#
# Dernier match ajouté : [['TOP', 'Camille', 'JUNGLE', 'Viego', 'MIDDLE', 'Ornn', 'BOTTOM', 'Draven', 'UTILITY', 'Blitzcrank'], ['TOP', 'Yone', 'JUNGLE', 'Rumble', 'MIDDLE', 'Zoe', 'BOTTOM', 'Kaisa', 'UTILITY', 'Rell'], 'Blue']
# Matchs ajoutés : 10800
#
# Dernier match ajouté : []
# Matchs ajoutés : 10900
#
# Dernier match ajouté : [['TOP', 'KSante', 'JUNGLE', 'Volibear', 'MIDDLE', 'Lissandra', 'BOTTOM', 'Draven', 'UTILITY', 'Pyke'], ['TOP', 'Singed', 'JUNGLE', 'Viego', 'MIDDLE', 'Sion', 'BOTTOM', 'Aphelios', 'UTILITY', 'Braum'], 'Red']
# Matchs ajoutés : 11000
#
# Dernier match ajouté : [['TOP', 'Jayce', 'JUNGLE', 'Nidalee', 'MIDDLE', 'Akali', 'BOTTOM', 'Kaisa', 'UTILITY', 'Zyra'], ['TOP', 'Fiora', 'JUNGLE', 'Belveth', 'MIDDLE', 'Sylas', 'BOTTOM', 'Ezreal', 'UTILITY', 'Karma'], 'Blue']
# Matchs ajoutés : 11100
#
# Dernier match ajouté : [['TOP', 'Gangplank', 'JUNGLE', 'Amumu', 'MIDDLE', 'Cassiopeia', 'BOTTOM', 'Ezreal', 'UTILITY', 'Pyke'], ['TOP', 'Irelia', 'JUNGLE', 'Kindred', 'MIDDLE', 'Kennen', 'BOTTOM', 'Kaisa', 'UTILITY', 'Lux'], 'Blue']
# Matchs ajoutés : 11100
#
# Dernier match ajouté : []
# Matchs ajoutés : 11100
#
# Dernier match ajouté : []
# Matchs ajoutés : 11100
#
# Dernier match ajouté : []
# Matchs ajoutés : 11100
#
# Dernier match ajouté : []
# Matchs ajoutés : 11100
#
# Dernier match ajouté : []
# Matchs ajoutés : 11200
#
# Dernier match ajouté : [['UTILITY', 'KSante', 'JUNGLE', 'Nunu', 'MIDDLE', 'Irelia', 'BOTTOM', 'Ezreal', 'TOP', 'Singed'], ['TOP', 'Garen', 'JUNGLE', 'Karthus', 'MIDDLE', 'Annie', 'BOTTOM', 'Xayah', 'UTILITY', 'Nautilus'], 'Blue']
# Matchs ajoutés : 11200
#
# Dernier match ajouté : []
# Matchs ajoutés : 11300
#
# Dernier match ajouté : [['TOP', 'Sejuani', 'JUNGLE', 'Khazix', 'MIDDLE', 'Annie', 'BOTTOM', 'Jinx', 'UTILITY', 'Rakan'], ['TOP', 'Poppy', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Zoe', 'BOTTOM', 'Ezreal', 'UTILITY', 'Heimerdinger'], 'Red']
# Matchs ajoutés : 11400
#
# Dernier match ajouté : [['TOP', 'Renekton', 'JUNGLE', 'Taliyah', 'MIDDLE', 'Yasuo', 'BOTTOM', 'Ezreal', 'UTILITY', 'Nautilus'], ['TOP', 'Garen', 'JUNGLE', 'Sylas', 'MIDDLE', 'Talon', 'BOTTOM', 'Caitlyn', 'UTILITY', 'Thresh'], 'Red']
# Matchs ajoutés : 11500
#
# Dernier match ajouté : [['TOP', 'Belveth', 'JUNGLE', 'Elise', 'MIDDLE', 'Yone', 'BOTTOM', 'Draven', 'UTILITY', 'Nautilus'], ['TOP', 'Jax', 'JUNGLE', 'MasterYi', 'MIDDLE', 'Azir', 'BOTTOM', 'Ezreal', 'UTILITY', 'Yuumi'], 'Blue']
# Matchs ajoutés : 11600
#
# Dernier match ajouté : [['TOP', 'Jax', 'JUNGLE', 'Viego', 'MIDDLE', 'Ahri', 'BOTTOM', 'Lucian', 'UTILITY', 'Shaco'], ['TOP', 'Darius', 'JUNGLE', 'Ivern', 'MIDDLE', 'AurelionSol', 'BOTTOM', 'Samira', 'UTILITY', 'Nautilus'], 'Blue']
# Matchs ajoutés : 11700
#
# Dernier match ajouté : [['TOP', 'Lucian', 'JUNGLE', 'Vi', 'MIDDLE', 'Ahri', 'BOTTOM', 'Xayah', 'UTILITY', 'Rakan'], ['TOP', 'Malphite', 'JUNGLE', 'Taliyah', 'MIDDLE', 'Gangplank', 'BOTTOM', 'Kaisa', 'UTILITY', 'Nautilus'], 'Blue']
# Matchs ajoutés : 11800
#
# Dernier match ajouté : [['TOP', 'Fiora', 'JUNGLE', 'Nocturne', 'MIDDLE', 'Xerath', 'BOTTOM', 'Xayah', 'UTILITY', 'Rakan'], ['TOP', 'Kayle', 'JUNGLE', 'Shyvana', 'MIDDLE', 'Cassiopeia', 'BOTTOM', 'Varus', 'UTILITY', 'Seraphine'], 'Blue']
# Matchs ajoutés : 11900
#
# Dernier match ajouté : [['TOP', 'Aatrox', 'JUNGLE', 'Poppy', 'MIDDLE', 'Azir', 'BOTTOM', 'Kaisa', 'UTILITY', 'Rell'], ['TOP', 'Shen', 'JUNGLE', 'JarvanIV', 'MIDDLE', 'Akali', 'BOTTOM', 'Varus', 'UTILITY', 'Rakan'], 'Blue']
# Matchs ajoutés : 12000
#
# Dernier match ajouté : [['TOP', 'KSante', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Leblanc', 'BOTTOM', 'Caitlyn', 'UTILITY', 'Alistar'], ['TOP', 'Poppy', 'JUNGLE', 'Graves', 'MIDDLE', 'Jayce', 'BOTTOM', 'Sivir', 'UTILITY', 'Rakan'], 'Blue']
# Matchs ajoutés : 12100
#
# Dernier match ajouté : [['TOP', 'Renekton', 'JUNGLE', 'Viego', 'MIDDLE', 'Lissandra', 'BOTTOM', 'Xayah', 'UTILITY', 'Rell'], ['TOP', 'Poppy', 'JUNGLE', 'Volibear', 'MIDDLE', 'Katarina', 'BOTTOM', 'Kaisa', 'UTILITY', 'Thresh'], 'Blue']
# Matchs ajoutés : 12200
#
# Dernier match ajouté : [['TOP', 'Zac', 'JUNGLE', 'Qiyana', 'MIDDLE', 'Sylas', 'BOTTOM', 'Kaisa', 'UTILITY', 'Thresh'], ['TOP', 'Aatrox', 'JUNGLE', 'Nunu', 'MIDDLE', 'RekSai', 'BOTTOM', 'Ezreal', 'UTILITY', 'Blitzcrank'], 'Blue']
# Matchs ajoutés : 12200
#
# Dernier match ajouté : []
# Matchs ajoutés : 12200
#
# Dernier match ajouté : []
# Matchs ajoutés : 12300
#
# Dernier match ajouté : [['TOP', 'Zac', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Orianna', 'BOTTOM', 'Aphelios', 'UTILITY', 'Xerath'], ['TOP', 'Maokai', 'JUNGLE', 'Graves', 'MIDDLE', 'Syndra', 'BOTTOM', 'Ezreal', 'UTILITY', 'Soraka'], 'Red']
# Matchs ajoutés : 12400
#
# Dernier match ajouté : [['TOP', 'Ornn', 'JUNGLE', 'Karthus', 'MIDDLE', 'Jayce', 'BOTTOM', 'Ezreal', 'UTILITY', 'Karma'], ['TOP', 'Shen', 'JUNGLE', 'JarvanIV', 'MIDDLE', 'Cassiopeia', 'BOTTOM', 'Kaisa', 'UTILITY', 'Nautilus'], 'Blue']
# Matchs ajoutés : 12400
#
# Dernier match ajouté : []
# Matchs ajoutés : 12500
#
# Dernier match ajouté : [['TOP', 'Aatrox', 'JUNGLE', 'Maokai', 'MIDDLE', 'Orianna', 'BOTTOM', 'Xayah', 'UTILITY', 'Blitzcrank'], ['TOP', 'Jayce', 'JUNGLE', 'Gragas', 'MIDDLE', 'Naafiri', 'BOTTOM', 'Ezreal', 'UTILITY', 'Alistar'], 'Red']
# Matchs ajoutés : 12500
#
# Dernier match ajouté : []
# Matchs ajoutés : 12600
#
# Dernier match ajouté : [['TOP', 'Renekton', 'JUNGLE', 'Taliyah', 'MIDDLE', 'Ahri', 'BOTTOM', 'Kaisa', 'UTILITY', 'Sona'], ['TOP', 'Darius', 'JUNGLE', 'Graves', 'MIDDLE', 'Zoe', 'BOTTOM', 'Ziggs', 'UTILITY', 'Heimerdinger'], 'Red']
# Matchs ajoutés : 12700
#
# Dernier match ajouté : [['TOP', 'Singed', 'JUNGLE', 'Belveth', 'MIDDLE', 'Vex', 'BOTTOM', 'Ezreal', 'UTILITY', 'Seraphine'], ['TOP', 'Irelia', 'JUNGLE', 'Nidalee', 'MIDDLE', 'Neeko', 'BOTTOM', 'Kaisa', 'UTILITY', 'Lux'], 'Red']
# Matchs ajoutés : 12700
#
# Dernier match ajouté : []
# Matchs ajoutés : 12800
#
# Dernier match ajouté : [['TOP', 'Renekton', 'JUNGLE', 'Poppy', 'MIDDLE', 'Leblanc', 'BOTTOM', 'Samira', 'UTILITY', 'Alistar'], ['TOP', 'KSante', 'JUNGLE', 'Kindred', 'MIDDLE', 'Annie', 'BOTTOM', 'Kaisa', 'UTILITY', 'Leona'], 'Blue']
# Matchs ajoutés : 12900
#
# Dernier match ajouté : [['TOP', 'Jax', 'JUNGLE', 'Ekko', 'MIDDLE', 'Zed', 'BOTTOM', 'Samira', 'UTILITY', 'Nautilus'], ['TOP', 'Illaoi', 'JUNGLE', 'Sylas', 'MIDDLE', 'Skarner', 'BOTTOM', 'Ashe', 'UTILITY', 'Braum'], 'Red']
# Matchs ajoutés : 13000
#
# Dernier match ajouté : [['TOP', 'Yone', 'JUNGLE', 'Nidalee', 'MIDDLE', 'Viktor', 'BOTTOM', 'Zeri', 'UTILITY', 'Blitzcrank'], ['TOP', 'Warwick', 'JUNGLE', 'Sylas', 'MIDDLE', 'Akali', 'BOTTOM', 'Kaisa', 'UTILITY', 'Thresh'], 'Blue']
# Matchs ajoutés : 13000
#
# Dernier match ajouté : []
# Matchs ajoutés : 13100
#
# Dernier match ajouté : [['TOP', 'Kennen', 'JUNGLE', 'Graves', 'MIDDLE', 'Akali', 'BOTTOM', 'Zeri', 'UTILITY', 'Karma'], ['TOP', 'Poppy', 'JUNGLE', 'Ivern', 'MIDDLE', 'Sylas', 'BOTTOM', 'Ezreal', 'UTILITY', 'Rakan'], 'Red']
# Matchs ajoutés : 13100
#
# Dernier match ajouté : []
# Matchs ajoutés : 13200
#
# Dernier match ajouté : [['TOP', 'Urgot', 'JUNGLE', 'LeeSin', 'MIDDLE', 'AurelionSol', 'BOTTOM', 'Ashe', 'UTILITY', 'Sona'], ['TOP', 'Pantheon', 'JUNGLE', 'Shaco', 'MIDDLE', 'Leblanc', 'BOTTOM', 'Jinx', 'UTILITY', 'Nautilus'], 'Red']
# Matchs ajoutés : 13200
#
# Dernier match ajouté : []
# Matchs ajoutés : 13300
#
# Dernier match ajouté : [['TOP', 'Zac', 'JUNGLE', 'Maokai', 'MIDDLE', 'Yone', 'BOTTOM', 'Kaisa', 'UTILITY', 'Rakan'], ['TOP', 'Volibear', 'JUNGLE', 'Nidalee', 'MIDDLE', 'Akali', 'BOTTOM', 'Samira', 'UTILITY', 'Rell'], 'Blue']
# Matchs ajoutés : 13300
#
# Dernier match ajouté : []
# Matchs ajoutés : 13400
#
# Dernier match ajouté : [['TOP', 'Darius', 'JUNGLE', 'RekSai', 'MIDDLE', 'Azir', 'BOTTOM', 'Xayah', 'UTILITY', 'Lulu'], ['TOP', 'Nasus', 'JUNGLE', 'Maokai', 'MIDDLE', 'Cassiopeia', 'BOTTOM', 'Twitch', 'UTILITY', 'Shaco'], 'Blue']
# Matchs ajoutés : 13500
#
# Dernier match ajouté : [['TOP', 'Nasus', 'JUNGLE', 'FiddleSticks', 'MIDDLE', 'Leblanc', 'BOTTOM', 'Xayah', 'UTILITY', 'Blitzcrank'], ['TOP', 'MonkeyKing', 'JUNGLE', 'Sylas', 'MIDDLE', 'Tristana', 'BOTTOM', 'Sivir', 'UTILITY', 'Xerath'], 'Blue']
# Matchs ajoutés : 13600
#
# Dernier match ajouté : [['TOP', 'Illaoi', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Yone', 'BOTTOM', 'Ezreal', 'UTILITY', 'Heimerdinger'], ['TOP', 'Kayle', 'JUNGLE', 'Khazix', 'MIDDLE', 'Zed', 'BOTTOM', 'Kaisa', 'UTILITY', 'Leona'], 'Red']
# Matchs ajoutés : 13700
#
# Dernier match ajouté : [['TOP', 'Kled', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Leblanc', 'BOTTOM', 'Ezreal', 'UTILITY', 'Nautilus'], ['TOP', 'Camille', 'JUNGLE', 'Khazix', 'MIDDLE', 'Viktor', 'BOTTOM', 'Kaisa', 'UTILITY', 'Janna'], 'Blue']
# Matchs ajoutés : 13700
#
# Dernier match ajouté : []
# Matchs ajoutés : 13800
#
# Dernier match ajouté : [['TOP', 'Aatrox', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Neeko', 'BOTTOM', 'Xayah', 'UTILITY', 'Nautilus'], ['TOP', 'Yone', 'JUNGLE', 'Graves', 'MIDDLE', 'Rumble', 'BOTTOM', 'Kaisa', 'UTILITY', 'Morgana'], 'Blue']
# Matchs ajoutés : 13900
#
# Dernier match ajouté : [['TOP', 'KSante', 'JUNGLE', 'Kindred', 'MIDDLE', 'Katarina', 'BOTTOM', 'Samira', 'UTILITY', 'Nautilus'], ['TOP', 'Zac', 'JUNGLE', 'Taliyah', 'MIDDLE', 'Tristana', 'BOTTOM', 'Twitch', 'UTILITY', 'Thresh'], 'Blue']
# Matchs ajoutés : 14000
#
# Dernier match ajouté : [['TOP', 'Poppy', 'JUNGLE', 'Sylas', 'MIDDLE', 'Qiyana', 'BOTTOM', 'Kalista', 'UTILITY', 'Pyke'], ['TOP', 'Karthus', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Jayce', 'BOTTOM', 'Aphelios', 'UTILITY', 'Gragas'], 'Red']
# Matchs ajoutés : 14000
#
# Dernier match ajouté : []
# Matchs ajoutés : 14100
#
# Dernier match ajouté : [['TOP', 'Jayce', 'JUNGLE', 'Maokai', 'MIDDLE', 'Azir', 'BOTTOM', 'Samira', 'UTILITY', 'Rell'], ['TOP', 'KSante', 'JUNGLE', 'Belveth', 'MIDDLE', 'Vladimir', 'BOTTOM', 'Kaisa', 'UTILITY', 'Pantheon'], 'Blue']
# Matchs ajoutés : 14200
#
# Dernier match ajouté : [['TOP', 'Darius', 'JUNGLE', 'Jax', 'MIDDLE', 'Taliyah', 'BOTTOM', 'Ashe', 'UTILITY', 'Taric'], ['TOP', 'KSante', 'JUNGLE', 'Poppy', 'MIDDLE', 'Fizz', 'BOTTOM', 'Samira', 'UTILITY', 'Thresh'], 'Blue']
# Matchs ajoutés : 14200
#
# Dernier match ajouté : []
# Matchs ajoutés : 14200
#
# Dernier match ajouté : []
# Matchs ajoutés : 14300
#
# Dernier match ajouté : [['TOP', 'Jayce', 'JUNGLE', 'Hecarim', 'MIDDLE', 'TwistedFate', 'BOTTOM', 'Aphelios', 'UTILITY', 'Karma'], ['TOP', 'Kayle', 'JUNGLE', 'XinZhao', 'MIDDLE', 'Varus', 'BOTTOM', 'Kaisa', 'UTILITY', 'Amumu'], 'Blue']
# Matchs ajoutés : 14400
#
# Dernier match ajouté : [['TOP', 'Riven', 'JUNGLE', 'Kindred', 'MIDDLE', 'Sylas', 'BOTTOM', 'Xayah', 'UTILITY', 'Morgana'], ['TOP', 'Rumble', 'JUNGLE', 'MasterYi', 'MIDDLE', 'Neeko', 'BOTTOM', 'Aphelios', 'UTILITY', 'Alistar'], 'Blue']
# Matchs ajoutés : 14400
#
# Dernier match ajouté : []
# Matchs ajoutés : 14500
#
# Dernier match ajouté : [['TOP', 'Irelia', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Ahri', 'BOTTOM', 'Jhin', 'UTILITY', 'Xerath'], ['TOP', 'Malphite', 'JUNGLE', 'FiddleSticks', 'MIDDLE', 'Talon', 'BOTTOM', 'Lucian', 'UTILITY', 'Milio'], 'Red']
# Matchs ajoutés : 14600
#
# Dernier match ajouté : [['TOP', 'Aatrox', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Orianna', 'BOTTOM', 'MissFortune', 'UTILITY', 'Alistar'], ['TOP', 'Jax', 'JUNGLE', 'Viego', 'MIDDLE', 'Katarina', 'BOTTOM', 'Kaisa', 'UTILITY', 'Rell'], 'Blue']
# Matchs ajoutés : 14600
#
# Dernier match ajouté : []
# Matchs ajoutés : 14700
#
# Dernier match ajouté : [['TOP', 'Renekton', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Shaco', 'BOTTOM', 'Kaisa', 'UTILITY', 'Rell'], ['TOP', 'Camille', 'JUNGLE', 'RekSai', 'MIDDLE', 'Naafiri', 'BOTTOM', 'Kalista', 'UTILITY', 'Blitzcrank'], 'Red']
# Matchs ajoutés : 14800
#
# Dernier match ajouté : [['TOP', 'Aatrox', 'JUNGLE', 'Ekko', 'MIDDLE', 'Qiyana', 'BOTTOM', 'Tristana', 'UTILITY', 'Maokai'], ['TOP', 'Irelia', 'JUNGLE', 'JarvanIV', 'MIDDLE', 'Katarina', 'BOTTOM', 'Draven', 'UTILITY', 'Blitzcrank'], 'Blue']
# Matchs ajoutés : 14800
#
# Dernier match ajouté : []
# Matchs ajoutés : 14900
#
# Dernier match ajouté : [['TOP', 'Yorick', 'JUNGLE', 'Nidalee', 'MIDDLE', 'Ekko', 'BOTTOM', 'Aphelios', 'UTILITY', 'Thresh'], ['TOP', 'Renekton', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Azir', 'BOTTOM', 'Ezreal', 'UTILITY', 'Brand'], 'Red']
# Matchs ajoutés : 15000
#
# Dernier match ajouté : [['TOP', 'Jax', 'JUNGLE', 'Ivern', 'MIDDLE', 'Aatrox', 'BOTTOM', 'Caitlyn', 'UTILITY', 'Thresh'], ['TOP', 'Renekton', 'JUNGLE', 'Nidalee', 'MIDDLE', 'Akshan', 'BOTTOM', 'Xayah', 'UTILITY', 'Rell'], 'Red']
# Matchs ajoutés : 15100
#
# Dernier match ajouté : [['TOP', 'Poppy', 'JUNGLE', 'Nunu', 'MIDDLE', 'Syndra', 'BOTTOM', 'Jhin', 'UTILITY', 'Pyke'], ['UTILITY', 'Thresh', 'JUNGLE', 'Zac', 'MIDDLE', 'Leblanc', 'BOTTOM', 'Kaisa', 'TOP', 'Jax'], 'Red']
# Matchs ajoutés : 15200
#
# Dernier match ajouté : [['TOP', 'Maokai', 'JUNGLE', 'Diana', 'MIDDLE', 'Pantheon', 'BOTTOM', 'Zeri', 'UTILITY', 'Thresh'], ['TOP', 'Renekton', 'JUNGLE', 'Viego', 'MIDDLE', 'Ahri', 'BOTTOM', 'Ezreal', 'UTILITY', 'Rell'], 'Red']
# Matchs ajoutés : 15200
#
# Dernier match ajouté : []
# Matchs ajoutés : 15300
#
# Dernier match ajouté : [['TOP', 'Draven', 'JUNGLE', 'Belveth', 'MIDDLE', 'Naafiri', 'BOTTOM', 'Kaisa', 'UTILITY', 'Senna'], ['TOP', 'Renekton', 'JUNGLE', 'Karthus', 'MIDDLE', 'Yasuo', 'BOTTOM', 'Aphelios', 'UTILITY', 'Lulu'], 'Red']
# Matchs ajoutés : 15400
#
# Dernier match ajouté : [['TOP', 'Rumble', 'JUNGLE', 'Vi', 'MIDDLE', 'Malphite', 'BOTTOM', 'Kaisa', 'UTILITY', 'Alistar'], ['TOP', 'Rengar', 'JUNGLE', 'Ivern', 'MIDDLE', 'Galio', 'BOTTOM', 'Twitch', 'UTILITY', 'Thresh'], 'Red']
# Matchs ajoutés : 15500
#
# Dernier match ajouté : [['TOP', 'Kled', 'JUNGLE', 'Sylas', 'MIDDLE', 'Vi', 'BOTTOM', 'Tristana', 'UTILITY', 'Bard'], ['TOP', 'Mordekaiser', 'JUNGLE', 'Viego', 'MIDDLE', 'Akali', 'BOTTOM', 'Ezreal', 'UTILITY', 'Karma'], 'Blue']
# Matchs ajoutés : 15500
#
# Dernier match ajouté : []
# Matchs ajoutés : 15500
#
# Dernier match ajouté : []
# Matchs ajoutés : 15600
#
# Dernier match ajouté : [['TOP', 'Kennen', 'JUNGLE', 'Lillia', 'MIDDLE', 'Zed', 'BOTTOM', 'Draven', 'UTILITY', 'Rell'], ['TOP', 'Riven', 'JUNGLE', 'Khazix', 'MIDDLE', 'Talon', 'BOTTOM', 'Samira', 'UTILITY', 'FiddleSticks'], 'Red']
# Matchs ajoutés : 15700
#
# Dernier match ajouté : [['TOP', 'Akshan', 'JUNGLE', 'Sylas', 'MIDDLE', 'Yone', 'BOTTOM', 'Xayah', 'UTILITY', 'Thresh'], ['TOP', 'Akali', 'JUNGLE', 'Graves', 'MIDDLE', 'Zed', 'BOTTOM', 'Lucian', 'UTILITY', 'Blitzcrank'], 'Red']
# Matchs ajoutés : 15700
#
# Dernier match ajouté : []
# Matchs ajoutés : 15800
#
# Dernier match ajouté : [['TOP', 'Neeko', 'JUNGLE', 'Poppy', 'MIDDLE', 'Pantheon', 'BOTTOM', 'Aphelios', 'UTILITY', 'Zyra'], ['TOP', 'Gangplank', 'JUNGLE', 'Jax', 'MIDDLE', 'Talon', 'BOTTOM', 'Ashe', 'UTILITY', 'Heimerdinger'], 'Blue']
# Matchs ajoutés : 15900
#
# Dernier match ajouté : [['TOP', 'Gangplank', 'JUNGLE', 'Viego', 'MIDDLE', 'Taliyah', 'BOTTOM', 'Zeri', 'UTILITY', 'Alistar'], ['TOP', 'Irelia', 'JUNGLE', 'Tristana', 'MIDDLE', 'Elise', 'BOTTOM', 'Kaisa', 'UTILITY', 'Poppy'], 'Red']
# Matchs ajoutés : 16000
#
# Dernier match ajouté : [['TOP', 'Renekton', 'JUNGLE', 'Ekko', 'MIDDLE', 'Zed', 'BOTTOM', 'Tristana', 'UTILITY', 'Rell'], ['TOP', 'Camille', 'JUNGLE', 'Taliyah', 'MIDDLE', 'Pantheon', 'BOTTOM', 'Nilah', 'UTILITY', 'Blitzcrank'], 'Red']
# Matchs ajoutés : 16100
#
# Dernier match ajouté : [['TOP', 'Malphite', 'JUNGLE', 'Nidalee', 'MIDDLE', 'Yasuo', 'BOTTOM', 'Samira', 'UTILITY', 'Rell'], ['TOP', 'Renekton', 'JUNGLE', 'Graves', 'MIDDLE', 'Leblanc', 'BOTTOM', 'Kaisa', 'UTILITY', 'Braum'], 'Blue']
# Matchs ajoutés : 16200
#
# Dernier match ajouté : [['TOP', 'Renekton', 'JUNGLE', 'Elise', 'MIDDLE', 'Orianna', 'BOTTOM', 'Kaisa', 'UTILITY', 'Lulu'], ['TOP', 'Tryndamere', 'JUNGLE', 'Graves', 'MIDDLE', 'Viktor', 'BOTTOM', 'Jhin', 'UTILITY', 'Nautilus'], 'Blue']
# Matchs ajoutés : 16300
#
# Dernier match ajouté : [['TOP', 'Gangplank', 'JUNGLE', 'Taliyah', 'MIDDLE', 'Leblanc', 'BOTTOM', 'Lucian', 'UTILITY', 'Leona'], ['TOP', 'Shen', 'JUNGLE', 'Kindred', 'MIDDLE', 'Katarina', 'BOTTOM', 'Ezreal', 'UTILITY', 'Karma'], 'Red']
# Matchs ajoutés : 16400
#
# Dernier match ajouté : [['MIDDLE', 'Sett', 'JUNGLE', 'MasterYi', 'TOP', 'Akali', 'BOTTOM', 'Kaisa', 'UTILITY', 'Rell'], ['TOP', 'Aatrox', 'JUNGLE', 'Kindred', 'MIDDLE', 'Azir', 'BOTTOM', 'Zeri', 'UTILITY', 'Alistar'], 'Blue']
# Matchs ajoutés : 16500
#
# Dernier match ajouté : [['TOP', 'Poppy', 'JUNGLE', 'Taliyah', 'MIDDLE', 'Tristana', 'BOTTOM', 'Ezreal', 'UTILITY', 'Alistar'], ['TOP', 'Jax', 'JUNGLE', 'Sejuani', 'MIDDLE', 'AurelionSol', 'BOTTOM', 'Zeri', 'UTILITY', 'Rell'], 'Blue']
# Matchs ajoutés : 16600
#
# Dernier match ajouté : [['TOP', 'Leblanc', 'JUNGLE', 'Graves', 'MIDDLE', 'Malzahar', 'BOTTOM', 'Ezreal', 'UTILITY', 'Nautilus'], ['TOP', 'Gragas', 'JUNGLE', 'Kindred', 'MIDDLE', 'Orianna', 'BOTTOM', 'Xerath', 'UTILITY', 'Rakan'], 'Red']
# Matchs ajoutés : 16700
#
# Dernier match ajouté : [['TOP', 'Karma', 'JUNGLE', 'Poppy', 'MIDDLE', 'Talon', 'BOTTOM', 'Jinx', 'UTILITY', 'Gragas'], ['TOP', 'Gwen', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Katarina', 'BOTTOM', 'Kaisa', 'UTILITY', 'Rell'], 'Blue']
# Matchs ajoutés : 16800
#
# Dernier match ajouté : [['TOP', 'Aatrox', 'JUNGLE', 'Nunu', 'MIDDLE', 'Akshan', 'BOTTOM', 'Kaisa', 'UTILITY', 'Pyke'], ['TOP', 'Gwen', 'JUNGLE', 'JarvanIV', 'MIDDLE', 'Tristana', 'BOTTOM', 'Ezreal', 'UTILITY', 'FiddleSticks'], 'Red']
# Matchs ajoutés : 16900
#
# Dernier match ajouté : [['TOP', 'Kayle', 'JUNGLE', 'Taliyah', 'MIDDLE', 'Renekton', 'BOTTOM', 'Lucian', 'UTILITY', 'Senna'], ['TOP', 'Sett', 'JUNGLE', 'Nidalee', 'MIDDLE', 'Yasuo', 'BOTTOM', 'KogMaw', 'UTILITY', 'Yuumi'], 'Red']
# Matchs ajoutés : 17000
#
# Dernier match ajouté : [['TOP', 'Aatrox', 'JUNGLE', 'RekSai', 'MIDDLE', 'Taliyah', 'BOTTOM', 'Ezreal', 'UTILITY', 'Nautilus'], ['TOP', 'Rumble', 'JUNGLE', 'Viego', 'MIDDLE', 'Lissandra', 'BOTTOM', 'Caitlyn', 'UTILITY', 'Lux'], 'Red']
# Matchs ajoutés : 17100
#
# Dernier match ajouté : [['TOP', 'Fiora', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Akali', 'BOTTOM', 'Aphelios', 'UTILITY', 'Zilean'], ['TOP', 'Akshan', 'JUNGLE', 'Viego', 'MIDDLE', 'Sylas', 'BOTTOM', 'Zeri', 'UTILITY', 'Rakan'], 'Red']
# Matchs ajoutés : 17100
#
# Dernier match ajouté : []
# Matchs ajoutés : 17200
#
# Dernier match ajouté : [['TOP', 'Yone', 'JUNGLE', 'Nidalee', 'MIDDLE', 'Talon', 'BOTTOM', 'KogMaw', 'UTILITY', 'Milio'], ['TOP', 'Sion', 'JUNGLE', 'Nocturne', 'MIDDLE', 'Rumble', 'BOTTOM', 'Ziggs', 'UTILITY', 'Rakan'], 'Blue']
# Matchs ajoutés : 17300
#
# Dernier match ajouté : [['TOP', 'Olaf', 'JUNGLE', 'Elise', 'MIDDLE', 'Yasuo', 'BOTTOM', 'Twitch', 'UTILITY', 'Lulu'], ['TOP', 'Gangplank', 'JUNGLE', 'Khazix', 'MIDDLE', 'Viktor', 'BOTTOM', 'Ezreal', 'UTILITY', 'Zyra'], 'Red']
# Matchs ajoutés : 17400
#
# Dernier match ajouté : [['TOP', 'Jax', 'JUNGLE', 'Khazix', 'MIDDLE', 'Ahri', 'BOTTOM', 'Xayah', 'UTILITY', 'Rell'], ['TOP', 'Poppy', 'JUNGLE', 'Kindred', 'MIDDLE', 'Tristana', 'BOTTOM', 'Kaisa', 'UTILITY', 'Alistar'], 'Red']
# Matchs ajoutés : 17500
#
# Dernier match ajouté : [['TOP', 'Riven', 'JUNGLE', 'Khazix', 'MIDDLE', 'Sylas', 'BOTTOM', 'Jinx', 'UTILITY', 'Thresh'], ['TOP', 'Yone', 'JUNGLE', 'Shaco', 'MIDDLE', 'Azir', 'BOTTOM', 'Swain', 'UTILITY', 'Heimerdinger'], 'Blue']
# Matchs ajoutés : 17500
#
# Dernier match ajouté : []
# Matchs ajoutés : 17600
#
# Dernier match ajouté : [['TOP', 'Nasus', 'JUNGLE', 'Sejuani', 'MIDDLE', 'Ekko', 'BOTTOM', 'Samira', 'UTILITY', 'Rell'], ['TOP', 'Yone', 'JUNGLE', 'Graves', 'MIDDLE', 'Fizz', 'BOTTOM', 'Xayah', 'UTILITY', 'Rakan'], 'Red']
# Matchs ajoutés : 17700
#
# Dernier match ajouté : [['TOP', 'Jayce', 'JUNGLE', 'Khazix', 'MIDDLE', 'Yone', 'BOTTOM', 'Varus', 'UTILITY', 'Neeko'], ['TOP', 'KSante', 'JUNGLE', 'Sejuani', 'MIDDLE', 'Tristana', 'BOTTOM', 'Kaisa', 'UTILITY', 'Belveth'], 'Red']
# Matchs ajoutés : 17700
#
# Dernier match ajouté : []
# Matchs ajoutés : 17800
#
# Dernier match ajouté : [['TOP', 'Riven', 'JUNGLE', 'Sejuani', 'MIDDLE', 'Irelia', 'BOTTOM', 'Draven', 'UTILITY', 'Renata'], ['TOP', 'Pantheon', 'JUNGLE', 'Hecarim', 'MIDDLE', 'Yone', 'BOTTOM', 'Kaisa', 'UTILITY', 'Rakan'], 'Blue']
# Matchs ajoutés : 17800
#
# Dernier match ajouté : []
# Matchs ajoutés : 17800
#
# Dernier match ajouté : []
# Matchs ajoutés : 17800
#
# Dernier match ajouté : []
# Matchs ajoutés : 17800
#
# Dernier match ajouté : []
# Matchs ajoutés : 17900
#
# Dernier match ajouté : [['TOP', 'Heimerdinger', 'JUNGLE', 'Kindred', 'MIDDLE', 'Zoe', 'BOTTOM', 'Kaisa', 'UTILITY', 'Rakan'], ['TOP', 'Maokai', 'JUNGLE', 'Kayn', 'MIDDLE', 'Irelia', 'BOTTOM', 'Ezreal', 'UTILITY', 'Senna'], 'Blue']
# Matchs ajoutés : 18000
#
# Dernier match ajouté : [['TOP', 'Rengar', 'JUNGLE', 'Elise', 'MIDDLE', 'Katarina', 'BOTTOM', 'MissFortune', 'UTILITY', 'Leona'], ['TOP', 'Yorick', 'JUNGLE', 'Maokai', 'MIDDLE', 'Tristana', 'BOTTOM', 'Kaisa', 'UTILITY', 'Nautilus'], 'Blue']
# Matchs ajoutés : 18100
#
# Dernier match ajouté : [['TOP', 'Poppy', 'JUNGLE', 'Gragas', 'MIDDLE', 'Yone', 'BOTTOM', 'Xayah', 'UTILITY', 'Alistar'], ['TOP', 'Gangplank', 'JUNGLE', 'Ekko', 'MIDDLE', 'Leblanc', 'BOTTOM', 'Nilah', 'UTILITY', 'Nautilus'], 'Red']
# Matchs ajoutés : 18100
#
# Dernier match ajouté : []
# Matchs ajoutés : 18200
#
# Dernier match ajouté : [['TOP', 'Urgot', 'JUNGLE', 'Viego', 'MIDDLE', 'Ahri', 'BOTTOM', 'Vayne', 'UTILITY', 'Bard'], ['TOP', 'Gwen', 'JUNGLE', 'Graves', 'MIDDLE', 'Katarina', 'BOTTOM', 'Samira', 'UTILITY', 'Nautilus'], 'Red']
# Matchs ajoutés : 18300
#
# Dernier match ajouté : [['TOP', 'Darius', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Ahri', 'BOTTOM', 'Sivir', 'UTILITY', 'Lux'], ['TOP', 'KSante', 'JUNGLE', 'Belveth', 'MIDDLE', 'AurelionSol', 'BOTTOM', 'Zeri', 'UTILITY', 'Karma'], 'Red']
# Matchs ajoutés : 18400
#
# Dernier match ajouté : [['TOP', 'Sett', 'JUNGLE', 'JarvanIV', 'MIDDLE', 'Galio', 'BOTTOM', 'Ezreal', 'UTILITY', 'Yuumi'], ['TOP', 'Illaoi', 'JUNGLE', 'Ivern', 'MIDDLE', 'Irelia', 'BOTTOM', 'Xayah', 'UTILITY', 'Blitzcrank'], 'Red']
# Matchs ajoutés : 18500
#
# Dernier match ajouté : [['TOP', 'KSante', 'JUNGLE', 'Sejuani', 'MIDDLE', 'Jayce', 'BOTTOM', 'MissFortune', 'UTILITY', 'Azir'], ['TOP', 'Zac', 'JUNGLE', 'Nocturne', 'MIDDLE', 'Talon', 'BOTTOM', 'Kaisa', 'UTILITY', 'Rakan'], 'Red']
# Matchs ajoutés : 18600
#
# Dernier match ajouté : [['TOP', 'Quinn', 'JUNGLE', 'Nidalee', 'MIDDLE', 'Jayce', 'BOTTOM', 'Kaisa', 'UTILITY', 'Nautilus'], ['TOP', 'Vladimir', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Leblanc', 'BOTTOM', 'Aphelios', 'UTILITY', 'Rell'], 'Blue']
# Matchs ajoutés : 18700
#
# Dernier match ajouté : [['TOP', 'Kennen', 'JUNGLE', 'Kindred', 'MIDDLE', 'Yone', 'BOTTOM', 'Caitlyn', 'UTILITY', 'Taric'], ['TOP', 'Aatrox', 'JUNGLE', 'Ekko', 'MIDDLE', 'Zed', 'BOTTOM', 'Zeri', 'UTILITY', 'Alistar'], 'Blue']
# Matchs ajoutés : 18700
#
# Dernier match ajouté : []
# Matchs ajoutés : 18800
#
# Dernier match ajouté : [['TOP', 'Akali', 'JUNGLE', 'Gragas', 'MIDDLE', 'Irelia', 'BOTTOM', 'Xayah', 'UTILITY', 'Bard'], ['TOP', 'Warwick', 'JUNGLE', 'Karthus', 'MIDDLE', 'Yasuo', 'BOTTOM', 'Tristana', 'UTILITY', 'Rell'], 'Red']
# Matchs ajoutés : 18800
#
# Dernier match ajouté : []
# Matchs ajoutés : 18900
#
# Dernier match ajouté : [['TOP', 'Cassiopeia', 'JUNGLE', 'Graves', 'MIDDLE', 'Ekko', 'BOTTOM', 'MissFortune', 'UTILITY', 'Heimerdinger'], ['TOP', 'Jayce', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Singed', 'BOTTOM', 'Samira', 'UTILITY', 'Pyke'], 'Blue']
# Matchs ajoutés : 18900
#
# Dernier match ajouté : []
# Matchs ajoutés : 18900
#
# Dernier match ajouté : []
# Matchs ajoutés : 19000
#
# Dernier match ajouté : [['TOP', 'Olaf', 'JUNGLE', 'Nidalee', 'MIDDLE', 'Ahri', 'BOTTOM', 'Kaisa', 'UTILITY', 'Rammus'], ['TOP', 'Yone', 'JUNGLE', 'Rumble', 'MIDDLE', 'Leblanc', 'BOTTOM', 'Xayah', 'UTILITY', 'Leona'], 'Blue']
# Matchs ajoutés : 19100
#
# Dernier match ajouté : [['TOP', 'Heimerdinger', 'JUNGLE', 'JarvanIV', 'MIDDLE', 'Lissandra', 'BOTTOM', 'Kaisa', 'UTILITY', 'Rakan'], ['TOP', 'Irelia', 'JUNGLE', 'Nidalee', 'MIDDLE', 'Naafiri', 'BOTTOM', 'Draven', 'UTILITY', 'Lulu'], 'Red']
# Matchs ajoutés : 19200
#
# Dernier match ajouté : [['TOP', 'Olaf', 'JUNGLE', 'Viego', 'MIDDLE', 'Syndra', 'BOTTOM', 'Kaisa', 'UTILITY', 'Rell'], ['TOP', 'Fiora', 'JUNGLE', 'Rengar', 'MIDDLE', 'TwistedFate', 'BOTTOM', 'MissFortune', 'UTILITY', 'Xerath'], 'Blue']
# Matchs ajoutés : 19300
#
# Dernier match ajouté : [['TOP', 'Renekton', 'JUNGLE', 'Graves', 'MIDDLE', 'Leblanc', 'BOTTOM', 'Caitlyn', 'UTILITY', 'Lux'], ['TOP', 'Aatrox', 'JUNGLE', 'Evelynn', 'MIDDLE', 'Neeko', 'BOTTOM', 'Nilah', 'UTILITY', 'Senna'], 'Red']
# Matchs ajoutés : 19300
#
# Dernier match ajouté : []
# Matchs ajoutés : 19400
#
# Dernier match ajouté : [['TOP', 'Jax', 'JUNGLE', 'Lillia', 'MIDDLE', 'Tristana', 'BOTTOM', 'Kaisa', 'UTILITY', 'Amumu'], ['TOP', 'Fiora', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Xerath', 'BOTTOM', 'Draven', 'UTILITY', 'Nautilus'], 'Red']
# Matchs ajoutés : 19500
#
# Dernier match ajouté : [['TOP', 'Nasus', 'JUNGLE', 'Graves', 'MIDDLE', 'Aatrox', 'BOTTOM', 'Kaisa', 'UTILITY', 'Nautilus'], ['TOP', 'Akshan', 'JUNGLE', 'Rumble', 'MIDDLE', 'Zed', 'BOTTOM', 'Xayah', 'UTILITY', 'Rell'], 'Blue']
# Matchs ajoutés : 19600
#
# Dernier match ajouté : [['TOP', 'Renekton', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Sylas', 'BOTTOM', 'Ashe', 'UTILITY', 'Blitzcrank'], ['TOP', 'Yone', 'JUNGLE', 'Graves', 'BOTTOM', 'Ezreal', 'MIDDLE', 'Lissandra', 'UTILITY', 'Rell'], 'Red']
# Matchs ajoutés : 19600
#
# Dernier match ajouté : []
# Matchs ajoutés : 19700
#
# Dernier match ajouté : [['TOP', 'Gwen', 'JUNGLE', 'Khazix', 'MIDDLE', 'Yone', 'BOTTOM', 'Ashe', 'UTILITY', 'Thresh'], ['TOP', 'Akshan', 'JUNGLE', 'Warwick', 'MIDDLE', 'Xerath', 'BOTTOM', 'Xayah', 'UTILITY', 'Pyke'], 'Red']
# Matchs ajoutés : 19700
#
# Dernier match ajouté : []
# Matchs ajoutés : 19800
#
# Dernier match ajouté : [['TOP', 'Jax', 'JUNGLE', 'Maokai', 'MIDDLE', 'Yone', 'BOTTOM', 'Kaisa', 'UTILITY', 'Leona'], ['TOP', 'Aatrox', 'JUNGLE', 'Zac', 'MIDDLE', 'Katarina', 'BOTTOM', 'Xayah', 'UTILITY', 'Rakan'], 'Blue']
# Matchs ajoutés : 19900
#
# Dernier match ajouté : [['TOP', 'Quinn', 'JUNGLE', 'Gwen', 'MIDDLE', 'Yone', 'BOTTOM', 'Draven', 'UTILITY', 'Anivia'], ['TOP', 'Kayle', 'JUNGLE', 'MonkeyKing', 'MIDDLE', 'Naafiri', 'BOTTOM', 'Jhin', 'UTILITY', 'Xerath'], 'Blue']
# Matchs ajoutés : 20000
#
# Dernier match ajouté : [['TOP', 'Gnar', 'JUNGLE', 'MasterYi', 'MIDDLE', 'Katarina', 'BOTTOM', 'Zeri', 'UTILITY', 'Xerath'], ['TOP', 'Irelia', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Diana', 'BOTTOM', 'Kaisa', 'UTILITY', 'Pyke'], 'Red']
# Matchs ajoutés : 20000
#
# Dernier match ajouté : []
# Matchs ajoutés : 20100
#
# Dernier match ajouté : [['TOP', 'Sion', 'JUNGLE', 'Kindred', 'MIDDLE', 'Ekko', 'BOTTOM', 'Draven', 'UTILITY', 'Karma'], ['TOP', 'Renekton', 'JUNGLE', 'Taliyah', 'MIDDLE', 'Singed', 'BOTTOM', 'Xayah', 'UTILITY', 'Rakan'], 'Red']
# Matchs ajoutés : 20200
#
# Dernier match ajouté : [['TOP', 'Aatrox', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Zed', 'BOTTOM', 'Tristana', 'UTILITY', 'Rell'], ['TOP', 'Irelia', 'JUNGLE', 'Elise', 'MIDDLE', 'Qiyana', 'BOTTOM', 'Kaisa', 'UTILITY', 'Thresh'], 'Red']
# Matchs ajoutés : 20300
#
# Dernier match ajouté : [['TOP', 'DrMundo', 'JUNGLE', 'FiddleSticks', 'MIDDLE', 'Akshan', 'BOTTOM', 'Vayne', 'UTILITY', 'Veigar'], ['TOP', 'Camille', 'JUNGLE', 'Gragas', 'MIDDLE', 'Talon', 'BOTTOM', 'Kaisa', 'UTILITY', 'Pyke'], 'Red']
# Matchs ajoutés : 20400
#
# Dernier match ajouté : [['TOP', 'Yasuo', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Anivia', 'BOTTOM', 'Swain', 'UTILITY', 'Rakan'], ['TOP', 'Jayce', 'JUNGLE', 'Viego', 'MIDDLE', 'Xerath', 'BOTTOM', 'Aphelios', 'UTILITY', 'Milio'], 'Blue']
# Matchs ajoutés : 20500
#
# Dernier match ajouté : [['TOP', 'KSante', 'JUNGLE', 'Nidalee', 'MIDDLE', 'Tristana', 'BOTTOM', 'Samira', 'UTILITY', 'Rell'], ['TOP', 'Poppy', 'JUNGLE', 'Kindred', 'MIDDLE', 'Galio', 'BOTTOM', 'Kaisa', 'UTILITY', 'Alistar'], 'Red']
# Matchs ajoutés : 20500
#
# Dernier match ajouté : []
# Matchs ajoutés : 20600
#
# Dernier match ajouté : [['TOP', 'Aatrox', 'JUNGLE', 'Gragas', 'MIDDLE', 'Qiyana', 'BOTTOM', 'Kaisa', 'UTILITY', 'Lux'], ['TOP', 'Yone', 'JUNGLE', 'Ivern', 'MIDDLE', 'Vladimir', 'BOTTOM', 'Tristana', 'UTILITY', 'Rakan'], 'Blue']
# Matchs ajoutés : 20700
#
# Dernier match ajouté : [['TOP', 'Camille', 'JUNGLE', 'Kindred', 'MIDDLE', 'Leblanc', 'BOTTOM', 'Jinx', 'UTILITY', 'Leona'], ['TOP', 'Jax', 'JUNGLE', 'Viego', 'MIDDLE', 'Galio', 'BOTTOM', 'Zeri', 'UTILITY', 'Rakan'], 'Red']
# Matchs ajoutés : 20800
#
# Dernier match ajouté : [['TOP', 'Alistar', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Leblanc', 'BOTTOM', 'Aphelios', 'UTILITY', 'Thresh'], ['TOP', 'Nidalee', 'JUNGLE', 'Graves', 'MIDDLE', 'Kennen', 'BOTTOM', 'Caitlyn', 'UTILITY', 'Ahri'], 'Blue']
# Matchs ajoutés : 20800
#
# Dernier match ajouté : []
# Matchs ajoutés : 20900
#
# Dernier match ajouté : [['TOP', 'KSante', 'JUNGLE', 'Khazix', 'MIDDLE', 'Gragas', 'BOTTOM', 'Twitch', 'UTILITY', 'Rakan'], ['TOP', 'Ryze', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Yasuo', 'BOTTOM', 'Kalista', 'UTILITY', 'Pyke'], 'Blue']
# Matchs ajoutés : 21000
#
# Dernier match ajouté : [['TOP', 'Nasus', 'JUNGLE', 'Udyr', 'MIDDLE', 'Katarina', 'BOTTOM', 'Jhin', 'UTILITY', 'Milio'], ['TOP', 'Sion', 'JUNGLE', 'Viego', 'UTILITY', 'Poppy', 'MIDDLE', 'Anivia', 'BOTTOM', 'Ezreal'], 'Blue']
# Matchs ajoutés : 21000
#
# Dernier match ajouté : []
# Matchs ajoutés : 21100
#
# Dernier match ajouté : [['TOP', 'Jax', 'JUNGLE', 'Kayn', 'MIDDLE', 'Ahri', 'BOTTOM', 'Xayah', 'UTILITY', 'Lux'], ['TOP', 'KSante', 'JUNGLE', 'JarvanIV', 'MIDDLE', 'Yasuo', 'BOTTOM', 'Karthus', 'UTILITY', 'Heimerdinger'], 'Red']
# Matchs ajoutés : 21200
#
# Dernier match ajouté : [['TOP', 'Renekton', 'JUNGLE', 'Nidalee', 'MIDDLE', 'Zed', 'BOTTOM', 'Sivir', 'UTILITY', 'Sett'], ['TOP', 'Malphite', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Sylas', 'BOTTOM', 'Kaisa', 'UTILITY', 'Nautilus'], 'Red']
# Matchs ajoutés : 21300
#
# ...
# Matchs ajoutés : 92500
#
# Dernier match ajouté : [['TOP', 'KSante', 'JUNGLE', 'Ekko', 'MIDDLE', 'Yone', 'BOTTOM', 'Ashe', 'UTILITY', 'Zac'], ['TOP', 'Soraka', 'JUNGLE', 'Diana', 'MIDDLE', 'Yasuo', 'BOTTOM', 'Samira', 'UTILITY', 'Nautilus'], 'Red']
# Matchs ajoutés : 92600
#
# Dernier match ajouté : [['TOP', 'Quinn', 'JUNGLE', 'Elise', 'MIDDLE', 'Talon', 'BOTTOM', 'Ezreal', 'UTILITY', 'Nautilus'], ['TOP', 'Darius', 'JUNGLE', 'Skarner', 'MIDDLE', 'Lissandra', 'BOTTOM', 'Draven', 'UTILITY', 'Braum'], 'Red']
# Matchs ajoutés : 92700
#
# Dernier match ajouté : [['TOP', 'Garen', 'JUNGLE', 'Volibear', 'MIDDLE', 'Ahri', 'BOTTOM', 'Jinx', 'UTILITY', 'Blitzcrank'], ['TOP', 'Jayce', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Akali', 'BOTTOM', 'Aphelios', 'UTILITY', 'Taric'], 'Red']
# Matchs ajoutés : 92700
#
# Dernier match ajouté : []
# Matchs ajoutés : 92800
#
# Dernier match ajouté : [['TOP', 'Sett', 'JUNGLE', 'Graves', 'MIDDLE', 'Orianna', 'BOTTOM', 'Kaisa', 'UTILITY', 'Thresh'], ['TOP', 'Irelia', 'JUNGLE', 'JarvanIV', 'MIDDLE', 'Viktor', 'BOTTOM', 'Caitlyn', 'UTILITY', 'Bard'], 'Blue']
# Matchs ajoutés : 92900
#
# Dernier match ajouté : [['TOP', 'Yone', 'JUNGLE', 'Karthus', 'MIDDLE', 'Irelia', 'BOTTOM', 'Samira', 'UTILITY', 'Zac'], ['TOP', 'Darius', 'JUNGLE', 'MasterYi', 'MIDDLE', 'Ahri', 'BOTTOM', 'MissFortune', 'UTILITY', 'JarvanIV'], 'Red']
# Matchs ajoutés : 92900
#
# Dernier match ajouté : []
# Matchs ajoutés : 93000
#
# Dernier match ajouté : [['TOP', 'KSante', 'JUNGLE', 'Khazix', 'MIDDLE', 'Graves', 'UTILITY', 'Taric', 'UTILITY', 'Katarina'], ['TOP', 'Rumble', 'JUNGLE', 'Kindred', 'MIDDLE', 'Nocturne', 'BOTTOM', 'Caitlyn', 'UTILITY', 'Rakan'], 'Blue']
# Matchs ajoutés : 93100
#
# Dernier match ajouté : [['TOP', 'Fiora', 'JUNGLE', 'Khazix', 'MIDDLE', 'TwistedFate', 'BOTTOM', 'Aphelios', 'UTILITY', 'Milio'], ['TOP', 'Kennen', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Jayce', 'BOTTOM', 'Ezreal', 'UTILITY', 'Karma'], 'Blue']
# Matchs ajoutés : 93200
#
# Dernier match ajouté : [['TOP', 'Sett', 'JUNGLE', 'Khazix', 'MIDDLE', 'Yone', 'BOTTOM', 'Xayah', 'UTILITY', 'Maokai'], ['TOP', 'Jax', 'JUNGLE', 'Kayn', 'MIDDLE', 'Neeko', 'BOTTOM', 'Kaisa', 'UTILITY', 'Leona'], 'Blue']
# Matchs ajoutés : 93300
#
# Dernier match ajouté : [['TOP', 'Yorick', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Zoe', 'BOTTOM', 'Xayah', 'UTILITY', 'Blitzcrank'], ['TOP', 'Jax', 'JUNGLE', 'Taliyah', 'MIDDLE', 'Renekton', 'BOTTOM', 'Kaisa', 'UTILITY', 'Nautilus'], 'Red']
# Matchs ajoutés : 93400
#
# Dernier match ajouté : [['TOP', 'Renekton', 'JUNGLE', 'Sylas', 'MIDDLE', 'Chogath', 'BOTTOM', 'Zeri', 'UTILITY', 'Nautilus'], ['TOP', 'Yone', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Varus', 'BOTTOM', 'Xayah', 'UTILITY', 'Alistar'], 'Red']
# Matchs ajoutés : 93400
#
# Dernier match ajouté : []
# Matchs ajoutés : 93500
#
# Dernier match ajouté : [['TOP', 'Irelia', 'JUNGLE', 'Qiyana', 'MIDDLE', 'Swain', 'BOTTOM', 'Aphelios', 'UTILITY', 'Rakan'], ['TOP', 'Rumble', 'JUNGLE', 'Nidalee', 'MIDDLE', 'Renekton', 'BOTTOM', 'Ivern', 'UTILITY', 'Shaco'], 'Blue']
# Matchs ajoutés : 93600
#
# Dernier match ajouté : [['TOP', 'Rengar', 'UTILITY', 'Nautilus', 'MIDDLE', 'Azir', 'BOTTOM', 'Caitlyn', 'JUNGLE', 'Vi'], ['TOP', 'Darius', 'JUNGLE', 'Udyr', 'MIDDLE', 'Xerath', 'BOTTOM', 'Ezreal', 'UTILITY', 'Karma'], 'Red']
# Matchs ajoutés : 93700
#
# Dernier match ajouté : [['TOP', 'Rengar', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Katarina', 'BOTTOM', 'Ezreal', 'UTILITY', 'Blitzcrank'], ['TOP', 'Tryndamere', 'JUNGLE', 'Poppy', 'MIDDLE', 'Neeko', 'BOTTOM', 'Jhin', 'UTILITY', 'Zyra'], 'Blue']
# Matchs ajoutés : 93800
#
# Dernier match ajouté : [['TOP', 'Jayce', 'JUNGLE', 'Shaco', 'MIDDLE', 'Katarina', 'BOTTOM', 'Ezreal', 'UTILITY', 'Malphite'], ['TOP', 'KSante', 'JUNGLE', 'Taliyah', 'MIDDLE', 'Yasuo', 'BOTTOM', 'Xayah', 'UTILITY', 'Zyra'], 'Blue']
# Matchs ajoutés : 93800
#
# Dernier match ajouté : []
# Matchs ajoutés : 93900
#
# Dernier match ajouté : [['TOP', 'Poppy', 'JUNGLE', 'Graves', 'MIDDLE', 'Akali', 'BOTTOM', 'Zeri', 'UTILITY', 'Alistar'], ['TOP', 'Ornn', 'JUNGLE', 'Sejuani', 'MIDDLE', 'Yasuo', 'BOTTOM', 'Kaisa', 'UTILITY', 'Blitzcrank'], 'Blue']
# Matchs ajoutés : 94000
#
# Dernier match ajouté : [['TOP', 'Malphite', 'JUNGLE', 'Elise', 'MIDDLE', 'Yasuo', 'BOTTOM', 'Nilah', 'UTILITY', 'Maokai'], ['TOP', 'Fiora', 'JUNGLE', 'Rengar', 'MIDDLE', 'Lissandra', 'BOTTOM', 'Caitlyn', 'UTILITY', 'Pyke'], 'Blue']
# Matchs ajoutés : 94100
#
# Dernier match ajouté : [['TOP', 'Jax', 'JUNGLE', 'Rell', 'MIDDLE', 'Azir', 'BOTTOM', 'Samira', 'UTILITY', 'Belveth'], ['TOP', 'Malphite', 'JUNGLE', 'Nidalee', 'MIDDLE', 'KSante', 'BOTTOM', 'Xayah', 'UTILITY', 'Rakan'], 'Blue']
# Matchs ajoutés : 94200
#
# Dernier match ajouté : [['TOP', 'Akali', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Azir', 'BOTTOM', 'Ezreal', 'UTILITY', 'Karma'], ['TOP', 'Tryndamere', 'JUNGLE', 'Nidalee', 'MIDDLE', 'Qiyana', 'BOTTOM', 'Kaisa', 'UTILITY', 'Rakan'], 'Red']
# Matchs ajoutés : 94300
#
# Dernier match ajouté : [['TOP', 'Jayce', 'JUNGLE', 'Elise', 'MIDDLE', 'KSante', 'BOTTOM', 'Ashe', 'UTILITY', 'Milio'], ['TOP', 'Fiora', 'JUNGLE', 'Viego', 'MIDDLE', 'Neeko', 'BOTTOM', 'Kaisa', 'UTILITY', 'Rakan'], 'Blue']
# Matchs ajoutés : 94400
#
# Dernier match ajouté : [['TOP', 'Yone', 'JUNGLE', 'Poppy', 'MIDDLE', 'Akali', 'BOTTOM', 'Aphelios', 'UTILITY', 'Thresh'], ['TOP', 'Yasuo', 'JUNGLE', 'Kindred', 'MIDDLE', 'Neeko', 'BOTTOM', 'Kaisa', 'UTILITY', 'Pyke'], 'Red']
# Matchs ajoutés : 94500
#
# Dernier match ajouté : [['TOP', 'Sylas', 'JUNGLE', 'Maokai', 'MIDDLE', 'Yone', 'BOTTOM', 'Vayne', 'UTILITY', 'Morgana'], ['TOP', 'Gragas', 'JUNGLE', 'Viego', 'MIDDLE', 'Xerath', 'BOTTOM', 'Sivir', 'UTILITY', 'Rell'], 'Blue']
# Matchs ajoutés : 94600
#
# Dernier match ajouté : [['TOP', 'Yone', 'JUNGLE', 'Shyvana', 'MIDDLE', 'Ahri', 'BOTTOM', 'Ezreal', 'UTILITY', 'Leona'], ['TOP', 'Renekton', 'JUNGLE', 'Nunu', 'MIDDLE', 'Taliyah', 'BOTTOM', 'Samira', 'UTILITY', 'Nautilus'], 'Red']
# Matchs ajoutés : 94700
#
# Dernier match ajouté : [['TOP', 'Darius', 'JUNGLE', 'Zac', 'MIDDLE', 'Qiyana', 'BOTTOM', 'Draven', 'UTILITY', 'Nautilus'], ['TOP', 'Pantheon', 'JUNGLE', 'Ekko', 'MIDDLE', 'Akshan', 'BOTTOM', 'Ezreal', 'UTILITY', 'Lux'], 'Blue']
# Matchs ajoutés : 94800
#
# Dernier match ajouté : [['TOP', 'Yone', 'JUNGLE', 'Urgot', 'MIDDLE', 'Annie', 'BOTTOM', 'Draven', 'UTILITY', 'Nami'], ['TOP', 'Aatrox', 'JUNGLE', 'Graves', 'MIDDLE', 'Syndra', 'BOTTOM', 'Aphelios', 'UTILITY', 'Milio'], 'Red']
# Matchs ajoutés : 94900
#
# Dernier match ajouté : [['TOP', 'Aatrox', 'JUNGLE', 'Sejuani', 'MIDDLE', 'Katarina', 'BOTTOM', 'Xayah', 'UTILITY', 'Rakan'], ['TOP', 'Fiora', 'JUNGLE', 'Khazix', 'MIDDLE', 'Neeko', 'BOTTOM', 'Draven', 'UTILITY', 'Thresh'], 'Red']
# Matchs ajoutés : 95000
#
# Dernier match ajouté : [['MIDDLE', 'KSante', 'JUNGLE', 'Taliyah', 'TOP', 'Irelia', 'BOTTOM', 'Kaisa', 'UTILITY', 'Karma'], ['TOP', 'Fiora', 'JUNGLE', 'Ekko', 'MIDDLE', 'Jayce', 'BOTTOM', 'Caitlyn', 'UTILITY', 'Bard'], 'Blue']
# Matchs ajoutés : 95000
#
# Dernier match ajouté : []
# Matchs ajoutés : 95100
#
# Dernier match ajouté : [['TOP', 'KSante', 'JUNGLE', 'FiddleSticks', 'MIDDLE', 'Yone', 'BOTTOM', 'Aphelios', 'UTILITY', 'Rumble'], ['TOP', 'Pantheon', 'JUNGLE', 'Karthus', 'MIDDLE', 'Leblanc', 'BOTTOM', 'Nilah', 'UTILITY', 'Bard'], 'Red']
# Matchs ajoutés : 95200
#
# Dernier match ajouté : [['TOP', 'KSante', 'JUNGLE', 'Viego', 'MIDDLE', 'Kassadin', 'BOTTOM', 'Varus', 'UTILITY', 'Neeko'], ['TOP', 'Lulu', 'JUNGLE', 'Khazix', 'MIDDLE', 'Rumble', 'BOTTOM', 'Xayah', 'UTILITY', 'Rakan'], 'Blue']
# Matchs ajoutés : 95300
#
# Dernier match ajouté : [['TOP', 'Yone', 'JUNGLE', 'Viego', 'MIDDLE', 'Syndra', 'BOTTOM', 'Kaisa', 'UTILITY', 'Blitzcrank'], ['TOP', 'Kennen', 'JUNGLE', 'Kayn', 'MIDDLE', 'Tristana', 'BOTTOM', 'Ezreal', 'UTILITY', 'Senna'], 'Blue']
# Matchs ajoutés : 95300
#
# Dernier match ajouté : []
# Matchs ajoutés : 95400
#
# Dernier match ajouté : [['TOP', 'Aatrox', 'JUNGLE', 'Karthus', 'MIDDLE', 'Yasuo', 'BOTTOM', 'Veigar', 'UTILITY', 'Alistar'], ['TOP', 'Sylas', 'JUNGLE', 'RekSai', 'MIDDLE', 'Leblanc', 'BOTTOM', 'Lucian', 'UTILITY', 'Milio'], 'Blue']
# Matchs ajoutés : 95500
#
# Dernier match ajouté : [['TOP', 'Aatrox', 'JUNGLE', 'Elise', 'MIDDLE', 'Tryndamere', 'BOTTOM', 'Jhin', 'UTILITY', 'Blitzcrank'], ['TOP', 'Renekton', 'JUNGLE', 'Viego', 'MIDDLE', 'Taliyah', 'BOTTOM', 'Draven', 'UTILITY', 'Nautilus'], 'Red']
# Matchs ajoutés : 95500
#
# Dernier match ajouté : []
# Matchs ajoutés : 95600
#
# Dernier match ajouté : [['TOP', 'KSante', 'JUNGLE', 'Viego', 'MIDDLE', 'Lux', 'BOTTOM', 'Varus', 'UTILITY', 'Rakan'], ['TOP', 'Renekton', 'JUNGLE', 'Graves', 'MIDDLE', 'Zoe', 'BOTTOM', 'Yasuo', 'UTILITY', 'Nautilus'], 'Blue']
# Matchs ajoutés : 95600
#
# Dernier match ajouté : []
# Matchs ajoutés : 95700
#
# Dernier match ajouté : [['TOP', 'Renekton', 'JUNGLE', 'LeeSin', 'MIDDLE', 'TwistedFate', 'BOTTOM', 'Ezreal', 'UTILITY', 'Janna'], ['TOP', 'Rumble', 'JUNGLE', 'Nidalee', 'MIDDLE', 'Qiyana', 'BOTTOM', 'Samira', 'UTILITY', 'Rakan'], 'Blue']
# Matchs ajoutés : 95800
#
# Dernier match ajouté : [['TOP', 'Malphite', 'JUNGLE', 'Maokai', 'MIDDLE', 'Talon', 'BOTTOM', 'Jinx', 'UTILITY', 'Rakan'], ['TOP', 'Rumble', 'JUNGLE', 'Viego', 'MIDDLE', 'TwistedFate', 'BOTTOM', 'Samira', 'UTILITY', 'Rell'], 'Red']
# Matchs ajoutés : 95800
#
# Dernier match ajouté : []
# Matchs ajoutés : 95900
#
# Dernier match ajouté : [['TOP', 'Gwen', 'JUNGLE', 'Maokai', 'MIDDLE', 'Talon', 'BOTTOM', 'Jhin', 'UTILITY', 'MissFortune'], ['TOP', 'Rumble', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Diana', 'BOTTOM', 'Lucian', 'UTILITY', 'Nami'], 'Blue']
# Matchs ajoutés : 96000
#
# Dernier match ajouté : [['TOP', 'Fiora', 'JUNGLE', 'Rumble', 'MIDDLE', 'Akali', 'BOTTOM', 'Kaisa', 'UTILITY', 'Nautilus'], ['TOP', 'Irelia', 'JUNGLE', 'Diana', 'MIDDLE', 'TwistedFate', 'BOTTOM', 'Tristana', 'UTILITY', 'Blitzcrank'], 'Red']
# Matchs ajoutés : 96100
#
# Dernier match ajouté : [['TOP', 'Garen', 'JUNGLE', 'Taliyah', 'MIDDLE', 'Galio', 'BOTTOM', 'Kaisa', 'UTILITY', 'Soraka'], ['TOP', 'Gnar', 'JUNGLE', 'Maokai', 'MIDDLE', 'Zed', 'BOTTOM', 'Sivir', 'UTILITY', 'Pyke'], 'Red']
# Matchs ajoutés : 96200
#
# Dernier match ajouté : [['TOP', 'Jax', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Sylas', 'BOTTOM', 'Ezreal', 'UTILITY', 'Karma'], ['TOP', 'Yorick', 'JUNGLE', 'Hecarim', 'MIDDLE', 'Viktor', 'BOTTOM', 'Jhin', 'UTILITY', 'Xerath'], 'Blue']
# Matchs ajoutés : 96300
#
# Dernier match ajouté : [['TOP', 'KSante', 'JUNGLE', 'Khazix', 'MIDDLE', 'Akali', 'BOTTOM', 'Yasuo', 'UTILITY', 'Nautilus'], ['TOP', 'Renekton', 'JUNGLE', 'Evelynn', 'MIDDLE', 'Jayce', 'BOTTOM', 'Cassiopeia', 'UTILITY', 'Maokai'], 'Red']
# Matchs ajoutés : 96300
#
# Dernier match ajouté : []
# Matchs ajoutés : 96400
#
# Dernier match ajouté : [['TOP', 'Ornn', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Ahri', 'BOTTOM', 'Kaisa', 'UTILITY', 'Thresh'], ['TOP', 'Rumble', 'JUNGLE', 'MonkeyKing', 'MIDDLE', 'Qiyana', 'BOTTOM', 'Aphelios', 'UTILITY', 'Blitzcrank'], 'Blue']
# Matchs ajoutés : 96500
#
# Dernier match ajouté : [['TOP', 'Jax', 'JUNGLE', 'Taliyah', 'MIDDLE', 'Leblanc', 'BOTTOM', 'Sivir', 'UTILITY', 'Zyra'], ['TOP', 'Irelia', 'JUNGLE', 'Amumu', 'MIDDLE', 'Naafiri', 'BOTTOM', 'Kaisa', 'UTILITY', 'Zilean'], 'Red']
# Matchs ajoutés : 96500
#
# Dernier match ajouté : []
# Matchs ajoutés : 96600
#
# Dernier match ajouté : [['TOP', 'Sion', 'JUNGLE', 'Elise', 'MIDDLE', 'Orianna', 'BOTTOM', 'Ezreal', 'UTILITY', 'Pyke'], ['TOP', 'Jax', 'JUNGLE', 'Karthus', 'MIDDLE', 'Akshan', 'BOTTOM', 'Kaisa', 'UTILITY', 'Morgana'], 'Red']
# Matchs ajoutés : 96700
#
# Dernier match ajouté : [['TOP', 'Renekton', 'JUNGLE', 'Karthus', 'MIDDLE', 'Zed', 'BOTTOM', 'Varus', 'UTILITY', 'Rakan'], ['TOP', 'Aatrox', 'JUNGLE', 'Kindred', 'BOTTOM', 'Xayah', 'MIDDLE', 'Chogath', 'UTILITY', 'Rell'], 'Red']
# Matchs ajoutés : 96800
#
# Dernier match ajouté : [['TOP', 'Maokai', 'JUNGLE', 'RekSai', 'MIDDLE', 'Naafiri', 'BOTTOM', 'Kaisa', 'UTILITY', 'Rakan'], ['TOP', 'Udyr', 'JUNGLE', 'Graves', 'MIDDLE', 'Yasuo', 'BOTTOM', 'Xayah', 'UTILITY', 'Nautilus'], 'Red']
# Matchs ajoutés : 96900
#
# Dernier match ajouté : [['TOP', 'Udyr', 'JUNGLE', 'Graves', 'MIDDLE', 'Cassiopeia', 'BOTTOM', 'Sylas', 'UTILITY', 'Taric'], ['TOP', 'Jayce', 'JUNGLE', 'Rengar', 'MIDDLE', 'Akshan', 'UTILITY', 'Thresh', 'UTILITY', 'Kaisa'], 'Blue']
# Matchs ajoutés : 97000
#
# Dernier match ajouté : [['TOP', 'Nocturne', 'JUNGLE', 'Taliyah', 'MIDDLE', 'Viego', 'BOTTOM', 'Ezreal', 'UTILITY', 'Poppy'], ['TOP', 'Olaf', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Lissandra', 'BOTTOM', 'Xayah', 'UTILITY', 'Rakan'], 'Red']
# Matchs ajoutés : 97100
#
# Dernier match ajouté : [['TOP', 'Jax', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Neeko', 'BOTTOM', 'Kaisa', 'UTILITY', 'Rakan'], ['TOP', 'Gragas', 'JUNGLE', 'Graves', 'MIDDLE', 'Galio', 'BOTTOM', 'Samira', 'UTILITY', 'Pyke'], 'Red']
# Matchs ajoutés : 97100
#
# Dernier match ajouté : []
# Matchs ajoutés : 97200
#
# Dernier match ajouté : [['TOP', 'Aatrox', 'JUNGLE', 'Nunu', 'MIDDLE', 'Leblanc', 'BOTTOM', 'Samira', 'UTILITY', 'Alistar'], ['TOP', 'Renekton', 'JUNGLE', 'Lillia', 'MIDDLE', 'Tristana', 'BOTTOM', 'Kaisa', 'UTILITY', 'Gragas'], 'Red']
# Matchs ajoutés : 97200
#
# Dernier match ajouté : []
# Matchs ajoutés : 97300
#
# Dernier match ajouté : [['TOP', 'Jax', 'JUNGLE', 'Sejuani', 'MIDDLE', 'Vayne', 'BOTTOM', 'Kaisa', 'UTILITY', 'Nautilus'], ['TOP', 'Malphite', 'JUNGLE', 'MasterYi', 'MIDDLE', 'Zed', 'BOTTOM', 'Ezreal', 'UTILITY', 'Anivia'], 'Blue']
# Matchs ajoutés : 97400
#
# Dernier match ajouté : [['TOP', 'Garen', 'JUNGLE', 'Taliyah', 'MIDDLE', 'Anivia', 'BOTTOM', 'Samira', 'UTILITY', 'Rell'], ['TOP', 'Gragas', 'JUNGLE', 'Khazix', 'MIDDLE', 'Jhin', 'BOTTOM', 'Zeri', 'UTILITY', 'Braum'], 'Red']
# Matchs ajoutés : 97500
#
# Dernier match ajouté : [['TOP', 'Rumble', 'JUNGLE', 'Taliyah', 'MIDDLE', 'Tristana', 'BOTTOM', 'Caitlyn', 'UTILITY', 'Pyke'], ['TOP', 'Darius', 'JUNGLE', 'Elise', 'MIDDLE', 'AurelionSol', 'BOTTOM', 'Kaisa', 'UTILITY', 'Leona'], 'Blue']
# Matchs ajoutés : 97500
#
# Dernier match ajouté : []
# Matchs ajoutés : 97600
#
# Dernier match ajouté : [['TOP', 'Jayce', 'JUNGLE', 'Viego', 'MIDDLE', 'Viktor', 'BOTTOM', 'Sivir', 'UTILITY', 'Soraka'], ['TOP', 'Jax', 'JUNGLE', 'Taliyah', 'MIDDLE', 'Pantheon', 'BOTTOM', 'MissFortune', 'UTILITY', 'Thresh'], 'Blue']
# Matchs ajoutés : 97700
#
# Dernier match ajouté : [['TOP', 'Rammus', 'JUNGLE', 'Belveth', 'MIDDLE', 'Tristana', 'BOTTOM', 'Ezreal', 'UTILITY', 'Thresh'], ['TOP', 'Aatrox', 'JUNGLE', 'MasterYi', 'MIDDLE', 'Ahri', 'BOTTOM', 'Xayah', 'UTILITY', 'Rakan'], 'Red']
# Matchs ajoutés : 97700
#
# Dernier match ajouté : []
# Matchs ajoutés : 97800
#
# Dernier match ajouté : [['TOP', 'Poppy', 'JUNGLE', 'Udyr', 'MIDDLE', 'Sylas', 'BOTTOM', 'Draven', 'UTILITY', 'Pyke'], ['BOTTOM', 'Xayah', 'JUNGLE', 'JarvanIV', 'MIDDLE', 'Irelia', 'TOP', 'Rumble', 'UTILITY', 'Alistar'], 'Red']
# Matchs ajoutés : 97900
#
# Dernier match ajouté : [['TOP', 'Gwen', 'JUNGLE', 'FiddleSticks', 'MIDDLE', 'Qiyana', 'BOTTOM', 'Sivir', 'UTILITY', 'Morgana'], ['TOP', 'Aatrox', 'JUNGLE', 'Elise', 'MIDDLE', 'Lissandra', 'BOTTOM', 'Varus', 'UTILITY', 'Yuumi'], 'Blue']
# Matchs ajoutés : 98000
#
# Dernier match ajouté : [['TOP', 'Leblanc', 'JUNGLE', 'Viego', 'MIDDLE', 'Azir', 'BOTTOM', 'Ezreal', 'UTILITY', 'Soraka'], ['TOP', 'Nocturne', 'JUNGLE', 'Qiyana', 'MIDDLE', 'Brand', 'BOTTOM', 'Varus', 'UTILITY', 'Karma'], 'Blue']
# Matchs ajoutés : 98100
#
# Dernier match ajouté : [['TOP', 'Rengar', 'JUNGLE', 'Naafiri', 'MIDDLE', 'Ahri', 'BOTTOM', 'Ezreal', 'UTILITY', 'Karma'], ['TOP', 'Riven', 'JUNGLE', 'Graves', 'MIDDLE', 'Aatrox', 'BOTTOM', 'Vayne', 'UTILITY', 'Leona'], 'Blue']
# Matchs ajoutés : 98200
#
# Dernier match ajouté : [['TOP', 'Vladimir', 'JUNGLE', 'Kindred', 'MIDDLE', 'TwistedFate', 'BOTTOM', 'Jinx', 'UTILITY', 'Thresh'], ['TOP', 'Fiora', 'JUNGLE', 'Taliyah', 'MIDDLE', 'Brand', 'BOTTOM', 'Jhin', 'UTILITY', 'Leona'], 'Blue']
# Matchs ajoutés : 98200
#
# Dernier match ajouté : []
# Matchs ajoutés : 98300
#
# Dernier match ajouté : [['TOP', 'Rumble', 'JUNGLE', 'LeeSin', 'MIDDLE', 'Neeko', 'BOTTOM', 'Varus', 'UTILITY', 'Zyra'], ['TOP', 'Renekton', 'JUNGLE', 'Ivern', 'MIDDLE', 'Leblanc', 'BOTTOM', 'Aphelios', 'UTILITY', 'Blitzcrank'], 'Blue']
